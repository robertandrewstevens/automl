# %% [markdown]
# # AutoGluon: Porto Seguro (Classification) # 1
#
# Based on: https://auto.gluon.ai/0.1.0/tutorials/tabular_prediction/tabular-quickstart.html

# %%
time_limit = 60*60  # 1 hour max (confirm with timer)
metric = "roc_auc"  # specify your evaluation metric
label = "target" # name of target or label variable (just happens to be called "target" for this dataset)

# %% [markdown]
# ## Import

# %%
# Import packages

from autogluon.tabular import TabularDataset
from autogluon.tabular import TabularPredictor

import numpy as np
import pandas as pd

# %%
# Import data

train_data = TabularDataset("porto_train.csv")
test_data = TabularDataset("porto_test.csv")

# %%
train_data.shape
# Out:
# (476170, 60)

# %%
test_data.shape
# Out:
# (119042, 59)

# %% [markdown]
# ## Tidy

# %%
# Replace "-1" with missing value
train_data = train_data.replace(-1, np.nan)
test_data = test_data.replace(-1, np.nan)

# %% [markdown]
# ## Transform

# %%
# Drop variable not used as predictors
train_data = train_data.drop(["id", "fold"], axis=1)
test_data = test_data.drop(["id"], axis=1)

# %%
# Convert categorical variables to "category" data type
cat_vars = [col for col in train_data.columns if 'cat' in col]
cat_vars
# Out:
# ['ps_ind_02_cat',
#  'ps_ind_04_cat',
#  'ps_ind_05_cat',
#  'ps_car_01_cat',
#  'ps_car_02_cat',
#  'ps_car_03_cat',
#  'ps_car_04_cat',
#  'ps_car_05_cat',
#  'ps_car_06_cat',
#  'ps_car_07_cat',
#  'ps_car_08_cat',
#  'ps_car_09_cat',
#  'ps_car_10_cat',
#  'ps_car_11_cat']

# %%
for col in cat_vars:
    test_data[col] = test_data[col].astype('category')
    
cat_vars = cat_vars + ["target"]

for col in cat_vars:
    train_data[col] = train_data[col].astype('category')

# %%
# Create separate test data to demonstrate how to make predictions on new examples at inference time:
y_test = test_data[label]  # values to predict

# %% [markdown]
# ## Visualize

# %% [markdown]
# (skipped)

# %% [markdown]
# ## Model 1

# %%
# %timeit

predictor = TabularPredictor(
    label=label, 
    eval_metric=metric
).fit(
    train_data, 
    time_limit=time_limit
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230709_041912/"
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230709_041912/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    476170
# Train Data Columns: 57
# Label Column: target
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    54314.7 MB
# 	Train Data (Original)  Memory Usage: 170.47 MB (0.3% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 18 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 14 | ['ps_ind_02_cat', 'ps_ind_04_cat', 'ps_ind_05_cat', 'ps_car_01_cat', 'ps_car_02_cat', ...]
# 		('float', [])    : 11 | ['ps_reg_01', 'ps_reg_02', 'ps_reg_03', 'ps_car_11', 'ps_car_12', ...]
# 		('int', [])      : 32 | ['ps_ind_01', 'ps_ind_03', 'ps_ind_06_bin', 'ps_ind_07_bin', 'ps_ind_08_bin', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 13 | ['ps_ind_02_cat', 'ps_ind_04_cat', 'ps_ind_05_cat', 'ps_car_01_cat', 'ps_car_02_cat', ...]
# 		('float', [])     : 11 | ['ps_reg_01', 'ps_reg_02', 'ps_reg_03', 'ps_car_11', 'ps_car_12', ...]
# 		('int', [])       : 15 | ['ps_ind_01', 'ps_ind_03', 'ps_ind_14', 'ps_ind_15', 'ps_calc_04', ...]
# 		('int', ['bool']) : 18 | ['ps_ind_06_bin', 'ps_ind_07_bin', 'ps_ind_08_bin', 'ps_ind_09_bin', 'ps_ind_10_bin', ...]
# 	2.5s = Fit runtime
# 	57 features in original data used to generate 57 features in processed data.
# 	Train Data (Processed) Memory Usage: 113.81 MB (0.2% of available memory)
# Data preprocessing and feature engineering runtime = 3.07s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.01, Train Rows: 471408, Val Rows: 4762
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ... Training model for up to 3596.93s of the 3596.93s of remaining time.
# 	0.5039	 = Validation score   (roc_auc)
# 	9.88s	 = Training   runtime
# 	1.28s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 3585.47s of the 3585.47s of remaining time.
# 	0.5047	 = Validation score   (roc_auc)
# 	0.73s	 = Training   runtime
# 	1.18s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 3583.27s of the 3583.27s of remaining time.
# 	0.5919	 = Validation score   (roc_auc)
# 	6.22s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3576.96s of the 3576.96s of remaining time.
# 	0.5818	 = Validation score   (roc_auc)
# 	1.77s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ... Training model for up to 3575.09s of the 3575.09s of remaining time.
# 	0.583	 = Validation score   (roc_auc)
# 	18.47s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForestEntr ... Training model for up to 3554.4s of the 3554.4s of remaining time.
# 	0.5819	 = Validation score   (roc_auc)
# 	17.82s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 3534.32s of the 3534.32s of remaining time.
# 	0.602	 = Validation score   (roc_auc)
# 	54.72s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesGini ... Training model for up to 3479.45s of the 3479.45s of remaining time.
# 	0.5851	 = Validation score   (roc_auc)
# 	11.64s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: ExtraTreesEntr ... Training model for up to 3465.18s of the 3465.18s of remaining time.
# 	0.6018	 = Validation score   (roc_auc)
# 	13.8s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 3448.95s of the 3448.95s of remaining time.
# No improvement since epoch 6: early stopping
# 	0.5908	 = Validation score   (roc_auc)
# 	347.12s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 3101.4s of the 3101.39s of remaining time.
# 	0.6015	 = Validation score   (roc_auc)
# 	8.48s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 3092.74s of the 3092.74s of remaining time.
# 	0.5942	 = Validation score   (roc_auc)
# 	280.28s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 2812.31s of the 2812.3s of remaining time.
# 	0.5871	 = Validation score   (roc_auc)
# 	3.45s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2808.69s of remaining time.
# 	0.6123	 = Validation score   (roc_auc)
# 	1.38s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 793.69s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230709_041912/")

# %%
# Use trained models to make predictions on the new data and then evaluate performance:
y_pred = predictor.predict_proba(test_data)

# %%
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluation: roc_auc on test data: 0.6318303042376591
# Evaluations on test data:
# {
#     "roc_auc": 0.6318303042376591,
#     "accuracy": 0.9635842811780716,
#     "balanced_accuracy": 0.5,
#     "mcc": 0.0,
#     "f1": 0.0,
#     "precision": 0.0,
#     "recall": 0.0
# }

# %%
# Evaluate the performance of each individual trained model on test data:
predictor.leaderboard(test_data, silent=True)
# Out:
#                       model  score_test  score_val  pred_time_test  \
# 0       WeightedEnsemble_L2    0.637412   0.643819       41.094840
# 1           CatBoost_BAG_L1    0.636831   0.641170        1.771478
# 2            XGBoost_BAG_L1    0.635973   0.638350        7.723609
# 3    NeuralNetFastAI_BAG_L1    0.633692   0.633700       11.070570
# 4         LightGBMXT_BAG_L1    0.625950   0.632746        1.868313
# 5      LightGBMLarge_BAG_L1    0.625450   0.631070        1.680449
# 6           LightGBM_BAG_L1    0.624337   0.631292        1.626274
# 7     NeuralNetTorch_BAG_L1    0.623265   0.624779       10.279494
# 8   RandomForestEntr_BAG_L1    0.612346   0.603324        1.565257
# 9     ExtraTreesGini_BAG_L1    0.611302   0.601947        1.644346
# 10    ExtraTreesEntr_BAG_L1    0.610887   0.602843        1.854632
# 11  RandomForestGini_BAG_L1    0.606320   0.599457        1.638636
# 12    KNeighborsUnif_BAG_L1    0.508529   0.507671        8.839921
# 13    KNeighborsDist_BAG_L1    0.507869   0.507647        9.337647
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 0      107.645130  3184.220309                 0.016129
# 1        1.641047   526.517942                 1.771478
# 2        4.710784    21.222854                 7.723609
# 3        8.574730  1404.439920                11.070570
# 4        1.751455    13.131827                 1.868313
# 5        1.986630    21.514956                 1.680449
# 6        1.626623    12.259130                 1.626274
# 7        8.108717  1017.867617                10.279494
# 8       27.163695    22.053309                 1.565257
# 9       24.210879    13.278623                 1.644346
# 10      25.356524    13.531745                 1.854632
# 11      26.636434    21.747743                 1.638636
# 12      32.418323     0.610170                 8.839921
# 13      31.855565     0.628425                 9.337647
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.088491         109.933267            2       True
# 1                 1.641047         526.517942            1       True
# 2                 4.710784          21.222854            1       True
# 3                 8.574730        1404.439920            1       True
# 4                 1.751455          13.131827            1       True
# 5                 1.986630          21.514956            1       True
# 6                 1.626623          12.259130            1       True
# 7                 8.108717        1017.867617            1       True
# 8                27.163695          22.053309            1       True
# 9                24.210879          13.278623            1       True
# 10               25.356524          13.531745            1       True
# 11               26.636434          21.747743            1       True
# 12               32.418323           0.610170            1       True
# 13               31.855565           0.628425            1       True
#
#     fit_order
# 0          14
# 1           7
# 2          11
# 3          10
# 4           3
# 5          13
# 6           4
# 7          12
# 8           6
# 9           8
# 10          9
# 11          5
# 12          1
# 13          2

# %% [markdown]
# ## Model 2

# %%
# %timeit

predictor = TabularPredictor(label, eval_metric=metric).fit(train_data, time_limit=time_limit, presets='best_quality')
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230709_043303/"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230709_043303/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    476170
# Train Data Columns: 57
# Label Column: target
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    46129.58 MB
# 	Train Data (Original)  Memory Usage: 170.47 MB (0.4% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 18 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 14 | ['ps_ind_02_cat', 'ps_ind_04_cat', 'ps_ind_05_cat', 'ps_car_01_cat', 'ps_car_02_cat', ...]
# 		('float', [])    : 11 | ['ps_reg_01', 'ps_reg_02', 'ps_reg_03', 'ps_car_11', 'ps_car_12', ...]
# 		('int', [])      : 32 | ['ps_ind_01', 'ps_ind_03', 'ps_ind_06_bin', 'ps_ind_07_bin', 'ps_ind_08_bin', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 13 | ['ps_ind_02_cat', 'ps_ind_04_cat', 'ps_ind_05_cat', 'ps_car_01_cat', 'ps_car_02_cat', ...]
# 		('float', [])     : 11 | ['ps_reg_01', 'ps_reg_02', 'ps_reg_03', 'ps_car_11', 'ps_car_12', ...]
# 		('int', [])       : 15 | ['ps_ind_01', 'ps_ind_03', 'ps_ind_14', 'ps_ind_15', 'ps_calc_04', ...]
# 		('int', ['bool']) : 18 | ['ps_ind_06_bin', 'ps_ind_07_bin', 'ps_ind_08_bin', 'ps_ind_09_bin', 'ps_ind_10_bin', ...]
# 	3.9s = Fit runtime
# 	57 features in original data used to generate 57 features in processed data.
# 	Train Data (Processed) Memory Usage: 113.81 MB (0.2% of available memory)
# Data preprocessing and feature engineering runtime = 4.6s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 3595.4s of the 3595.4s of remaining time.
# 	0.5077	 = Validation score   (roc_auc)
# 	0.61s	 = Training   runtime
# 	32.42s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 3561.65s of the 3561.64s of remaining time.
# 	0.5076	 = Validation score   (roc_auc)
# 	0.63s	 = Training   runtime
# 	31.86s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3528.24s of the 3528.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6327	 = Validation score   (roc_auc)
# 	13.13s	 = Training   runtime
# 	1.75s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3494.83s of the 3494.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6313	 = Validation score   (roc_auc)
# 	12.26s	 = Training   runtime
# 	1.63s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 3475.14s of the 3475.14s of remaining time.
# 	0.5995	 = Validation score   (roc_auc)
# 	21.75s	 = Training   runtime
# 	26.64s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 3423.95s of the 3423.95s of remaining time.
# 	0.6033	 = Validation score   (roc_auc)
# 	22.05s	 = Training   runtime
# 	27.16s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3372.0s of the 3372.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6412	 = Validation score   (roc_auc)
# 	526.52s	 = Training   runtime
# 	1.64s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2837.96s of the 2837.95s of remaining time.
# 	0.6019	 = Validation score   (roc_auc)
# 	13.28s	 = Training   runtime
# 	24.21s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2797.75s of the 2797.74s of remaining time.
# 	0.6028	 = Validation score   (roc_auc)
# 	13.53s	 = Training   runtime
# 	25.36s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2756.14s of the 2756.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6337	 = Validation score   (roc_auc)
# 	1404.44s	 = Training   runtime
# 	8.57s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1341.99s of the 1341.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6384	 = Validation score   (roc_auc)
# 	21.22s	 = Training   runtime
# 	4.71s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1311.1s of the 1311.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6248	 = Validation score   (roc_auc)
# 	1017.87s	 = Training   runtime
# 	8.11s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 285.98s of the 285.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6311	 = Validation score   (roc_auc)
# 	21.51s	 = Training   runtime
# 	1.99s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 254.72s of remaining time.
# 	0.6438	 = Validation score   (roc_auc)
# 	109.93s	 = Training   runtime
# 	0.09s	 = Validation runtime
# AutoGluon training complete, total runtime = 3456.02s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230709_043303/")

# %%
# Use trained models to make predictions on the new data and then evaluate performance:
y_pred = predictor.predict_proba(test_data)

# %%
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluation: roc_auc on test data: 0.6374115862058618
# Evaluations on test data:
# {
#     "roc_auc": 0.6374115862058618,
#     "accuracy": 0.9635842811780716,
#     "balanced_accuracy": 0.5,
#     "mcc": 0.0,
#     "f1": 0.0,
#     "precision": 0.0,
#     "recall": 0.0
# }

# %%
# Evaluate the performance of each individual trained model on test data:
predictor.leaderboard(test_data, silent=True)
# Out:
#                       model  score_test  score_val  pred_time_test  \
# 0       WeightedEnsemble_L2    0.637412   0.643819       41.714066
# 1           CatBoost_BAG_L1    0.636831   0.641170        1.440531
# 2            XGBoost_BAG_L1    0.635973   0.638350        7.920245
# 3    NeuralNetFastAI_BAG_L1    0.633692   0.633700       10.987027
# 4         LightGBMXT_BAG_L1    0.625950   0.632746        1.557794
# 5      LightGBMLarge_BAG_L1    0.625450   0.631070        1.914848
# 6           LightGBM_BAG_L1    0.624337   0.631292        1.503453
# 7     NeuralNetTorch_BAG_L1    0.623265   0.624779       10.898428
# 8   RandomForestEntr_BAG_L1    0.612346   0.603324        1.766314
# 9     ExtraTreesGini_BAG_L1    0.611302   0.601947        2.383173
# 10    ExtraTreesEntr_BAG_L1    0.610887   0.602843        1.863467
# 11  RandomForestGini_BAG_L1    0.606320   0.599457        1.844809
# 12    KNeighborsUnif_BAG_L1    0.508529   0.507671        8.861315
# 13    KNeighborsDist_BAG_L1    0.507869   0.507647        9.277762
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 0      107.645130  3184.220309                 0.017151
# 1        1.641047   526.517942                 1.440531
# 2        4.710784    21.222854                 7.920245
# 3        8.574730  1404.439920                10.987027
# 4        1.751455    13.131827                 1.557794
# 5        1.986630    21.514956                 1.914848
# 6        1.626623    12.259130                 1.503453
# 7        8.108717  1017.867617                10.898428
# 8       27.163695    22.053309                 1.766314
# 9       24.210879    13.278623                 2.383173
# 10      25.356524    13.531745                 1.863467
# 11      26.636434    21.747743                 1.844809
# 12      32.418323     0.610170                 8.861315
# 13      31.855565     0.628425                 9.277762
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.088491         109.933267            2       True
# 1                 1.641047         526.517942            1       True
# 2                 4.710784          21.222854            1       True
# 3                 8.574730        1404.439920            1       True
# 4                 1.751455          13.131827            1       True
# 5                 1.986630          21.514956            1       True
# 6                 1.626623          12.259130            1       True
# 7                 8.108717        1017.867617            1       True
# 8                27.163695          22.053309            1       True
# 9                24.210879          13.278623            1       True
# 10               25.356524          13.531745            1       True
# 11               26.636434          21.747743            1       True
# 12               32.418323           0.610170            1       True
# 13               31.855565           0.628425            1       True
#
#     fit_order
# 0          14
# 1           7
# 2          11
# 3          10
# 4           3
# 5          13
# 6           4
# 7          12
# 8           6
# 9           8
# 10          9
# 11          5
# 12          1
# 13          2

# %% [markdown]
# ## Communicate

# %% [markdown]
# (skipped)
