# %% [markdown]
# # AutoML: Build Production-Ready Models Quickly!
#
# https://www.linkedin.com/learning/automl-build-production-ready-models-quickly/

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data

# %%
# TODO: Download the suggested data from Zindi
# https://zindi.africa/competitions/ai-tunisia-hack-5-predictive-analytics-challenge-2
# data = TabularDataset("data/Train.csv")
data = TabularDataset("Train_zindi.csv")
data.head()
# Out:
#            ID       DATOP     FLTID DEPSTN ARRSTN                  STD  \
# 0  train_id_0  2016-01-03  TU 0712     CMN    TUN  2016-01-03 10:30:00
# 1  train_id_1  2016-01-13  TU 0757     MXP    TUN  2016-01-13 15:05:00
# 2  train_id_2  2016-01-16  TU 0214     TUN    IST  2016-01-16 04:10:00
# 3  train_id_3  2016-01-17  TU 0480     DJE    NTE  2016-01-17 14:10:00
# 4  train_id_4  2016-01-17  TU 0338     TUN    ALG  2016-01-17 14:30:00
#
#                    STA STATUS         AC  target
# 0  2016-01-03 12.55.00    ATA  TU 32AIMN   260.0
# 1  2016-01-13 16.55.00    ATA  TU 31BIMO    20.0
# 2  2016-01-16 06.45.00    ATA  TU 32AIMN     0.0
# 3  2016-01-17 17.00.00    ATA  TU 736IOK     0.0
# 4  2016-01-17 15.50.00    ATA  TU 320IMU    22.0

# %%
train, val = train_test_split(data, test_size=0.3, shuffle=True)

# %%
# test = TabularDataset("data/Test.csv")
test = TabularDataset("Test_zindi.csv")
test.head()
# Out:
#           ID       DATOP     FLTID DEPSTN ARRSTN                  STD  \
# 0  test_id_0  2016-05-04  TU 0700     DJE    TUN  2016-05-04 06:40:00
# 1  test_id_1  2016-05-05  TU 0395     TUN    BKO  2016-05-05 15:20:00
# 2  test_id_2  2016-05-06  TU 0745     FRA    TUN  2016-05-06 10:00:00
# 3  test_id_3  2016-05-11  TU 0848     BEY    TUN  2016-05-11 09:40:00
# 4  test_id_4  2016-05-11  TU 0635     ORY    MIR  2016-05-11 09:50:00
#
#                    STA STATUS         AC
# 0  2016-05-04 07.30.00    ATA  TU 32AIMF
# 1  2016-05-05 20.05.00    ATA  TU 320IMW
# 2  2016-05-06 12.25.00    ATA  TU 32AIMC
# 3  2016-05-11 13.10.00    ATA  TU 31BIMO
# 4  2016-05-11 12.35.00    ATA  TU 736IOQ

# %% [markdown]
# ## Modeling

# %%
LABEL = 'target'
SAVE_PATH = 'AutoGluonModels_exercise'
EVAL_METRIC = 'root_mean_squared_error'
PROBLEM_TYPE = 'regression'

# %%
# TODO: Fit the Tabular Predictor and enable bagging
predictor = TabularPredictor(
    label=LABEL, 
    problem_type=PROBLEM_TYPE, 
    path=SAVE_PATH, 
    eval_metric=EVAL_METRIC
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutoGluonModels_exercise"

# %%
predictor.fit(train, presets=["best_quality"], time_limit=300)
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 300s
# AutoGluon will save models to "AutoGluonModels_exercise/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    75483
# Train Data Columns: 9
# Label Column: target
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    252925.39 MB
# 	Train Data (Original)  Memory Usage: 45.37 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Unused Original Features (Count: 1): ['ID']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['ID']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('object', [])                     : 6 | ['FLTID', 'DEPSTN', 'ARRSTN', 'STA', 'STATUS', ...]
# 		('object', ['datetime_as_object']) : 2 | ['DATOP', 'STD']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             :  6 | ['FLTID', 'DEPSTN', 'ARRSTN', 'STA', 'STATUS', ...]
# 		('int', ['datetime_as_int']) : 10 | ['DATOP', 'DATOP.year', 'DATOP.month', 'DATOP.day', 'DATOP.dayofweek', ...]
# 	0.9s = Fit runtime
# 	8 features in original data used to generate 16 features in processed data.
# 	Train Data (Processed) Memory Usage: 6.65 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.99s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 199.29s of the 299.01s of remaining time.
# 	-123.0407	 = Validation score   (-root_mean_squared_error)
# 	0.25s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 195.27s of the 294.99s of remaining time.
# 	-135.7765	 = Validation score   (-root_mean_squared_error)
# 	0.24s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 194.06s of the 293.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-110.5703	 = Validation score   (-root_mean_squared_error)
# 	8.09s	 = Training   runtime
# 	1.24s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 172.67s of the 272.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-109.0453	 = Validation score   (-root_mean_squared_error)
# 	6.25s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 159.88s of the 259.6s of remaining time.
# 	-103.4023	 = Validation score   (-root_mean_squared_error)
# 	4.1s	 = Training   runtime
# 	3.15s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 149.74s of the 249.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-109.0813	 = Validation score   (-root_mean_squared_error)
# 	120.12s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 22.07s of the 121.79s of remaining time.
# 	-107.0995	 = Validation score   (-root_mean_squared_error)
# 	1.46s	 = Training   runtime
# 	2.86s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 15.67s of the 115.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-113.7552	 = Validation score   (-root_mean_squared_error)
# 	16.22s	 = Training   runtime
# 	1.34s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 299.01s of the 91.6s of remaining time.
# 	-102.5154	 = Validation score   (-root_mean_squared_error)
# 	1.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 90.4s of the 90.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-101.6474	 = Validation score   (-root_mean_squared_error)
# 	6.19s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 78.17s of the 78.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-101.3927	 = Validation score   (-root_mean_squared_error)
# 	2.59s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 69.96s of the 69.94s of remaining time.
# 	-103.0033	 = Validation score   (-root_mean_squared_error)
# 	11.4s	 = Training   runtime
# 	3.61s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 52.36s of the 52.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-101.4827	 = Validation score   (-root_mean_squared_error)
# 	12.11s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 33.79s of the 33.77s of remaining time.
# 	-101.0167	 = Validation score   (-root_mean_squared_error)
# 	2.21s	 = Training   runtime
# 	3.25s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 25.56s of the 25.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-101.9742	 = Validation score   (-root_mean_squared_error)
# 	22.95s	 = Training   runtime
# 	1.34s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 299.01s of the -3.02s of remaining time.
# 	-100.0493	 = Validation score   (-root_mean_squared_error)
# 	0.85s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 304.36s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutoGluonModels_exercise/")

# %%
predictor.leaderboard(val, extra_info=False, silent=True)
# Out:
#                      model  score_test   score_val  pred_time_test  \
# 0      WeightedEnsemble_L3  -93.677852 -100.049317       24.334713
# 1   NeuralNetFastAI_BAG_L2  -93.856195 -101.974191       22.131018
# 2        LightGBMXT_BAG_L2  -93.910921 -101.647383       16.617862
# 3          LightGBM_BAG_L2  -94.448083 -101.392730       16.259925
# 4          CatBoost_BAG_L2  -94.584190 -101.482698       16.472789
# 5     ExtraTreesMSE_BAG_L2  -94.958373 -101.016701       17.526253
# 6      WeightedEnsemble_L2  -95.285548 -102.515432        5.587272
# 7   RandomForestMSE_BAG_L2  -95.647679 -103.003301       17.543985
# 8   RandomForestMSE_BAG_L1  -95.655382 -103.402255        1.526633
# 9     ExtraTreesMSE_BAG_L1 -100.731435 -107.099531        1.551129
# 10         LightGBM_BAG_L1 -100.942517 -109.045332        0.737674
# 11         CatBoost_BAG_L1 -102.611050 -109.081324        1.763631
# 12       LightGBMXT_BAG_L1 -103.310679 -110.570348        2.932470
# 13  NeuralNetFastAI_BAG_L1 -106.361383 -113.755181        6.934087
# 14   KNeighborsUnif_BAG_L1 -118.706751 -123.040669        0.279956
# 15   KNeighborsDist_BAG_L1 -133.550926 -135.776499        0.344213
#
#     pred_time_val    fit_time  pred_time_test_marginal  \
# 0       16.368551  191.520031                 0.009035
# 1       12.526481  179.675219                 6.061224
# 2       11.609477  162.919681                 0.548069
# 3       11.360376  159.320507                 0.190131
# 4       11.460613  168.836469                 0.402996
# 5       14.439605  158.932750                 1.456460
# 6        7.387640  132.972328                 0.008204
# 7       14.796955  168.121637                 1.474191
# 8        3.147031    4.095523                 1.526633
# 9        2.856326    1.456186                 1.551129
# 10       0.643289    6.248527                 0.737674
# 11       0.739224  120.121440                 1.763631
# 12       1.244663    8.092841                 2.932470
# 13       1.335695   16.222969                 6.934087
# 14       0.591778    0.252955                 0.279956
# 15       0.631822    0.235970                 0.344213
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.002093           0.851107            3       True
# 1                 1.336654          22.948808            2       True
# 2                 0.419650           6.193270            2       True
# 3                 0.170549           2.594096            2       True
# 4                 0.270786          12.110058            2       True
# 5                 3.249778           2.206339            2       True
# 6                 0.001771           1.050652            2       True
# 7                 3.607128          11.395226            2       True
# 8                 3.147031           4.095523            1       True
# 9                 2.856326           1.456186            1       True
# 10                0.643289           6.248527            1       True
# 11                0.739224         120.121440            1       True
# 12                1.244663           8.092841            1       True
# 13                1.335695          16.222969            1       True
# 14                0.591778           0.252955            1       True
# 15                0.631822           0.235970            1       True
#
#     fit_order
# 0          16
# 1          15
# 2          10
# 3          11
# 4          13
# 5          14
# 6           9
# 7          12
# 8           5
# 9           7
# 10          4
# 11          6
# 12          3
# 13          8
# 14          1
# 15          2

# %%
# TODO: Make predictions on the test set
predictions = predictor.predict(test)
predictions.head()
# Out:
# 0     6.740745
# 1    44.015724
# 2    19.614748
# 3    14.127172
# 4    19.046211
# Name: target, dtype: float32

# %% [markdown]
# ## Hyperparameter Tuning

# %%
predictor_hpt = TabularPredictor(label=LABEL, problem_type=PROBLEM_TYPE, path=SAVE_PATH + "_hpt", eval_metric=EVAL_METRIC).fit(
    train, presets=['best_quality'], time_limit=300, hyperparameters={
        'RF': [{'max_depth': 6}],
        'GBM': [{'max_depth': 6}],
        'XGB': [{'max_depth': 12}]
})
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutoGluonModels_exercise_hpt"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 300s
# AutoGluon will save models to "AutoGluonModels_exercise_hpt/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    75483
# Train Data Columns: 9
# Label Column: target
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    250438.79 MB
# 	Train Data (Original)  Memory Usage: 45.37 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Unused Original Features (Count: 1): ['ID']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['ID']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('object', [])                     : 6 | ['FLTID', 'DEPSTN', 'ARRSTN', 'STA', 'STATUS', ...]
# 		('object', ['datetime_as_object']) : 2 | ['DATOP', 'STD']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             :  6 | ['FLTID', 'DEPSTN', 'ARRSTN', 'STA', 'STATUS', ...]
# 		('int', ['datetime_as_int']) : 10 | ['DATOP', 'DATOP.year', 'DATOP.month', 'DATOP.day', 'DATOP.dayofweek', ...]
# 	0.9s = Fit runtime
# 	8 features in original data used to generate 16 features in processed data.
# 	Train Data (Processed) Memory Usage: 6.65 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.92s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 3 L1 models ...
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 199.34s of the 299.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-109.8402	 = Validation score   (-root_mean_squared_error)
# 	3.91s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: RandomForest_BAG_L1 ... Training model for up to 189.16s of the 288.9s of remaining time.
# 	-115.4676	 = Validation score   (-root_mean_squared_error)
# 	1.34s	 = Training   runtime
# 	1.27s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 186.24s of the 285.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-112.1701	 = Validation score   (-root_mean_squared_error)
# 	3.59s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 176.96s of the 276.71s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-108.666	 = Validation score   (-root_mean_squared_error)
# 	9.64s	 = Training   runtime
# 	1.58s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 165.61s of the 265.35s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-111.5041	 = Validation score   (-root_mean_squared_error)
# 	7.01s	 = Training   runtime
# 	0.96s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 156.67s of the 256.41s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-108.0708	 = Validation score   (-root_mean_squared_error)
# 	19.42s	 = Training   runtime
# 	2.81s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 140.83s of the 240.58s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-111.0847	 = Validation score   (-root_mean_squared_error)
# 	10.32s	 = Training   runtime
# 	1.43s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 126.81s of the 226.56s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-107.7361	 = Validation score   (-root_mean_squared_error)
# 	27.96s	 = Training   runtime
# 	4.05s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 110.22s of the 209.97s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-110.9715	 = Validation score   (-root_mean_squared_error)
# 	13.34s	 = Training   runtime
# 	1.91s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 101.45s of the 201.19s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-108.0976	 = Validation score   (-root_mean_squared_error)
# 	136.04s	 = Training   runtime
# 	4.43s	 = Validation runtime
# Completed 5/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 299.08s of the 87.53s of remaining time.
# 	-108.0976	 = Validation score   (-root_mean_squared_error)
# 	0.5s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 3 L2 models ...
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 86.87s of the 86.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-108.9128	 = Validation score   (-root_mean_squared_error)
# 	4.67s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: RandomForest_BAG_L2 ... Training model for up to 73.96s of the 73.95s of remaining time.
# 	-107.5566	 = Validation score   (-root_mean_squared_error)
# 	2.01s	 = Training   runtime
# 	1.3s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 70.33s of the 70.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-109.0382	 = Validation score   (-root_mean_squared_error)
# 	2.85s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 61.46s of the 61.45s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-108.5605	 = Validation score   (-root_mean_squared_error)
# 	7.66s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 52.65s of the 52.64s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-108.4643	 = Validation score   (-root_mean_squared_error)
# 	5.51s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 44.11s of the 44.09s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-108.3976	 = Validation score   (-root_mean_squared_error)
# 	10.36s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 35.59s of the 35.58s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-108.0789	 = Validation score   (-root_mean_squared_error)
# 	8.3s	 = Training   runtime
# 	1.31s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 26.77s of the 26.76s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-108.2705	 = Validation score   (-root_mean_squared_error)
# 	13.77s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 17.16s of the 17.14s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-107.9696	 = Validation score   (-root_mean_squared_error)
# 	11.02s	 = Training   runtime
# 	1.76s	 = Validation runtime
# Completed 4/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 299.08s of the 7.52s of remaining time.
# 	-106.7466	 = Validation score   (-root_mean_squared_error)
# 	0.58s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 293.48s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutoGluonModels_exercise_hpt/")

# %%
predictor_hpt.leaderboard(val, extra_info=False, silent=True)
# Out:
#                  model  score_test   score_val  pred_time_test  pred_time_val  \
# 0  WeightedEnsemble_L3 -100.489179 -106.746614       11.231981       8.776819
# 1  RandomForest_BAG_L2 -100.703767 -107.556599        5.450180       7.013753
# 2      LightGBM_BAG_L1 -101.363407 -108.097569        5.172319       4.434872
# 3  WeightedEnsemble_L2 -101.363407 -108.097569        5.176995       4.436493
# 4      LightGBM_BAG_L2 -101.701182 -108.270524        6.354372       6.473211
# 5       XGBoost_BAG_L2 -102.258540 -107.969565       11.089925       7.470561
# 6       XGBoost_BAG_L1 -104.236993 -110.971540        5.884815       1.907619
# 7  RandomForest_BAG_L1 -108.489866 -115.467637        0.142697       1.274214
#
#      fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0  150.994469                 0.006892                0.001591
# 1  139.392403                 0.135164                1.304668
# 2  136.043010                 5.172319                4.434872
# 3  136.539467                 0.004677                0.001621
# 4  151.149653                 1.039356                0.764125
# 5  148.399947                 5.774909                1.761476
# 6   13.338402                 5.884815                1.907619
# 7    1.339036                 0.142697                1.274214
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           0.584164            3       True          8
# 1           2.010358            2       True          6
# 2         136.043010            1       True          1
# 3           0.496458            2       True          4
# 4          13.767608            2       True          5
# 5          11.017902            2       True          7
# 6          13.338402            1       True          3
# 7           1.339036            1       True          2

# %%
predictions = predictor.predict(test)
predictions.head()
# Out:
# 0     6.740745
# 1    44.015724
# 2    19.614748
# 3    14.127172
# 4    19.046211
# Name: target, dtype: float32

# %% [markdown]
# ## Submission

# %%
# submission = TabularDataset("data/SampleSubmission.csv")
submission = TabularDataset("SampleSubmission_zindi.csv")
submission.head()
# Out:
# Loaded data from: SampleSubmission_zindi.csv | Columns = 2 / 2 | Rows = 9333 -> 9333
#           ID  target
# 0  test_id_0    2470
# 1  test_id_1    2944
# 2  test_id_2    2585
# 3  test_id_3    3264
# 4  test_id_4    1369

# %%
submission["target"] = predictions

# %%
# submission.to_csv("data/submssion.csv", index=False)
submission.to_csv("submssion_zindi.csv", index=False)
