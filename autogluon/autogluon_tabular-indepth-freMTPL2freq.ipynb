# %% [markdown]
# https://auto.gluon.ai/0.1.0/tutorials/tabular_prediction/tabular-indepth.html
#
# # Predicting Columns in a Table - In Depth: freMTPL2freq (regression)
#
# Tip: If you are new to AutoGluon, review "Predicting Columns in a Table - Quick Start" to learn the basics of the AutoGluon API.
#
# https://auto.gluon.ai/0.1.0/tutorials/tabular_prediction/tabular-quickstart.html#sec-tabularquick
#
# This tutorial describes how you can exert greater control when using AutoGluon’s `fit()` or `predict()`. Recall that to maximize predictive performance, you should always first try `fit()` with all default arguments except `eval_metric` and `presets`, before you experiment with other arguments covered in this in-depth tutorial like `hyperparameter_tune_kwargs`, `hyperparameters`, `num_stack_levels`, `num_bag_folds`, `num_bag_sets`, etc.
#
# Using the same census data table as in the "Predicting Columns in a Table - Quick Start" tutorial, we’ll now predict the occupation of an individual - a multiclass classification problem. Start by importing AutoGluon’s `TabularPredictor` and `TabularDataset`, and loading the data.

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

import pandas as pd
import numpy as np

# %%
# train_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/train.csv')
train_data = TabularDataset("freMTPL2freq_dataset_train.csv")
test_data = TabularDataset("freMTPL2freq_dataset_test.csv")
# subsample_size = 500  # subsample subset of data for faster demo, try setting this to much larger values
# train_data = train_data.sample(n=subsample_size, random_state=0)

# %%
train_data.info()
# Out:
# <class 'autogluon.core.dataset.TabularDataset'>
# RangeIndex: 474765 entries, 0 to 474764
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   IDpol       474765 non-null  int64
#  1   ClaimNb     474765 non-null  int64
#  2   Exposure    474765 non-null  float64
#  3   VehPower    474765 non-null  int64
#  4   VehAge      474765 non-null  int64
#  5   DrivAge     474765 non-null  int64
#  6   BonusMalus  474765 non-null  int64
#  7   VehBrand    474765 non-null  object
#  8   VehGas      474765 non-null  object
#  9   Area        474765 non-null  object
#  10  Density     474765 non-null  int64
#  11  Region      474765 non-null  object
# dtypes: float64(1), int64(7), object(4)
# memory usage: 43.5+ MB

# %%
test_data.info()
# Out:
# <class 'autogluon.core.dataset.TabularDataset'>
# RangeIndex: 203226 entries, 0 to 203225
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   IDpol       203226 non-null  float64
#  1   ClaimNb     203226 non-null  int64
#  2   Exposure    203226 non-null  float64
#  3   VehPower    203226 non-null  int64
#  4   VehAge      203226 non-null  int64
#  5   DrivAge     203226 non-null  int64
#  6   BonusMalus  203226 non-null  int64
#  7   VehBrand    203226 non-null  object
#  8   VehGas      203226 non-null  object
#  9   Area        203226 non-null  object
#  10  Density     203226 non-null  int64
#  11  Region      203226 non-null  object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 18.6+ MB

# %%
train_data.head().T

# %%
label = 'ClaimNb'
print("Summary of target column: \n", train_data[label].describe())
# Out:
# Summary of target column:
#  count    474765.000000
# mean          0.038583
# std           0.205458
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          11.000000
# Name: ClaimNb, dtype: float64

# %% [markdown]
# ## Data Cleaning

# %%
# IDpol: The policy ID, so drop it
train_data = train_data.drop(["IDpol"], axis=1)
test_data = test_data.drop(["IDpol"], axis=1)

# %%
train_data.shape
# Out:
# (474765, 11)

# %%
test_data.shape
# Out:
# (203226, 11)

# %%
# new_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv')
# test_data = new_data[5000:].copy()  # this should be separate data in your applications
y_test = test_data[label]
test_data_nolabel = test_data.drop(columns=[label])  # delete label column
# val_data = new_data[:5000].copy()

# metric = 'accuracy' # we specify eval-metric just for demo (unnecessary as it's the default)
metric = 'mean_absolute_error'

# %% [markdown]
# ## Specifying hyperparameters and tuning them
#
# We first demonstrate hyperparameter-tuning and how you can provide your own validation dataset that AutoGluon internally relies on to: tune hyperparameters, early-stop iterative training, and construct model ensembles. One reason you may specify validation data is when future test data will stem from a different distribution than training data (and your specified validation data is more representative of the future data that will likely be encountered).
#
# If you don’t have a strong reason to provide your own validation dataset, we recommend you omit the `tuning_data` argument. This lets AutoGluon automatically select validation data from your provided training set (it uses smart strategies such as stratified sampling). For greater control, you can specify the `holdout_fra`c argument to tell AutoGluon what fraction of the provided training data to hold out for validation.
#
# **Caution:** Since AutoGluon tunes internal knobs based on this validation data, performance estimates reported on this data may be over-optimistic. For unbiased performance estimates, you should always call `predict()` on a separate dataset (that was never passed to `fit()`), as we did in the previous Quick-Start tutorial. We also emphasize that most options specified in this tutorial are chosen to minimize runtime for the purposes of demonstration and you should select more reasonable values in order to obtain high-quality models.
#
# `fit()` trains neural networks and various types of tree ensembles by default. You can specify various hyperparameter values for each type of model. For each hyperparameter, you can either specify a single fixed value, or a search space of values to consider during hyperparameter optimization. Hyperparameters which you do not specify are left at default settings chosen automatically by AutoGluon, which may be fixed values or search spaces.

# %%
import autogluon.core as ag

# %%
# specifies non-default hyperparameter values for neural network models
#    num_epochs: number of training epochs (controls training time of NN models)
#    learning_rate: learning rate used in training (real-valued hyperparameter searched on log-scale)
#    activation: activation function used in NN (categorical hyperparameter, default = first entry)
#    layers: each choice for categorical hyperparameter 'layers' corresponds to list of sizes for each NN layer to use
#    dropout_prob: dropout probability (real-valued hyperparameter)
nn_options = {
    'num_epochs': 10,
    'learning_rate': ag.space.Real(1e-4, 1e-2, default=5e-4, log=True),
    'activation': ag.space.Categorical('relu', 'softrelu', 'tanh'),
    'layers': ag.space.Categorical([100], [1000], [200, 100], [300, 200, 100]),
    'dropout_prob': ag.space.Real(0.0, 0.5, default=0.1)
}

nn_options
# Out:
# {'num_epochs': 10,
#  'learning_rate': Real: lower=0.0001, upper=0.01,
#  'activation': Categorical['relu', 'softrelu', 'tanh'],
#  'layers': Categorical[[100], [1000], [200, 100], [300, 200, 100]],
#  'dropout_prob': Real: lower=0.0, upper=0.5}

# %%
# specifies non-default hyperparameter values for lightGBM gradient boosted trees
#    num_boost_round: number of boosting rounds (controls training time of GBM models)
#    num_leaves: number of leaves in trees (integer hyperparameter)
gbm_options = {  
    'num_boost_round': 100,
    'num_leaves': ag.space.Int(lower=26, upper=66, default=36)
}

gbm_options
# Out:
# {'num_boost_round': 100, 'num_leaves': Int: lower=26, upper=66}

# %%
# hyperparameters of each model type
# When these keys are missing from hyperparameters dict, no models of that type are trained
#    NN: NOTE: comment this line out if you get errors on Mac OSX
hyperparameters = {  
    'GBM': gbm_options,
    'NN': nn_options
}

hyperparameters
# Out:
# {'GBM': {'num_boost_round': 100, 'num_leaves': Int: lower=26, upper=66},
#  'NN': {'num_epochs': 10,
#   'learning_rate': Real: lower=0.0001, upper=0.01,
#   'activation': Categorical['relu', 'softrelu', 'tanh'],
#   'layers': Categorical[[100], [1000], [200, 100], [300, 200, 100]],
#   'dropout_prob': Real: lower=0.0, upper=0.5}}

# %%
# train various models for ~2 min
# time_limit = 2*60

# https://www.kaggle.com/code/daikikatsuragawa/tps-mar-2021-benchmark-using-autogluon/notebook
# If the value of time_limit is too small, we will get the following error:
# ValueError: AutoGluon did not successfully train any models

# increased time_limit to 1 hour
time_limit = 60*60
time_limit
# Out:
# 3600

# %%
# try at most 5 different hyperparameter configurations for each type of model
num_trials = 5
num_trials
# Out:
# 5

# %%
# to tune hyperparameters using Bayesian optimization routine with a local scheduler
search_strategy = 'auto'
search_strategy
# Out:
# 'auto'

# %%
# HPO is not performed unless hyperparameter_tune_kwargs is specified
hyperparameter_tune_kwargs = {
    'num_trials': num_trials,
    'searcher': search_strategy
}

hyperparameter_tune_kwargs
# Out:
# {'num_trials': 5, 'searcher': 'auto'}

# %%
label
# Out:
# 'ClaimNb'

# %%
metric
# Out:
# 'mean_absolute_error'

# %%
# NEED TO DEBUG
"""
predictor = TabularPredictor(label=label, eval_metric=metric).fit(
    train_data,
    tuning_data=val_data,
    time_limit=time_limit,
    hyperparameters=hyperparameters,
    hyperparameter_tune_kwargs=hyperparameter_tune_kwargs
)
"""
# Out:
# '\npredictor = TabularPredictor(label=label, eval_metric=metric).fit(\n    train_data,\n    tuning_data=val_data,\n    time_limit=time_limit,\n    hyperparameters=hyperparameters,\n    hyperparameter_tune_kwargs=hyperparameter_tune_kwargs\n)\n'

# %%
# specified problem_type to eliminate infering multi-class problem_type, e.g.,
#   problem_type="regression"

predictor = TabularPredictor(
    label=label, 
    eval_metric=metric,
    problem_type="regression"
).fit(
    train_data,
    time_limit=time_limit
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230702_210555/"
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230702_210555/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    167728.76 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.3s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.42s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.01, Train Rows: 470017, Val Rows: 4748
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ... Training model for up to 3598.57s of the 3598.57s of remaining time.
# 	-0.0769	 = Validation score   (-mean_absolute_error)
# 	3.57s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 3594.57s of the 3594.57s of remaining time.
# 	-0.0764	 = Validation score   (-mean_absolute_error)
# 	1.0s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 3593.18s of the 3593.18s of remaining time.
# 	-0.0752	 = Validation score   (-mean_absolute_error)
# 	5.84s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3587.19s of the 3587.19s of remaining time.
# 	-0.0745	 = Validation score   (-mean_absolute_error)
# 	2.77s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestMSE ... Training model for up to 3584.28s of the 3584.28s of remaining time.
# 	-0.0803	 = Validation score   (-mean_absolute_error)
# 	14.57s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 3567.73s of the 3567.73s of remaining time.
# 	-0.0748	 = Validation score   (-mean_absolute_error)
# 	44.67s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE ... Training model for up to 3522.93s of the 3522.93s of remaining time.
# 	-0.0783	 = Validation score   (-mean_absolute_error)
# 	5.75s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 3515.16s of the 3515.15s of remaining time.
# No improvement since epoch 8: early stopping
# 	-0.0703	 = Validation score   (-mean_absolute_error)
# 	316.25s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 3198.53s of the 3198.53s of remaining time.
# 	-0.0747	 = Validation score   (-mean_absolute_error)
# 	3.8s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 3194.6s of the 3194.6s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	376.39s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 2818.08s of the 2818.08s of remaining time.
# 	-0.0746	 = Validation score   (-mean_absolute_error)
# 	3.57s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2814.32s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	0.36s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 786.62s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230702_210555/")

# %% [markdown]
# We again demonstrate how to use the trained models to predict on the test data.

# %%
y_pred = predictor.predict(test_data_nolabel)

# %%
# print("Predictions:  ", list(y_pred)[:5])
print("Predictions:\n", y_pred[:5])
# Out:
# Predictions:
#  0    8.739490e-15
# 1    4.045679e-15
# 2    4.697084e-14
# 3    2.464720e-15
# 4    5.489513e-09
# Name: ClaimNb, dtype: float32

# %%
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=False)
# Out:
# Evaluation: mean_absolute_error on test data: -0.039985119318079465
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.039985119318079465
# }

# %% [markdown]
# Use the following to view a summary of what happened during fit. Now this command will show details of the hyperparameter-tuning process for each type of model:

# %%
results = predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0        NeuralNetTorch  -0.042334       0.034553  376.387879                0.034553         376.387879            1       True         10
# 1   WeightedEnsemble_L2  -0.042334       0.035145  376.750426                0.000593           0.362546            2       True         12
# 2       NeuralNetFastAI  -0.070266       0.048698  316.246186                0.048698         316.246186            1       True          8
# 3              LightGBM  -0.074476       0.015795    2.769888                0.015795           2.769888            1       True          4
# 4         LightGBMLarge  -0.074557       0.007816    3.565485                0.007816           3.565485            1       True         11
# 5               XGBoost  -0.074668       0.022556    3.800750                0.022556           3.800750            1       True          9
# 6              CatBoost  -0.074781       0.013486   44.670350                0.013486          44.670350            1       True          6
# 7            LightGBMXT  -0.075217       0.014311    5.837898                0.014311           5.837898            1       True          3
# 8        KNeighborsDist  -0.076406       0.138187    1.000785                0.138187           1.000785            1       True          2
# 9        KNeighborsUnif  -0.076874       0.163981    3.571141                0.163981           3.571141            1       True          1
# 10        ExtraTreesMSE  -0.078331       0.197951    5.748578                0.197951           5.748578            1       True          7
# 11      RandomForestMSE  -0.080284       0.161480   14.565583                0.161480          14.565583            1       True          5
# Number of models trained: 12
# Types of models trained:
# {'WeightedEnsembleModel', 'LGBModel', 'XGBoostModel', 'XTModel', 'TabularNeuralNetTorchModel', 'NNFastAiTabularModel', 'CatBoostModel', 'RFModel', 'KNNModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# ('float', [])     : 1 | ['Exposure']
# ('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# ('int', ['bool']) : 1 | ['VehGas']
# Plot summary of models saved to file: AutogluonModels/ag-20230702_210555/SummaryOfModels.html
# *** End of fit() summary ***

# %% [markdown]
# In the above example, the predictive performance may be poor because we specified very little training to ensure quick runtimes. You can call `fit()` multiple times while modifying the above settings to better understand how these choices affect performance outcomes. For example: you can comment out the `train_data.head` command or increase `subsample_size` to train using a larger dataset, increase the `num_epochs` and `num_boost_round` hyperparameters, and increase the `time_limit` (which you should do for all code in these tutorials). To see more detailed output during the execution of `fit()`, you can also pass in the argument: `verbosity=3`.

# %% [markdown]
# ## Model ensembling with stacking/bagging
#
# Beyond hyperparameter-tuning with a correctly-specified evaluation metric, two other methods to boost predictive performance are bagging and stack-ensembling:
#
# "AutoGluon-Tabular: Robust and Accurate AutoML for Structured Data": https://arxiv.org/abs/2003.06505
#
# You’ll often see performance improve if you specify `num_bag_folds = 5-10, num_stack_levels = 1-3` in the call to `fit()`, but this will increase training times and memory/disk usage.

# %%
# last  argument is just for quick demo here, omit it in real applications
predictor = TabularPredictor(
    label=label, 
    eval_metric=metric,
    problem_type="regression"
).fit(
    train_data,
    num_bag_folds=5, num_bag_sets=1, num_stack_levels=1,
    # num_bag_folds=5, num_bag_sets=1, num_stack_levels=3,                                                              
    # hyperparameters = {'NN': {'num_epochs': 2}, 'GBM': {'num_boost_round': 20}},  
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230702_211907/"
# Warning: Training may take a very long time because `time_limit` was not specified and `train_data` is large (474765 samples, 144.87 MB).
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20230702_211907/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    161883.65 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.3s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.37s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-0.0719	 = Validation score   (-mean_absolute_error)
# 	0.61s	 = Training   runtime
# 	8.6s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	0.65s	 = Training   runtime
# 	13.93s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.072	 = Validation score   (-mean_absolute_error)
# 	6.61s	 = Training   runtime
# 	1.56s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0715	 = Validation score   (-mean_absolute_error)
# 	8.61s	 = Training   runtime
# 	3.75s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-0.0766	 = Validation score   (-mean_absolute_error)
# 	13.94s	 = Training   runtime
# 	12.11s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0716	 = Validation score   (-mean_absolute_error)
# 	143.48s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-0.0745	 = Validation score   (-mean_absolute_error)
# 	5.6s	 = Training   runtime
# 	11.42s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0647	 = Validation score   (-mean_absolute_error)
# 	301.98s	 = Training   runtime
# 	3.78s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0716	 = Validation score   (-mean_absolute_error)
# 	8.7s	 = Training   runtime
# 	1.95s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	365.41s	 = Training   runtime
# 	1.9s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0716	 = Validation score   (-mean_absolute_error)
# 	7.21s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	6.81s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0711	 = Validation score   (-mean_absolute_error)
# 	15.77s	 = Training   runtime
# 	3.42s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0711	 = Validation score   (-mean_absolute_error)
# 	6.84s	 = Training   runtime
# 	0.85s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ...
# 	-0.0796	 = Validation score   (-mean_absolute_error)
# 	108.32s	 = Training   runtime
# 	20.12s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0711	 = Validation score   (-mean_absolute_error)
# 	107.6s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ...
# 	-0.0759	 = Validation score   (-mean_absolute_error)
# 	14.39s	 = Training   runtime
# 	15.18s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0655	 = Validation score   (-mean_absolute_error)
# 	301.32s	 = Training   runtime
# 	3.86s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	10.74s	 = Training   runtime
# 	2.16s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	646.25s	 = Training   runtime
# 	3.16s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ...
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	9.61s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	5.35s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 2287.67s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230702_211907/")

# %% [markdown]
# You should not provide `tuning_data` when stacking/bagging, and instead provide all your available data as `train_data` (which AutoGluon will split in more intellgent ways). `num_bag_sets` controls how many times the k-fold bagging process is repeated to further reduce variance (increasing this may further boost accuracy but will substantially increase training times, inference latency, and memory/disk usage). Rather than manually searching for good bagging/stacking values yourself, AutoGluon will automatically select good values for you if you specify `auto_stack` instead:

# %%
save_path = 'agModels-predict_freMTPL2freq_2'  # folder where to store trained models

# last 2 arguments are for quick demo, omit them in real applications
predictor = TabularPredictor(
    label=label, 
    eval_metric=metric, 
    path=save_path,
    problem_type="regression"
).fit(
    train_data, 
    auto_stack=True,
    time_limit=30, 
    hyperparameters={'NN': {'num_epochs': 2}, 'GBM': {'num_boost_round': 20}} 
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predict_freMTPL2freq_2"
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 30s
# AutoGluon will save models to "agModels-predict_freMTPL2freq_2/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    160034.71 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.4s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.47s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# 	WARNING: "NN" model has been deprecated in v0.4.0 and renamed to "NN_MXNET". Starting in v0.6.0, specifying "NN" or "NN_MXNET" will raise an exception. Consider instead specifying "NN_TORCH".
# Fitting 2 L1 models ...
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 19.01s of the 28.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	2.24s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 11.33s of the 20.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetMXNet_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=30724, ip=10.164.150.180)
# ModuleNotFoundError: No module named 'mxnet'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=30724, ip=10.164.150.180)
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 374, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold,
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 703, in fit
#     out = self._fit(**kwargs)
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/models/tabular_nn/mxnet/tabular_nn_mxnet.py", line 135, in _fit
#     try_import_mxnet()
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/utils/try_import.py", line 49, in try_import_mxnet
#     raise ImportError(
# ImportError: Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 28.53s of the 15.41s of remaining time.
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# 	WARNING: "NN" model has been deprecated in v0.4.0 and renamed to "NN_MXNET". Starting in v0.6.0, specifying "NN" or "NN_MXNET" will raise an exception. Consider instead specifying "NN_TORCH".
# Fitting 2 L2 models ...
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 15.22s of the 15.18s of remaining time.
# 2023-07-02 21:57:31,125	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-02 21:57:31,126	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-02 21:57:31,127	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-02 21:57:31,132	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-02 21:57:31,133	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-07-02 21:57:31,134	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-02 21:57:31,136	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	2.25s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L2 ... Training model for up to 7.33s of the 7.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetMXNet_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=34392, ip=10.164.150.180)
# ModuleNotFoundError: No module named 'mxnet'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=34392, ip=10.164.150.180)
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 374, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold,
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 703, in fit
#     out = self._fit(**kwargs)
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/models/tabular_nn/mxnet/tabular_nn_mxnet.py", line 135, in _fit
#     try_import_mxnet()
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/utils/try_import.py", line 49, in try_import_mxnet
#     raise ImportError(
# ImportError: Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 28.53s of the 1.88s of remaining time.
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 28.65s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predict_freMTPL2freq_2/")

# %% [markdown]
# Often stacking/bagging will produce superior accuracy than hyperparameter-tuning, but you may try combining both techniques (note: specifying `presets='best_quality'` in `fit()` simply sets `auto_stack=True`).

# %% [markdown]
# ## Prediction options (inference)
#
# Even if you’ve started a new Python session since last calling `fit()`, you can still load a previously trained predictor from disk:
#
# ```
# # `predictor.path` is another way to get the relative path needed to later load predictor.
# predictor = TabularPredictor.load(save_path)
# ```
#
# Above `save_path` is the same folder previously passed to `TabularPredictor`, in which all the trained models have been saved. You can train easily models on one machine and deploy them on another. Simply copy the `save_path` folder to the new machine and specify its new path in `TabularPredictor.load()`.
#
# We can make a prediction on an individual example rather than a full dataset:

# %%
datapoint = test_data_nolabel.iloc[[0]]  # Note: .iloc[0] won't work because it returns pandas Series instead of DataFrame

print(datapoint)
predictor.predict(datapoint)
# Out:
# 2023-07-02 21:57:44,621	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-02 21:57:44,622	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-02 21:57:44,627	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-02 21:57:44,628	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-02 21:57:44,629	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-02 21:57:44,629	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-02 21:57:44,631	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
#    Exposure  VehPower  VehAge  DrivAge  BonusMalus VehBrand   VehGas Area  \
# 0       0.1         5       0       55          50      B12  Regular    D
#
#    Density       Region
# 0     1217  Rhone-Alpes
# 0    0.021197
# Name: ClaimNb, dtype: float32

# %% [markdown]
# To output predicted class probabilities instead of predicted classes, you can use:

# %%
predictor.predict_proba(datapoint)  # returns a DataFrame that shows which probability corresponds to which class
# Out:
# /home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/predictor/predictor.py:1420: FutureWarning: Calling `predictor.predict_proba` when problem_type=regression will raise an AssertionError starting in AutoGluon v0.8. Please call `predictor.predict` instead.
#   warnings.warn(
# 0    0.021197
# Name: ClaimNb, dtype: float32

# %% [markdown]
# By default, `predict()` and `predict_proba()` will utilize the model that AutoGluon thinks is most accurate, which is usually an ensemble of many individual models. Here’s how to see which model this is:

# %%
predictor.get_model_best()
# Out:
# 'WeightedEnsemble_L3'

# %% [markdown]
# We can instead specify a particular model to use for predictions (e.g. to reduce inference latency). Note that a ‘model’ in AutoGluon may refer to for example a single Neural Network, a bagged ensemble of many Neural Network copies trained on different training/validation splits, a weighted ensemble that aggregates the predictions of many other models, or a stacker model that operates on predictions output by other models. This is akin to viewing a Random Forest as one ‘model’ when it is in fact an ensemble of many decision trees.
#
# Before deciding which model to use, let’s evaluate all of the models AutoGluon has previously trained on our test data:

# %%
# predictor.leaderboard(test_data, silent=True)
predictor.leaderboard(test_data, silent=True).T
# Out:
#                                        0                    1  \
# model                    LightGBM_BAG_L2  WeightedEnsemble_L3
# score_test                     -0.073829            -0.073829
# score_val                      -0.072728            -0.072728
# pred_time_test                  0.606435             0.610742
# pred_time_val                   0.401058             0.408151
# fit_time                        4.485044             4.496381
# pred_time_test_marginal         0.325177             0.004307
# pred_time_val_marginal          0.197298             0.007093
# fit_time_marginal               2.247972             0.011337
# stack_level                            2                    3
# can_infer                           True                 True
# fit_order                              3                    4
#
#                                        2                    3
# model                    LightGBM_BAG_L1  WeightedEnsemble_L2
# score_test                     -0.073983            -0.073983
# score_val                      -0.072862            -0.072862
# pred_time_test                  0.281258             0.287324
# pred_time_val                    0.20376             0.210497
# fit_time                        2.237072             2.248087
# pred_time_test_marginal         0.281258             0.006066
# pred_time_val_marginal           0.20376             0.006737
# fit_time_marginal               2.237072             0.011015
# stack_level                            1                    2
# can_infer                           True                 True
# fit_order                              1                    2

# %% [markdown]
# The leaderboard shows each model’s predictive performance on the test data (`score_test`) and validation data (`score_val`), as well as the time required to: produce predictions for the test data (`pred_time_val`), produce predictions on the validation data (`pred_time_val`), and train only this model (`fit_time`). Below, we show that a leaderboard can be produced without new data (just uses the data previously reserved for validation inside `fit`) and can display extra information about each model:

# %%
# predictor.leaderboard(extra_info=True, silent=True)
predictor.leaderboard(extra_info=True, silent=True).T
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                          0  \
# model                                                                                                                                                                                                                                                                                                                                                                                                      LightGBM_BAG_L2
# score_val                                                                                                                                                                                                                                                                                                                                                                                                        -0.072728
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                     0.401058
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                          4.485044
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                            0.197298
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                 2.247972
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              2
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                3
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            11
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               8
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                  16
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                         518083
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                            1040886
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                      67638
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                          67961
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            1
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                  LGBModel
# hyperparameters                                                                                                                                                                                                                                                                                                  {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                       [VehBrand, DrivAge, BonusMalus, Region, VehPower, Density, Exposure, VehGas, Area, VehAge, LightGBM_BAG_L1]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                       {'learning_rate': 0.05, 'num_boost_round': 20}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                          {'num_boost_round': 20}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                [LightGBM_BAG_L1]
# descendants                                                                                                                                                                                                                                                                                                                                                                                          [WeightedEnsemble_L3]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                1  \
# model                                                                                                                                                                                                                                                                                                                                                                                        WeightedEnsemble_L3
# score_val                                                                                                                                                                                                                                                                                                                                                                                              -0.072728
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                           0.408151
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                4.496381
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                  0.007093
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                       0.011337
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                    3
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                   True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                      4
# num_features                                                                                                                                                                                                                                                                                                                                                                                                   1
# num_models                                                                                                                                                                                                                                                                                                                                                                                                     1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                        17
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                 2763
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                  1043649
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                             2763
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                67961
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                  2
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                0
# model_type                                                                                                                                                                                                                                                                                                                                                                                 WeightedEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                     GreedyWeightedEnsembleModel
# hyperparameters                                                                                                                                                                                                                                                                                       {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                           {}
# ag_args_fit                  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                                                                                       [LightGBM_BAG_L2]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                     {'ensemble_size': 100}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                   {'ensemble_size': 1}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# ancestors                                                                                                                                                                                                                                                                                                                                                                     [LightGBM_BAG_L2, LightGBM_BAG_L1]
# descendants                                                                                                                                                                                                                                                                                                                                                                                                   []
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          2  \
# model                                                                                                                                                                                                                                                                                                                                                                                                      LightGBM_BAG_L1
# score_val                                                                                                                                                                                                                                                                                                                                                                                                        -0.072862
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                      0.20376
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                          2.237072
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                             0.20376
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                 2.237072
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                1
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               8
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   8
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                         522803
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                             522803
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                      67961
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                          67961
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          3
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                  LGBModel
# hyperparameters                                                                                                                                                                                                                                                                                                  {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehBrand, DrivAge, BonusMalus, Region, VehPower, Density, Exposure, VehGas, Area, VehAge]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                       {'learning_rate': 0.05, 'num_boost_round': 20}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                          {'num_boost_round': 20}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                    [WeightedEnsemble_L2, LightGBM_BAG_L2, WeightedEnsemble_L3]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                3
# model                                                                                                                                                                                                                                                                                                                                                                                        WeightedEnsemble_L2
# score_val                                                                                                                                                                                                                                                                                                                                                                                              -0.072862
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                           0.210497
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                2.248087
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                  0.006737
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                       0.011015
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                    2
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                   True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                      2
# num_features                                                                                                                                                                                                                                                                                                                                                                                                   1
# num_models                                                                                                                                                                                                                                                                                                                                                                                                     1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                         9
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                 2763
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                   525566
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                             2763
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                67961
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                  1
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                0
# model_type                                                                                                                                                                                                                                                                                                                                                                                 WeightedEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                     GreedyWeightedEnsembleModel
# hyperparameters                                                                                                                                                                                                                                                                                       {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                           {}
# ag_args_fit                  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                                                                                       [LightGBM_BAG_L1]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                     {'ensemble_size': 100}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                   {'ensemble_size': 1}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                      [LightGBM_BAG_L1]
# descendants                                                                                                                                                                                                                                                                                                                                                                                                   []

# %% [markdown]
# The expanded leaderboard shows properties like how many features are used by each model (`num_features`), which other models are ancestors whose predictions are required inputs for each model (`ancestors`), and how much memory each model and all its ancestors would occupy if simultaneously persisted (`memory_size_w_ancestors`). See the leaderboard documentation for full details:
#
# https://auto.gluon.ai/0.1.0/api/autogluon.predictor.html#autogluon.tabular.TabularPredictor.leaderboard
#
# Here’s how to specify a particular model to use for prediction instead of AutoGluon’s default model-choice:

# %%
i = 0  # index of model to use
model_to_use = predictor.get_model_names()[i]
model_pred = predictor.predict(datapoint, model=model_to_use)
print("Prediction from %s model: %s" % (model_to_use, model_pred.iloc[0]))
# Out:
# Prediction from LightGBM_BAG_L1 model: 0.021949358

# %% [markdown]
# We can easily access various information about the trained predictor or a particular model:

# %%
all_models = predictor.get_model_names()
model_to_use = all_models[i]
specific_model = predictor._trainer.load_model(model_to_use)

# Objects defined below are dicts of various information (not printed here as they are quite large):
model_info = specific_model.get_info()
predictor_information = predictor.info()

# %% [markdown]
# The `predictor` also remembers what metric predictions should be evaluated with, which can be done with ground truth labels as follows:

# %%
y_pred = predictor.predict(test_data_nolabel)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: mean_absolute_error on test data: -0.07382930544418408
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.07382930544418408,
#     "root_mean_squared_error": -0.20785334362348507,
#     "mean_squared_error": -0.043203012455462556,
#     "r2": 0.030595522805380138,
#     "pearsonr": 0.19263159632652416,
#     "median_absolute_error": -0.03478221222758293
# }

# %% [markdown]
# However, you must be careful here as certain metrics require predicted probabilities rather than classes. Since the label columns remains in the `test_data` DataFrame, we can instead use the shorthand:

# %%
perf = predictor.evaluate(test_data)
# Out:
# /home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/predictor/predictor.py:1420: FutureWarning: Calling `predictor.predict_proba` when problem_type=regression will raise an AssertionError starting in AutoGluon v0.8. Please call `predictor.predict` instead.
#   warnings.warn(
# Evaluation: mean_absolute_error on test data: -0.07382930544418408
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.07382930544418408,
#     "root_mean_squared_error": -0.20785334362348507,
#     "mean_squared_error": -0.043203012455462556,
#     "r2": 0.030595522805380138,
#     "pearsonr": 0.19263159632652416,
#     "median_absolute_error": -0.03478221222758293
# }

# %% [markdown]
# which will correctly select between `predict()` or `predict_proba()` depending on the evaluation metric.

# %% [markdown]
# ## Interpretability (feature importance)
#
# To better understand our trained predictor, we can estimate the overall importance of each feature:

# %%
predictor.feature_importance(test_data)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	8.39s	= Expected runtime (1.68s per shuffle set)
# 	1.8s	= Actual runtime (Completed 5 of 5 shuffle sets)
#             importance    stddev   p_value  n  p99_high   p99_low
# BonusMalus    0.004605  0.000562  0.000026  5  0.005762  0.003449
# Exposure      0.002813  0.000644  0.000308  5  0.004138  0.001487
# DrivAge       0.000838  0.000132  0.000072  5  0.001110  0.000566
# VehAge        0.000185  0.000051  0.000642  5  0.000291  0.000079
# VehBrand      0.000174  0.000028  0.000075  5  0.000231  0.000117
# Region        0.000144  0.000071  0.005421  5  0.000290 -0.000003
# Density       0.000142  0.000047  0.001247  5  0.000238  0.000045
# VehGas        0.000044  0.000021  0.004603  5  0.000088  0.000001
# VehPower      0.000026  0.000009  0.001660  5  0.000046  0.000007
# Area         -0.000005  0.000008  0.864395  5  0.000012 -0.000022

# %% [markdown]
# Computed via permutation-shuffling, these feature importance scores quantify the drop in predictive performance (of the already trained predictor) when one column’s values are randomly shuffled across rows.
#
# https://explained.ai/rf-importance/
#
# The top features in this list contribute most to AutoGluon’s accuracy (for predicting when/if a patient will be readmitted to the hospital). Features with non-positive importance score hardly contribute to the predictor’s accuracy, or may even be actively harmful to include in the data (consider removing these features from your data and calling `fit` again). These scores facilitate interpretability of the predictor’s global behavior (which features it relies on for all predictions) rather than local explanations that only rationalize one particular prediction.
#
# https://christophm.github.io/interpretable-ml-book/taxonomy-of-interpretability-methods.html

# %% [markdown]
# ## Accelerating inference
#
# We describe multiple ways to reduce the time it takes for AutoGluon to produce predictions.

# %% [markdown]
# ### Keeping models in memory
#
# By default, AutoGluon loads models into memory one at a time and only when they are needed for prediction. This strategy is robust for large stacked/bagged ensembles, but leads to slower prediction times. If you plan to repeatedly make predictions (e.g. on new datapoints one at a time rather than one large test dataset), you can first specify that all models required for inference should be loaded into memory as follows:

# %%
predictor.persist_models()

num_test = 20
preds = np.array([''] * num_test, dtype='object')
for i in range(num_test):
    datapoint = test_data_nolabel.iloc[[i]]
    pred_numpy = predictor.predict(datapoint, as_pandas=False)
    preds[i] = pred_numpy[0]

perf = predictor.evaluate_predictions(y_test[:num_test], preds, auxiliary_metrics=True)
print("Predictions: ", preds)

predictor.unpersist_models()  # free memory by clearing models, future predict() calls will load models from disk
# Out:
# Persisting 3 models in memory. Models will require 0.0% of memory.
# /usr/local/lib/python3.9/site-packages/scipy/stats/stats.py:4023: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# Evaluation: mean_absolute_error on test data: -0.03614488542079926
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.03614488542079926,
#     "root_mean_squared_error": -0.04348980311031695,
#     "mean_squared_error": -0.0018913629745741342,
#     "r2": 0.0,
#     "pearsonr": NaN,
#     "median_absolute_error": -0.02470323257148266
# }
# Unpersisted 3 models: ['LightGBM_BAG_L2', 'WeightedEnsemble_L3', 'LightGBM_BAG_L1']
# Predictions:  [0.021197435 0.021197435 0.024703233 0.12624344 0.04158317 0.039908644
#  0.021197435 0.019564483 0.04604639 0.019564483 0.021087468 0.019564483
#  0.06287587 0.04638099 0.039490342 0.024703233 0.021197435 0.04662274
#  0.04020452 0.019564483]
# ['LightGBM_BAG_L2', 'WeightedEnsemble_L3', 'LightGBM_BAG_L1']

# %% [markdown]
# You can alternatively specify a particular model to persist via the models argument of `persist_models()`, or simply set `models='all'` to simultaneously load every single model that was trained during `fit`.

# %% [markdown]
# ## Using smaller ensemble or faster model for prediction
#
# Without having to retrain any models, one can construct alternative ensembles that aggregate individual models’ predictions with different weighting schemes. These ensembles become smaller (and hence faster for prediction) if they assign nonzero weight to less models. You can produce a wide variety of ensembles with different accuracy-speed tradeoffs like this:

# %%
additional_ensembles = predictor.fit_weighted_ensemble(expand_pareto_frontier=True)
print("Alternative ensembles you can use for prediction:", additional_ensembles)

predictor.leaderboard(only_pareto_frontier=True, silent=True)
# Out:
# Fitting model: WeightedEnsemble_L3Best ...
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	2.74s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Alternative ensembles you can use for prediction: ['WeightedEnsemble_L3Best']
#              model  score_val  pred_time_val  fit_time  \
# 0  LightGBM_BAG_L2  -0.072728       0.401058  4.485044
# 1  LightGBM_BAG_L1  -0.072862       0.203760  2.237072
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.197298           2.247972            2       True
# 1                0.203760           2.237072            1       True
#
#    fit_order
# 0          3
# 1          1

# %% [markdown]
# The resulting leaderboard will contain the most accurate model for a given inference-latency. You can select whichever model exhibits acceptable latency from the leaderboard and use it for prediction.

# %%
model_for_prediction = additional_ensembles[0]
predictions = predictor.predict(test_data, model=model_for_prediction)

# delete these extra models so they don't affect rest of tutorial
predictor.delete_models(models_to_delete=additional_ensembles, dry_run=False)
# Out:
# Deleting model WeightedEnsemble_L3Best. All files under agModels-predict_freMTPL2freq_2/models/WeightedEnsemble_L3Best/ will be removed.

# %% [markdown]
# ### Collapsing bagged ensembles via `refit_full`
#
# For an ensemble predictor trained with bagging (as done above), recall there ~10 bagged copies of each individual model trained on different train/validation folds. We can collapse this bag of ~10 models into a single model that’s fit to the full dataset, which can greatly reduce its memory/latency requirements (but may also reduce accuracy). Below we refit such a model for each original model but you can alternatively do this for just a particular model by specifying the model argument of `refit_full()`.

# %%
refit_model_map = predictor.refit_full()
print("Name of each refit-full model corresponding to a previous bagged ensemble:")
print(refit_model_map)
predictor.leaderboard(test_data, silent=True)
# Out:
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	0.56s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	0.01s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	0.61s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	0.01s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 2.08s
# Name of each refit-full model corresponding to a previous bagged ensemble:
# {'LightGBM_BAG_L1': 'LightGBM_BAG_L1_FULL', 'WeightedEnsemble_L2': 'WeightedEnsemble_L2_FULL', 'LightGBM_BAG_L2': 'LightGBM_BAG_L2_FULL', 'WeightedEnsemble_L3': 'WeightedEnsemble_L3_FULL'}
#                       model  score_test  score_val  pred_time_test  \
# 0      LightGBM_BAG_L2_FULL   -0.073810        NaN        0.081527
# 1  WeightedEnsemble_L3_FULL   -0.073810        NaN        0.086516
# 2           LightGBM_BAG_L2   -0.073829  -0.072728        0.593302
# 3       WeightedEnsemble_L3   -0.073829  -0.072728        0.598036
# 4      LightGBM_BAG_L1_FULL   -0.073976        NaN        0.038184
# 5  WeightedEnsemble_L2_FULL   -0.073976        NaN        0.042882
# 6           LightGBM_BAG_L1   -0.073983  -0.072862        0.289905
# 7       WeightedEnsemble_L2   -0.073983  -0.072862        0.294486
#
#    pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0            NaN  1.168340                 0.043343                     NaN
# 1            NaN  1.179677                 0.004989                     NaN
# 2       0.401058  4.485044                 0.303397                0.197298
# 3       0.408151  4.496381                 0.004734                0.007093
# 4            NaN  0.563145                 0.038184                     NaN
# 5            NaN  0.574160                 0.004698                     NaN
# 6       0.203760  2.237072                 0.289905                0.203760
# 7       0.210497  2.248087                 0.004581                0.006737
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           0.605196            2       True          7
# 1           0.011337            3       True          8
# 2           2.247972            2       True          3
# 3           0.011337            3       True          4
# 4           0.563145            1       True          5
# 5           0.011015            2       True          6
# 6           2.237072            1       True          1
# 7           0.011015            2       True          2

# %% [markdown]
# This adds the refit-full models to the leaderboard and we can opt to use any of them for prediction just like any other model. Note `pred_time_test` and `pred_time_val` list the time taken to produce predictions with each model (in seconds) on the test/validation data. Since the refit-full models were trained using all of the data, there is no internal validation score (`score_val`) available for them. You can also call `refit_full()` with non-bagged models to refit the same models to your full dataset (there won’t be memory/latency gains in this case but test accuracy may improve).

# %% [markdown]
# ### Model distillation
#
# While computationally-favorable, single individual models will usually have lower accuracy than weighted/stacked/bagged ensembles. Model Distillation offers one way to retain the computational benefits of a single model, while enjoying some of the accuracy-boost that comes with ensembling.
#
# "Fast, Accurate, and Simple Models for Tabular Data via Augmented Distillation": https://arxiv.org/abs/2006.14284
#
# The idea is to train the individual model (which we can call the student) to mimic the predictions of the full stack ensemble (the teacher). Like `refit_full()`, the `distill()` function will produce additional models we can opt to use for prediction.

# %%
student_models = predictor.distill(time_limit=3600)  # specify much longer time limit in real applications: 30 -> 3600
print(student_models)

preds_student = predictor.predict(test_data_nolabel, model=student_models[0])
print(f"predictions from {student_models[0]}:", list(preds_student)[:5])
predictor.leaderboard(test_data)
# Out:
# Distilling with teacher='WeightedEnsemble_L3_FULL', teacher_preds=soft, augment_method=spunge ...
# SPUNGE: Augmenting training data with 100000 synthetic samples for distillation...
# Distilling with each of these student models: ['LightGBM_DSTL', 'NeuralNetMXNet_DSTL', 'CatBoost_DSTL', 'RandomForest_DSTL', 'NeuralNetTorch_DSTL']
# Fitting 5 L1 models ...
# Fitting model: LightGBM_DSTL ... Training model for up to 3600.0s of the 3600.0s of remaining time.
# [1000]	valid_set's l1: 0.0745904
# 	-0.0745	 = Validation score   (-mean_absolute_error)
# 	5.31s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetMXNet_DSTL ... Training model for up to 3594.47s of the 3594.47s of remaining time.
# 	Warning: Exception caused NeuralNetMXNet_DSTL to fail during training (ImportError)... Skipping this model.
# 		Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Fitting model: CatBoost_DSTL ... Training model for up to 3594.37s of the 3594.37s of remaining time.
# 	-0.0747	 = Validation score   (-mean_absolute_error)
# 	345.8s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForest_DSTL ... Training model for up to 3248.31s of the 3248.31s of remaining time.
# 	-0.0804	 = Validation score   (-mean_absolute_error)
# 	17.91s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_DSTL ... Training model for up to 3228.46s of the 3228.45s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	489.26s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Repeating k-fold bagging: 3/20
# Repeating k-fold bagging: 4/20
# Repeating k-fold bagging: 5/20
# Repeating k-fold bagging: 6/20
# Repeating k-fold bagging: 7/20
# Repeating k-fold bagging: 8/20
# Repeating k-fold bagging: 9/20
# Repeating k-fold bagging: 10/20
# Repeating k-fold bagging: 11/20
# Repeating k-fold bagging: 12/20
# Repeating k-fold bagging: 13/20
# Repeating k-fold bagging: 14/20
# Repeating k-fold bagging: 15/20
# Repeating k-fold bagging: 16/20
# Repeating k-fold bagging: 17/20
# Repeating k-fold bagging: 18/20
# Repeating k-fold bagging: 19/20
# Repeating k-fold bagging: 20/20
# Completed 20/20 k-fold bagging repeats ...
# Distilling with each of these student models: ['WeightedEnsemble_L2_DSTL']
# Fitting model: WeightedEnsemble_L2_DSTL ... Training model for up to 360.0s of the 2739.04s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	0.16s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Distilled model leaderboard:
#                       model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       NeuralNetTorch_DSTL  -0.042334       0.031952  489.264411                0.031952         489.264411            1       True         12
# 1  WeightedEnsemble_L2_DSTL  -0.042334       0.032447  489.424435                0.000495           0.160024            2       True         13
# 2             LightGBM_DSTL  -0.074506       0.017576    5.313250                0.017576           5.313250            1       True          9
# 3             CatBoost_DSTL  -0.074689       0.022489  345.797047                0.022489         345.797047            1       True         10
# 4         RandomForest_DSTL  -0.080362       0.123744   17.913839                0.123744          17.913839            1       True         11
# ['LightGBM_DSTL', 'CatBoost_DSTL', 'RandomForest_DSTL', 'NeuralNetTorch_DSTL', 'WeightedEnsemble_L2_DSTL']
# predictions from LightGBM_DSTL: [0.007465063594281673, 0.010630946606397629, 0.011915091425180435, 0.11816341429948807, 0.03702206164598465]
#                        model  score_test  score_val  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0        NeuralNetTorch_DSTL   -0.039985  -0.042334        0.813594       0.031952  489.264411                 0.813594                0.031952         489.264411            1       True         12
# 1   WeightedEnsemble_L2_DSTL   -0.039985  -0.042334        0.823072       0.032447  489.424435                 0.009478                0.000495           0.160024            2       True         13
# 2              CatBoost_DSTL   -0.072362  -0.074689        0.353899       0.022489  345.797047                 0.353899                0.022489         345.797047            1       True         10
# 3              LightGBM_DSTL   -0.072499  -0.074506        0.390013       0.017576    5.313250                 0.390013                0.017576           5.313250            1       True          9
# 4       LightGBM_BAG_L2_FULL   -0.073810        NaN        0.089174            NaN    1.168340                 0.049518                     NaN           0.605196            2       True          7
# 5   WeightedEnsemble_L3_FULL   -0.073810        NaN        0.095431            NaN    1.179677                 0.006257                     NaN           0.011337            3       True          8
# 6            LightGBM_BAG_L2   -0.073829  -0.072728        0.660670       0.401058    4.485044                 0.343650                0.197298           2.247972            2       True          3
# 7        WeightedEnsemble_L3   -0.073829  -0.072728        0.667152       0.408151    4.496381                 0.006482                0.007093           0.011337            3       True          4
# 8       LightGBM_BAG_L1_FULL   -0.073976        NaN        0.039655            NaN    0.563145                 0.039655                     NaN           0.563145            1       True          5
# 9   WeightedEnsemble_L2_FULL   -0.073976        NaN        0.045850            NaN    0.574160                 0.006194                     NaN           0.011015            2       True          6
# 10           LightGBM_BAG_L1   -0.073983  -0.072862        0.317020       0.203760    2.237072                 0.317020                0.203760           2.237072            1       True          1
# 11       WeightedEnsemble_L2   -0.073983  -0.072862        0.323422       0.210497    2.248087                 0.006402                0.006737           0.011015            2       True          2
# 12         RandomForest_DSTL   -0.077501  -0.080362        1.720605       0.123744   17.913839                 1.720605                0.123744          17.913839            1       True         11
#                        model  score_test  score_val  pred_time_test  \
# 0        NeuralNetTorch_DSTL   -0.039985  -0.042334        0.813594
# 1   WeightedEnsemble_L2_DSTL   -0.039985  -0.042334        0.823072
# 2              CatBoost_DSTL   -0.072362  -0.074689        0.353899
# 3              LightGBM_DSTL   -0.072499  -0.074506        0.390013
# 4       LightGBM_BAG_L2_FULL   -0.073810        NaN        0.089174
# 5   WeightedEnsemble_L3_FULL   -0.073810        NaN        0.095431
# 6            LightGBM_BAG_L2   -0.073829  -0.072728        0.660670
# 7        WeightedEnsemble_L3   -0.073829  -0.072728        0.667152
# 8       LightGBM_BAG_L1_FULL   -0.073976        NaN        0.039655
# 9   WeightedEnsemble_L2_FULL   -0.073976        NaN        0.045850
# 10           LightGBM_BAG_L1   -0.073983  -0.072862        0.317020
# 11       WeightedEnsemble_L2   -0.073983  -0.072862        0.323422
# 12         RandomForest_DSTL   -0.077501  -0.080362        1.720605
#
#     pred_time_val    fit_time  pred_time_test_marginal  \
# 0        0.031952  489.264411                 0.813594
# 1        0.032447  489.424435                 0.009478
# 2        0.022489  345.797047                 0.353899
# 3        0.017576    5.313250                 0.390013
# 4             NaN    1.168340                 0.049518
# 5             NaN    1.179677                 0.006257
# 6        0.401058    4.485044                 0.343650
# 7        0.408151    4.496381                 0.006482
# 8             NaN    0.563145                 0.039655
# 9             NaN    0.574160                 0.006194
# 10       0.203760    2.237072                 0.317020
# 11       0.210497    2.248087                 0.006402
# 12       0.123744   17.913839                 1.720605
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.031952         489.264411            1       True
# 1                 0.000495           0.160024            2       True
# 2                 0.022489         345.797047            1       True
# 3                 0.017576           5.313250            1       True
# 4                      NaN           0.605196            2       True
# 5                      NaN           0.011337            3       True
# 6                 0.197298           2.247972            2       True
# 7                 0.007093           0.011337            3       True
# 8                      NaN           0.563145            1       True
# 9                      NaN           0.011015            2       True
# 10                0.203760           2.237072            1       True
# 11                0.006737           0.011015            2       True
# 12                0.123744          17.913839            1       True
#
#     fit_order
# 0          12
# 1          13
# 2          10
# 3           9
# 4           7
# 5           8
# 6           3
# 7           4
# 8           5
# 9           6
# 10          1
# 11          2
# 12         11

# %% [markdown]
# ### Faster presets or hyperparameters
#
# Instead of trying to speed up a cumbersome trained model at prediction time, if you know inference latency or memory will be an issue at the outset, then you can adjust the training process accordingly to ensure `fit()` does not produce unwieldy models.
#
# One option is to specify more lightweight presets:

# %%
presets = ['good_quality_faster_inference_only_refit', 'optimize_for_deployment']
predictor_light = TabularPredictor(
    label=label, 
    eval_metric=metric,
    problem_type="regression"
).fit(
    train_data, 
    presets=presets, 
    time_limit=3600
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230702_222743/"
# Preset alias specified: 'good_quality_faster_inference_only_refit' maps to 'good_quality'.
# Presets specified: ['good_quality_faster_inference_only_refit', 'optimize_for_deployment']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230702_222743/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    157989.69 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.3s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.35s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 9 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2398.5s of the 3598.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.072	 = Validation score   (-mean_absolute_error)
# 	7.63s	 = Training   runtime
# 	2.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2383.08s of the 3583.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0715	 = Validation score   (-mean_absolute_error)
# 	11.72s	 = Training   runtime
# 	1.99s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2365.45s of the 3565.6s of remaining time.
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	12.9s	 = Training   runtime
# 	10.87s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2340.75s of the 3540.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0715	 = Validation score   (-mean_absolute_error)
# 	136.9s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 2197.21s of the 3397.36s of remaining time.
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	5.59s	 = Training   runtime
# 	10.4s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2179.82s of the 3379.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0645	 = Validation score   (-mean_absolute_error)
# 	337.97s	 = Training   runtime
# 	3.69s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1834.24s of the 3034.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0716	 = Validation score   (-mean_absolute_error)
# 	8.76s	 = Training   runtime
# 	1.68s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1818.96s of the 3019.11s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	418.94s	 = Training   runtime
# 	2.26s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1394.15s of the 2594.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0716	 = Validation score   (-mean_absolute_error)
# 	8.29s	 = Training   runtime
# 	1.6s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1379.34s of the 2579.49s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0719	 = Validation score   (-mean_absolute_error)
# 	16.28s	 = Training   runtime
# 	4.64s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1364.7s of the 2564.85s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0715	 = Validation score   (-mean_absolute_error)
# 	20.84s	 = Training   runtime
# 	4.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1348.79s of the 2548.94s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0715	 = Validation score   (-mean_absolute_error)
# 	347.87s	 = Training   runtime
# 	0.99s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1131.93s of the 2332.08s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0645	 = Validation score   (-mean_absolute_error)
# 	667.59s	 = Training   runtime
# 	7.42s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 795.81s of the 1995.96s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0715	 = Validation score   (-mean_absolute_error)
# 	18.04s	 = Training   runtime
# 	3.38s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 779.91s of the 1980.06s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	755.7s	 = Training   runtime
# 	4.24s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 436.92s of the 1637.07s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0716	 = Validation score   (-mean_absolute_error)
# 	17.57s	 = Training   runtime
# 	3.24s	 = Validation runtime
# Completed 2/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1620.72s of remaining time.
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	4.82s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1615.52s of the 1615.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0714	 = Validation score   (-mean_absolute_error)
# 	21.04s	 = Training   runtime
# 	2.52s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 1587.32s of the 1587.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	10.36s	 = Training   runtime
# 	1.64s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 1570.59s of the 1570.52s of remaining time.
# 	-0.0713	 = Validation score   (-mean_absolute_error)
# 	58.81s	 = Training   runtime
# 	9.55s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1501.45s of the 1501.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	162.65s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1331.89s of the 1331.82s of remaining time.
# 	-0.0718	 = Validation score   (-mean_absolute_error)
# 	10.12s	 = Training   runtime
# 	9.97s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1310.87s of the 1310.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0647	 = Validation score   (-mean_absolute_error)
# 	358.51s	 = Training   runtime
# 	3.91s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 945.11s of the 945.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	11.74s	 = Training   runtime
# 	1.95s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 926.14s of the 926.07s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	395.29s	 = Training   runtime
# 	3.17s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 524.47s of the 524.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	9.53s	 = Training   runtime
# 	0.98s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 506.58s of remaining time.
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	4.69s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 3098.74s ... Best model: "WeightedEnsemble_L3"
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	2.63s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	2.69s	 = Training   runtime
# Fitting model: RandomForestMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	12.9s	 = Training   runtime
# 	10.87s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	52.59s	 = Training   runtime
# Fitting model: ExtraTreesMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	5.59s	 = Training   runtime
# 	10.4s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 8.
# 	97.33s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	3.4s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	69.57s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	4.18s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	81.93s	 = Training   runtime
# Refit complete, total runtime = 334.3s
# Deleting model LightGBMXT_BAG_L1. All files under AutogluonModels/ag-20230702_222743/models/LightGBMXT_BAG_L1/ will be removed.
# Deleting model LightGBM_BAG_L1. All files under AutogluonModels/ag-20230702_222743/models/LightGBM_BAG_L1/ will be removed.
# Deleting model RandomForestMSE_BAG_L1. All files under AutogluonModels/ag-20230702_222743/models/RandomForestMSE_BAG_L1/ will be removed.
# Deleting model CatBoost_BAG_L1. All files under AutogluonModels/ag-20230702_222743/models/CatBoost_BAG_L1/ will be removed.
# Deleting model ExtraTreesMSE_BAG_L1. All files under AutogluonModels/ag-20230702_222743/models/ExtraTreesMSE_BAG_L1/ will be removed.
# Deleting model NeuralNetFastAI_BAG_L1. All files under AutogluonModels/ag-20230702_222743/models/NeuralNetFastAI_BAG_L1/ will be removed.
# Deleting model XGBoost_BAG_L1. All files under AutogluonModels/ag-20230702_222743/models/XGBoost_BAG_L1/ will be removed.
# Deleting model NeuralNetTorch_BAG_L1. All files under AutogluonModels/ag-20230702_222743/models/NeuralNetTorch_BAG_L1/ will be removed.
# Deleting model LightGBMLarge_BAG_L1. All files under AutogluonModels/ag-20230702_222743/models/LightGBMLarge_BAG_L1/ will be removed.
# Deleting model WeightedEnsemble_L2. All files under AutogluonModels/ag-20230702_222743/models/WeightedEnsemble_L2/ will be removed.
# Deleting model LightGBMXT_BAG_L2. All files under AutogluonModels/ag-20230702_222743/models/LightGBMXT_BAG_L2/ will be removed.
# Deleting model LightGBM_BAG_L2. All files under AutogluonModels/ag-20230702_222743/models/LightGBM_BAG_L2/ will be removed.
# Deleting model RandomForestMSE_BAG_L2. All files under AutogluonModels/ag-20230702_222743/models/RandomForestMSE_BAG_L2/ will be removed.
# Deleting model CatBoost_BAG_L2. All files under AutogluonModels/ag-20230702_222743/models/CatBoost_BAG_L2/ will be removed.
# Deleting model ExtraTreesMSE_BAG_L2. All files under AutogluonModels/ag-20230702_222743/models/ExtraTreesMSE_BAG_L2/ will be removed.
# Deleting model NeuralNetFastAI_BAG_L2. All files under AutogluonModels/ag-20230702_222743/models/NeuralNetFastAI_BAG_L2/ will be removed.
# Deleting model XGBoost_BAG_L2. All files under AutogluonModels/ag-20230702_222743/models/XGBoost_BAG_L2/ will be removed.
# Deleting model NeuralNetTorch_BAG_L2. All files under AutogluonModels/ag-20230702_222743/models/NeuralNetTorch_BAG_L2/ will be removed.
# Deleting model LightGBMLarge_BAG_L2. All files under AutogluonModels/ag-20230702_222743/models/LightGBMLarge_BAG_L2/ will be removed.
# Deleting model WeightedEnsemble_L3. All files under AutogluonModels/ag-20230702_222743/models/WeightedEnsemble_L3/ will be removed.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230702_222743/")

# %% [markdown]
# Another option is to specify more lightweight hyperparameters:

# %%
# time_limit=30 -> 3600

predictor_light = TabularPredictor(
    label=label, 
    eval_metric=metric,
    problem_type="regression"
).fit(
    train_data, 
    hyperparameters='very_light', 
    time_limit=3600
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230702_232500/"
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230702_232500/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    155670.03 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.3s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.37s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.01, Train Rows: 470017, Val Rows: 4748
# Fitting 7 L1 models ...
# Fitting model: LightGBMXT ... Training model for up to 3598.63s of the 3598.63s of remaining time.
# 	-0.0752	 = Validation score   (-mean_absolute_error)
# 	4.28s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3594.05s of the 3594.05s of remaining time.
# 	-0.0745	 = Validation score   (-mean_absolute_error)
# 	2.74s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 3591.13s of the 3591.13s of remaining time.
# 	-0.0748	 = Validation score   (-mean_absolute_error)
# 	45.17s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 3545.6s of the 3545.6s of remaining time.
# No improvement since epoch 8: early stopping
# 	-0.0703	 = Validation score   (-mean_absolute_error)
# 	317.75s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 3227.47s of the 3227.47s of remaining time.
# 	-0.0747	 = Validation score   (-mean_absolute_error)
# 	4.32s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 3223.01s of the 3223.01s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	411.72s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 2811.17s of the 2811.17s of remaining time.
# 	-0.0746	 = Validation score   (-mean_absolute_error)
# 	3.81s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2807.2s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	0.25s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 794.08s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230702_232500/")

# %% [markdown]
# Here you can set hyperparameters to either 'light', 'very_light', or 'toy' to obtain progressively smaller (but less accurate) models and predictors. Advanced users may instead try manually specifying particular models’ hyperparameters in order to make them faster/smaller.
#
# Finally, you may also exclude specific unwieldy models from being trained at all. Below we exclude models that tend to be slower (K Nearest Neighbors, Neural Network, models with custom larger-than-default hyperparameters):

# %%
# time_limit=30 -> 3600 
    
excluded_model_types = ['KNN', 'NN', 'custom']

predictor_light = TabularPredictor(
    label=label, 
    eval_metric=metric,
    problem_type="regression"
).fit(
    train_data, 
    excluded_model_types=excluded_model_types, 
    time_limit=3600
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230702_233814/"
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230702_233814/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    146481.64 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.2s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.34s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.01, Train Rows: 470017, Val Rows: 4748
# Excluded Model Types: ['KNN', 'NN', 'custom']
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# Fitting 9 L1 models ...
# Fitting model: LightGBMXT ... Training model for up to 3598.66s of the 3598.66s of remaining time.
# 	-0.0752	 = Validation score   (-mean_absolute_error)
# 	4.16s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3594.33s of the 3594.33s of remaining time.
# 	-0.0745	 = Validation score   (-mean_absolute_error)
# 	2.86s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE ... Training model for up to 3591.34s of the 3591.33s of remaining time.
# 	-0.0803	 = Validation score   (-mean_absolute_error)
# 	17.22s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 3572.22s of the 3572.21s of remaining time.
# 	-0.0748	 = Validation score   (-mean_absolute_error)
# 	46.08s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE ... Training model for up to 3526.02s of the 3526.01s of remaining time.
# 	-0.0783	 = Validation score   (-mean_absolute_error)
# 	7.1s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 3517.01s of the 3517.01s of remaining time.
# No improvement since epoch 8: early stopping
# 	-0.0703	 = Validation score   (-mean_absolute_error)
# 	369.59s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 3147.04s of the 3147.04s of remaining time.
# 	-0.0747	 = Validation score   (-mean_absolute_error)
# 	4.15s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 3142.76s of the 3142.76s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	522.35s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 2620.27s of the 2620.26s of remaining time.
# 	-0.0746	 = Validation score   (-mean_absolute_error)
# 	4.59s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2615.46s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	0.39s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 985.5s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230702_233814/")

# %% [markdown]
# ## If you encounter memory issues
#
# To reduce memory usage during training, you may try each of the following strategies individually or combinations of them (these may harm accuracy):
#
# - In `fit()`, set `num_bag_sets=1` (can also try values greater than 1 to harm accuracy less)
#
# - In `fit()`, set `excluded_model_types=['KNN', 'XT', 'RF']` (or some subset of these models)
#
# - Try different `presets` in `fit()`
#
# - In `fit()`, set `hyperparameters='light'` or `hyperparameters='very_light'`
#
# - Text fields in your table require substantial memory for N-gram featurization. To mitigate this in `fit()`, you can either:
#     + (1) add `'ignore_text'` to your `presets` list (to ignore text features), or
#     + (2) specify the argument:
#
# ```
# from sklearn.feature_extraction.text import CountVectorizer
# from autogluon.features.generators import AutoMLPipelineFeatureGenerator
#
# feature_generator = AutoMLPipelineFeatureGenerator(
#     vectorizer=CountVectorizer(
#         min_df=30,
#         ngram_range=(1, 3),
#         max_features=MAX_NGRAM,
#         dtype=np.uint8
#     )
# )
# ```
#
# where `MAX_NGRAM=1000` say (try various values under 10000 to reduce the number of N-gram features used to represent each text field).
#
# In addition to reducing memory usage, many of the above strategies can also be used to reduce training times.
#
# To reduce memory usage during inference:
#
# - If trying to produce predictions for a large test dataset, break the test data into smaller chunks as demonstrated in FAQ.
#     + https://auto.gluon.ai/0.1.0/tutorials/tabular_prediction/tabular-faq.html#sec-faq
#
# - If models have been previously persisted in memory but inference-speed is not a major concern, call `predictor.unpersist_models()`
#
# - If models have been previously persisted in memory, bagging was used in `fit()`, and inference-speed is a concern: call `predictor.refit_full()` and use one of the refit-full models for prediction (ensure this is the only model persisted in memory)

# %% [markdown]
# ## If you encounter disk space issues
#
# To reduce disk usage, you may try each of the following strategies individually or combinations of them:
#
# - Make sure to delete all `predictor.path` folders from previous `fit()` runs
#     + These can eat up your free space if you call `fit()` many times
#     + If you didn’t specify path, AutoGluon still automatically saved its models to a folder called: `“AutogluonModels/ag-[TIMESTAMP]”`, where TIMESTAMP records when `fit()` was called, so make sure to also delete these folders if you run low on free space
#
# - Call `predictor.save_space()` to delete auxiliary files produced during `fit()`
#
# - Call `predictor.delete_models(models_to_keep='best', dry_run=False)` if you only intend to use this predictor for inference going forward (will delete files required for non-prediction-related functionality like `fit_summary`)
#
# - In `fit()`, you can add `'optimize_for_deployment'` to the presets list, which will automatically invoke the previous two strategies after training
#
# Most of the above strategies to reduce memory usage will also reduce disk usage (but may harm accuracy).

# %% [markdown]
# ## References
#
# The following paper describes how AutoGluon internally operates on tabular data:
#
# Erickson et al. "AutoGluon-Tabular: Robust and Accurate AutoML for Structured Data". Arxiv, 2020: https://arxiv.org/abs/2003.06505
