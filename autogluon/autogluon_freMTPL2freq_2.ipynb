# %% [markdown]
# # AutoGluon: freMTPL2freq (Regression) 2
#
# Based on: https://auto.gluon.ai/0.1.0/tutorials/tabular_prediction/tabular-indepth.html

# %%
time_limit = 60*60  # 1 hour max (confirm with timer)
metric = "mean_absolute_error"  # specify your evaluation metric
label = "ClaimNb" # name of target or label variable

# %% [markdown]
# ## Import

# %%
# Import packages

from autogluon.tabular import TabularDataset
from autogluon.tabular import TabularPredictor

import pandas as pd
import numpy as np

# %%
# Import data

train_data = TabularDataset("freMTPL2freq_dataset_train.csv")
test_data = TabularDataset("freMTPL2freq_dataset_test.csv")

# %%
train_data.shape
# Out:
# (474765, 12)

# %%
test_data.shape
# Out:
# (203226, 12)

# %% [markdown]
# ## Tidy

# %% [markdown]
# (skipped)

# %% [markdown]
# ## Transform

# %%
# remove "IDpol" (should not be a predictor)

train_data = train_data.drop(["IDpol"], axis=1)
test_data = test_data.drop(["IDpol"], axis=1)

# %%
y_test = test_data[label]

# %% [markdown]
# ## Visualize

# %% [markdown]
# (skipped)

# %% [markdown]
# ## Model 1

# %%
# %%time

predictor = TabularPredictor(
    label=label, 
    eval_metric=metric,
    problem_type="regression"
).fit(
    train_data,
    time_limit=time_limit
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230712_200524/"
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230712_200524/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    124071.31 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.5s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.58s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.01, Train Rows: 470017, Val Rows: 4748
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ... Training model for up to 3598.42s of the 3598.42s of remaining time.
# 	-0.0769	 = Validation score   (-mean_absolute_error)
# 	3.7s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 3594.29s of the 3594.29s of remaining time.
# 	-0.0764	 = Validation score   (-mean_absolute_error)
# 	1.23s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 3592.61s of the 3592.61s of remaining time.
# 	-0.0752	 = Validation score   (-mean_absolute_error)
# 	5.96s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3586.47s of the 3586.47s of remaining time.
# 	-0.0745	 = Validation score   (-mean_absolute_error)
# 	3.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestMSE ... Training model for up to 3583.31s of the 3583.31s of remaining time.
# 	-0.0803	 = Validation score   (-mean_absolute_error)
# 	14.55s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 3566.79s of the 3566.79s of remaining time.
# 	-0.0748	 = Validation score   (-mean_absolute_error)
# 	45.72s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE ... Training model for up to 3520.93s of the 3520.93s of remaining time.
# 	-0.0783	 = Validation score   (-mean_absolute_error)
# 	6.21s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 3512.6s of the 3512.59s of remaining time.
# No improvement since epoch 8: early stopping
# 	-0.0703	 = Validation score   (-mean_absolute_error)
# 	336.54s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 3175.64s of the 3175.64s of remaining time.
# 	-0.0747	 = Validation score   (-mean_absolute_error)
# 	4.55s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 3170.95s of the 3170.95s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	406.71s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 2764.11s of the 2764.11s of remaining time.
# 	-0.0746	 = Validation score   (-mean_absolute_error)
# 	3.35s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2760.58s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	0.41s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 840.44s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230712_200524/")
# CPU times: user 6h 16min 39s, sys: 9min 25s, total: 6h 26min 4s
# Wall time: 14min

# %%
y_pred = predictor.predict(test_data)

# %%
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: mean_absolute_error on test data: -0.039985119318079465
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.039985119318079465,
#     "root_mean_squared_error": -0.21486121610324158,
#     "mean_squared_error": -0.046165342185363875,
#     "r2": -0.03587427964308243,
#     "pearsonr": 0.010003043367767372,
#     "median_absolute_error": -1.6990729027714646e-12
# }

# %%
# predictor.evaluate(test_data)
perf = predictor.evaluate(test_data)
# Out:
# /home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/predictor/predictor.py:1420: FutureWarning: Calling `predictor.predict_proba` when problem_type=regression will raise an AssertionError starting in AutoGluon v0.8. Please call `predictor.predict` instead.
#   warnings.warn(
# Evaluation: mean_absolute_error on test data: -0.039985119318079465
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.039985119318079465,
#     "root_mean_squared_error": -0.21486121610324158,
#     "mean_squared_error": -0.046165342185363875,
#     "r2": -0.03587427964308243,
#     "pearsonr": 0.010003043367767372,
#     "median_absolute_error": -1.6990729027714646e-12
# }

# %%
predictor.leaderboard(test_data, silent=True).T
# Out:
#                                      0                    1                2   \
# model                    NeuralNetTorch  WeightedEnsemble_L2  NeuralNetFastAI
# score_test                    -0.039985            -0.039985        -0.067926
# score_val                     -0.042334            -0.042334        -0.070266
# pred_time_test                 0.754272             0.759658         1.767661
# pred_time_val                  0.034674             0.035263         0.054281
# fit_time                     406.705648           407.112568        336.54057
# pred_time_test_marginal        0.754272             0.005386         1.767661
# pred_time_val_marginal         0.034674             0.000589         0.054281
# fit_time_marginal            406.705648             0.406919        336.54057
# stack_level                           1                    2                1
# can_infer                          True                 True             True
# fit_order                            10                   12                8
#
#                                      3         4              5          6   \
# model                    KNeighborsDist  LightGBM  LightGBMLarge   CatBoost
# score_test                    -0.072297 -0.072425      -0.072524  -0.072578
# score_val                     -0.076406 -0.074476      -0.074557  -0.074781
# pred_time_test                 4.371001  0.209631       0.170105   0.215623
# pred_time_val                  0.188159  0.017241       0.008562   0.018024
# fit_time                       1.232858  3.001564       3.346161  45.719973
# pred_time_test_marginal        4.371001  0.209631       0.170105   0.215623
# pred_time_val_marginal         0.188159  0.017241       0.008562   0.018024
# fit_time_marginal              1.232858  3.001564       3.346161  45.719973
# stack_level                           1         1              1          1
# can_infer                          True      True           True       True
# fit_order                             2         4             11          6
#
#                                7           8               9              10  \
# model                     XGBoost  LightGBMXT  KNeighborsUnif  ExtraTreesMSE
# score_test               -0.07258   -0.072947       -0.073036      -0.075441
# score_val               -0.074668   -0.075217       -0.076874      -0.078331
# pred_time_test           0.650548    0.304293        9.105313       3.001544
# pred_time_val            0.023861    0.023039        0.134306       0.162833
# fit_time                 4.551962    5.964443        3.695668       6.213621
# pred_time_test_marginal  0.650548    0.304293        9.105313       3.001544
# pred_time_val_marginal   0.023861    0.023039        0.134306       0.162833
# fit_time_marginal        4.551962    5.964443        3.695668       6.213621
# stack_level                     1           1               1              1
# can_infer                    True        True            True           True
# fit_order                       9           3               1              7
#
#                                       11
# model                    RandomForestMSE
# score_test                     -0.077546
# score_val                      -0.080284
# pred_time_test                  1.986001
# pred_time_val                   0.141977
# fit_time                       14.550068
# pred_time_test_marginal         1.986001
# pred_time_val_marginal          0.141977
# fit_time_marginal              14.550068
# stack_level                            1
# can_infer                           True
# fit_order                              5

# %%
predictor.leaderboard(extra_info=True, silent=True).T
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           0   \
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         NeuralNetTorch
# score_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          -0.042334
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.034674
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          406.705648
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              0.034674
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 406.705648
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 10
# num_features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           268579
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               268579
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       268579
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           268579
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        TabularNeuralNetTorchModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        None
# hyperparameters              {'num_epochs': 500, 'epochs_wo_improve': 20, 'activation': 'relu', 'embedding_size_factor': 1.0, 'embed_exponent': 0.56, 'max_embedding_dim': 100, 'y_range': None, 'y_range_extend': 0.05, 'dropout_prob': 0.1, 'optimizer': 'adam', 'learning_rate': 0.0003, 'weight_decay': 1e-06, 'proc.embed_min_categories': 4, 'proc.impute_strategy': 'median', 'proc.max_category_levels': 100, 'proc.skew_threshold': 0.99, 'use_ngram_features': False, 'num_layers': 4, 'hidden_size': 128, 'max_batch_size': 512, 'use_batchnorm': False, 'loss_function': 'auto'}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     {'batch_size': 256, 'num_epochs': 5}
# ag_args_fit                                                                                                                                                      {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': ['text_ngram', 'text_as_category'], 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [Exposure, VehPower, VehAge, DrivAge, BonusMalus, VehGas, Density, VehBrand, Area, Region]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   None
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               None
# child_ag_args_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       None
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 []
# descendants                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [WeightedEnsemble_L2]
#
#                                                                                                                                                                                                                                                                                                                                                                                                               1   \
# model                                                                                                                                                                                                                                                                                                                                                                                        WeightedEnsemble_L2
# score_val                                                                                                                                                                                                                                                                                                                                                                                              -0.042334
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                           0.035263
# fit_time                                                                                                                                                                                                                                                                                                                                                                                              407.112568
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                  0.000589
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                       0.406919
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                    2
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                   True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                     12
# num_features                                                                                                                                                                                                                                                                                                                                                                                                   1
# num_models                                                                                                                                                                                                                                                                                                                                                                                                     1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                         2
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                 4281
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                   272860
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                             4281
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                               268579
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                  1
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                0
# model_type                                                                                                                                                                                                                                                                                                                                                                                 WeightedEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                     GreedyWeightedEnsembleModel
# hyperparameters                                                                                                                                                                                                                                                                                       {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                           {}
# ag_args_fit                  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                                                                                        [NeuralNetTorch]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                     {'ensemble_size': 100}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                   {'ensemble_size': 1}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                       [NeuralNetTorch]
# descendants                                                                                                                                                                                                                                                                                                                                                                                                   []
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                       2   \
# model                                                                                                                                                                                                                                                                                                                                                                                                                                    NeuralNetFastAI
# score_val                                                                                                                                                                                                                                                                                                                                                                                                                                      -0.070266
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                                                   0.054281
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                                                       336.54057
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                                          0.054281
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                                              336.54057
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                                                           True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                                              8
# num_features                                                                                                                                                                                                                                                                                                                                                                                                                                          10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                                                      1044989
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                          1044989
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                                                  1044989
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                      1044989
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                          0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                                                        0
# model_type                                                                                                                                                                                                                                                                                                                                                                                                                          NNFastAiTabularModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                                                    None
# hyperparameters                                                                                                                                                                                                                                                            {'layers': None, 'emb_drop': 0.1, 'ps': 0.1, 'bs': 'auto', 'lr': 0.01, 'epochs': 'auto', 'early.stopping.min_delta': 0.0001, 'early.stopping.patience': 20, 'smoothing': 0.0}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                      {'epochs': 30, 'best_epoch': 8}
# ag_args_fit                  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': ['text_ngram', 'text_as_category'], 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# features                                                                                                                                                                                                                                                                                                                                                      [Exposure, VehPower, VehAge, DrivAge, BonusMalus, VehGas, Density, VehBrand, Area, Region]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                                                        None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                                                                               None
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                           None
# child_ag_args_fit                                                                                                                                                                                                                                                                                                                                                                                                                                   None
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                             []
# descendants                                                                                                                                                                                                                                                                                                                                                                                                                                           []
#
#                                                                                                                                                                                                                                                                                                                                                                                                                         3   \
# model                                                                                                                                                                                                                                                                                                                                                                                                             LightGBM
# score_val                                                                                                                                                                                                                                                                                                                                                                                                        -0.074476
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                     0.017241
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                          3.001564
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                            0.017241
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                 3.001564
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# ...
# features                                                                                                                                                                                                                                                                                                                        [Exposure, VehPower, VehAge, DrivAge, BonusMalus, VehGas, Density, VehBrand, Area, Region]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                                                 None
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                             None
# child_ag_args_fit                                                                                                                                                                                                                                                                                                                                                                                                     None
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                                             []
#
#                                                                                                                                                                                                                                                                                                                                                                                                                         11
# model                                                                                                                                                                                                                                                                                                                                                                                                      RandomForestMSE
# score_val                                                                                                                                                                                                                                                                                                                                                                                                        -0.080284
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                     0.141977
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                         14.550068
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                            0.141977
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                14.550068
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                5
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                      576063480
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                          576063480
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                  576063480
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                      576063480
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          0
# model_type                                                                                                                                                                                                                                                                                                                                                                                                         RFModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                      None
# hyperparameters                                                                                                                                                                                                                                                                           {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error'}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                  {'n_estimators': 300}
# ag_args_fit                  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# features                                                                                                                                                                                                                                                                                                                        [Exposure, VehPower, VehAge, DrivAge, BonusMalus, VehGas, Density, VehBrand, Area, Region]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                                                 None
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                             None
# child_ag_args_fit                                                                                                                                                                                                                                                                                                                                                                                                     None
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                                             []

# %%
predictor.get_model_best()
# Out:
# 'WeightedEnsemble_L2'

# %%
predictor.feature_importance(test_data)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	2.71s	= Expected runtime (0.54s per shuffle set)
# 	1.69s	= Actual runtime (Completed 5 of 5 shuffle sets)
#               importance        stddev   p_value  n      p99_high  \
# Area        3.614439e-08  6.779431e-09  0.000142  5  5.010333e-08
# DrivAge     2.286729e-08  9.596051e-09  0.002986  5  4.262570e-08
# Density     1.336826e-08  4.709432e-09  0.001578  5  2.306504e-08
# Region      7.786567e-09  1.737080e-08  0.186451  5  4.355327e-08
# BonusMalus  3.333822e-09  1.165090e-08  0.278544  5  2.732318e-08
# VehBrand   -1.449882e-09  1.487335e-08  0.580942  5  2.917455e-08
# Exposure   -2.235083e-09  4.859108e-09  0.819089  5  7.769888e-09
# VehAge     -4.298406e-09  6.368754e-09  0.897121  5  8.814947e-09
# VehPower   -7.676738e-09  5.587757e-09  0.981390  5  3.828531e-09
# VehGas     -1.364351e-08  6.261727e-09  0.995896  5 -7.505231e-10
#
#                  p99_low
# Area        2.218544e-08
# DrivAge     3.108892e-09
# Density     3.671474e-09
# Region     -2.798014e-08
# BonusMalus -2.065554e-08
# VehBrand   -3.207431e-08
# Exposure   -1.224005e-08
# VehAge     -1.741176e-08
# VehPower   -1.918201e-08
# VehGas     -2.653649e-08

# %% [markdown]
# ## Model 2

# %%
# %%time

# Can see performance improve if you specify `num_bag_folds = 5-10, num_stack_levels = 1-3` in the call to `fit()`, 
# but this will increase training times and memory/disk usage.
    # num_bag_folds=5, num_bag_sets=1, num_stack_levels=3,                                                              
    # hyperparameters = {'NN': {'num_epochs': 2}, 'GBM': {'num_boost_round': 20}},  
predictor = TabularPredictor(
    label=label, 
    eval_metric=metric,
    problem_type="regression"
).fit(
    train_data,
    time_limit=time_limit,
    num_bag_folds=5, 
    num_bag_sets=1, 
    num_stack_levels=1
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230712_201956/"
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230712_201956/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    118364.62 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.4s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.47s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 2398.42s of the 3598.53s of remaining time.
# 	-0.0719	 = Validation score   (-mean_absolute_error)
# 	1.42s	 = Training   runtime
# 	10.68s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 2385.89s of the 3586.0s of remaining time.
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	1.39s	 = Training   runtime
# 	13.19s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2370.9s of the 3571.01s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.072	 = Validation score   (-mean_absolute_error)
# 	6.55s	 = Training   runtime
# 	1.47s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2345.82s of the 3545.93s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0715	 = Validation score   (-mean_absolute_error)
# 	6.6s	 = Training   runtime
# 	1.52s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2332.11s of the 3532.22s of remaining time.
# 	-0.0766	 = Validation score   (-mean_absolute_error)
# 	14.71s	 = Training   runtime
# 	12.86s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2302.21s of the 3502.32s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0716	 = Validation score   (-mean_absolute_error)
# 	150.97s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 2143.71s of the 3343.82s of remaining time.
# 	-0.0745	 = Validation score   (-mean_absolute_error)
# 	6.45s	 = Training   runtime
# 	11.21s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2123.99s of the 3324.1s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0645	 = Validation score   (-mean_absolute_error)
# 	380.64s	 = Training   runtime
# 	4.06s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1735.62s of the 2935.73s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0716	 = Validation score   (-mean_absolute_error)
# 	10.32s	 = Training   runtime
# 	1.9s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1718.28s of the 2918.39s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	791.58s	 = Training   runtime
# 	2.04s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 920.63s of the 2120.74s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0716	 = Validation score   (-mean_absolute_error)
# 	8.73s	 = Training   runtime
# 	1.22s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2103.23s of remaining time.
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	7.76s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 2095.28s of the 2095.19s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0711	 = Validation score   (-mean_absolute_error)
# 	16.55s	 = Training   runtime
# 	4.47s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 2071.07s of the 2070.99s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0711	 = Validation score   (-mean_absolute_error)
# 	8.04s	 = Training   runtime
# 	0.85s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 2056.63s of the 2056.55s of remaining time.
# 	-0.0795	 = Validation score   (-mean_absolute_error)
# 	119.78s	 = Training   runtime
# 	20.69s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1913.75s of the 1913.66s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	110.09s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1796.38s of the 1796.3s of remaining time.
# 	-0.0758	 = Validation score   (-mean_absolute_error)
# 	16.94s	 = Training   runtime
# 	14.51s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1762.49s of the 1762.41s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0665	 = Validation score   (-mean_absolute_error)
# 	398.73s	 = Training   runtime
# 	4.55s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1355.85s of the 1355.77s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	11.15s	 = Training   runtime
# 	2.4s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1337.17s of the 1337.09s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	1052.88s	 = Training   runtime
# 	3.77s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 277.59s of the 277.51s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	10.14s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 257.16s of remaining time.
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	5.46s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 3348.78s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230712_201956/")
# CPU times: user 2h 51min 52s, sys: 1min 45s, total: 2h 53min 37s
# Wall time: 55min 49s

# %%
y_pred = predictor.predict(test_data)

# %%
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: mean_absolute_error on test data: -0.03998511597831159
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.03998511597831159,
#     "root_mean_squared_error": -0.21486122632194812,
#     "mean_squared_error": -0.04616534657657142,
#     "r2": -0.03587437817455075,
#     "pearsonr": -0.0005451631196338667,
#     "median_absolute_error": -9.009491763745103e-10
# }

# %%
# predictor.evaluate(test_data)
perf = predictor.evaluate(test_data)
# Out:
# /home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/predictor/predictor.py:1420: FutureWarning: Calling `predictor.predict_proba` when problem_type=regression will raise an AssertionError starting in AutoGluon v0.8. Please call `predictor.predict` instead.
#   warnings.warn(
# Evaluation: mean_absolute_error on test data: -0.03998511597831159
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.03998511597831159,
#     "root_mean_squared_error": -0.21486122632194812,
#     "mean_squared_error": -0.04616534657657142,
#     "r2": -0.03587437817455075,
#     "pearsonr": -0.0005451631196338667,
#     "median_absolute_error": -9.009491763745103e-10
# }

# %%
predictor.leaderboard(test_data, silent=True).T
# Out:
#                                             0                    1   \
# model                    NeuralNetTorch_BAG_L2  WeightedEnsemble_L3
# score_test                           -0.039985            -0.039985
# score_val                            -0.038583            -0.038583
# pred_time_test                       42.877944            42.885132
# pred_time_val                        64.380429            64.387338
# fit_time                           2432.232371           2437.69545
# pred_time_test_marginal               6.691803             0.007188
# pred_time_val_marginal                3.771336             0.006908
# fit_time_marginal                  1052.880814             5.463078
# stack_level                                  2                    3
# can_infer                                 True                 True
# fit_order                                   20                   22
#
#                                             2                    3   \
# model                    NeuralNetTorch_BAG_L1  WeightedEnsemble_L2
# score_test                           -0.039985            -0.039985
# score_val                            -0.038583            -0.038583
# pred_time_test                        4.426929             4.434922
# pred_time_val                         2.040818             2.048222
# fit_time                            791.580384           799.344631
# pred_time_test_marginal               4.426929             0.007993
# pred_time_val_marginal                2.040818             0.007404
# fit_time_marginal                   791.580384             7.764246
# stack_level                                  1                    2
# can_infer                                 True                 True
# fit_order                                   10                   12
#
#                                              4                       5   \
# model                    NeuralNetFastAI_BAG_L1  NeuralNetFastAI_BAG_L2
# score_test                            -0.065238               -0.067169
# score_val                              -0.06452               -0.066485
# pred_time_test                          9.46909               45.770263
# pred_time_val                          4.062594               65.160219
# fit_time                             380.641476              1778.07983
# pred_time_test_marginal                 9.46909                9.584122
# pred_time_val_marginal                 4.062594                4.551126
# fit_time_marginal                    380.641476              398.728273
# stack_level                                   1                       2
# can_infer                                  True                    True
# fit_order                                     8                      18
#
#                                       6                7               8   \
# model                    CatBoost_BAG_L2  LightGBM_BAG_L2  XGBoost_BAG_L2
# score_test                     -0.072125        -0.072163       -0.072198
# score_val                      -0.071163        -0.071117       -0.071174
# pred_time_test                 36.706403        37.149064       40.254109
# pred_time_val                  61.001338        61.457231       63.010879
# fit_time                     1489.439266      1387.387631     1390.497276
# pred_time_test_marginal         0.520262         0.962923        4.067968
# pred_time_val_marginal          0.392245         0.848138        2.401786
# fit_time_marginal             110.087709         8.036074       11.145719
# stack_level                            2                2               2
# can_infer                           True             True            True
# fit_order                             16               14              19
#
#                                            9   ...               12  \
# model                    LightGBMLarge_BAG_L2  ...  LightGBM_BAG_L1
# score_test                          -0.072199  ...        -0.072418
# score_val                           -0.071182  ...        -0.071479
# pred_time_test                      37.286397  ...         1.326295
# pred_time_val                       61.405609  ...         1.519886
# fit_time                          1389.486912  ...         6.603834
# pred_time_test_marginal              1.100255  ...         1.326295
# pred_time_val_marginal               0.796516  ...         1.519886
# fit_time_marginal                   10.135355  ...         6.603834
# stack_level                                 2  ...                1
# can_infer                                True  ...             True
# fit_order                                  21  ...                4
#
#                                       13              14  \
# model                    CatBoost_BAG_L1  XGBoost_BAG_L1
# score_test                     -0.072537       -0.072576
# score_val                      -0.071574        -0.07159
# pred_time_test                   0.61804        3.578753
# pred_time_val                   0.462493        1.900516
# fit_time                      150.967978       10.316578
# pred_time_test_marginal          0.61804        3.578753
# pred_time_val_marginal          0.462493        1.900516
# fit_time_marginal             150.967978       10.316578
# stack_level                            1               1
# can_infer                           True            True
# fit_order                              6               9
#
#                                            15                 16  \
# model                    LightGBMLarge_BAG_L1  LightGBMXT_BAG_L1
# score_test                          -0.072584           -0.07295
# score_val                           -0.071613          -0.071975
# pred_time_test                       1.197194           1.323664
# pred_time_val                        1.218174           1.471195
# fit_time                             8.725085           6.552329
# pred_time_test_marginal              1.197194           1.323664
# pred_time_val_marginal               1.218174           1.471195
# fit_time_marginal                    8.725085           6.552329
# stack_level                                 1                  1
# can_infer                                True               True
# fit_order                                  11                  3
#
#                                             17                    18  \
# model                    KNeighborsUnif_BAG_L1  ExtraTreesMSE_BAG_L2
# score_test                           -0.073063             -0.073974
# score_val                            -0.071918             -0.075807
# pred_time_test                        5.433018             38.464293
# pred_time_val                        10.682108             75.121279
# fit_time                              1.416494           1396.295545
# pred_time_test_marginal               5.433018              2.278151
# pred_time_val_marginal               10.682108             14.512186
# fit_time_marginal                     1.416494             16.943988
# stack_level                                  1                     2
# can_infer                                 True                  True
# fit_order                                    1                    17
#
#                                              19                    20  \
# model                    RandomForestMSE_BAG_L2  ExtraTreesMSE_BAG_L1
# score_test                             -0.07468             -0.075443
# score_val                             -0.079536             -0.074546
# pred_time_test                        38.384353              1.369108
# pred_time_val                         81.295094             11.207154
# fit_time                            1499.129777              6.454112
# pred_time_test_marginal                2.198212              1.369108
# pred_time_val_marginal                20.686001             11.207154
# fit_time_marginal                     119.77822              6.454112
# stack_level                                   2                     1
# can_infer                                  True                  True
# fit_order                                    15                     7
#
#                                              21
# model                    RandomForestMSE_BAG_L1
# score_test                            -0.077438
# score_val                             -0.076606
# pred_time_test                         1.441711
# pred_time_val                         12.856482
# fit_time                              14.707682
# pred_time_test_marginal                1.441711
# pred_time_val_marginal                12.856482
# fit_time_marginal                     14.707682
# stack_level                                   1
# can_infer                                  True
# fit_order                                     5
#
# [12 rows x 22 columns]

# %%
predictor.leaderboard(extra_info=True, silent=True).T
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           0   \
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NeuralNetTorch_BAG_L2
# score_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          -0.038583
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      64.380429
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         2432.232371
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              3.771336
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1052.880814
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                2
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 20
# num_features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              21
# num_models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 5
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    44
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1822237
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1298342866
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       368057
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        576066291
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             11
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  TabularNeuralNetTorchModel
# hyperparameters                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {}
# ag_args_fit                                                                                                                                                                                              {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                    [VehBrand, ExtraTreesMSE_BAG_L1, RandomForestMSE_BAG_L1, Density, LightGBMXT_BAG_L1, NeuralNetFastAI_BAG_L1, XGBoost_BAG_L1, Region, LightGBMLarge_BAG_L1, CatBoost_BAG_L1, VehPower, LightGBM_BAG_L1, BonusMalus, DrivAge, VehGas, Area, Exposure, KNeighborsUnif_BAG_L1, VehAge, NeuralNetTorch_BAG_L1, KNeighborsDist_BAG_L1]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            None
# child_hyperparameters        {'num_epochs': 500, 'epochs_wo_improve': 20, 'activation': 'relu', 'embedding_size_factor': 1.0, 'embed_exponent': 0.56, 'max_embedding_dim': 100, 'y_range': None, 'y_range_extend': 0.05, 'dropout_prob': 0.1, 'optimizer': 'adam', 'learning_rate': 0.0003, 'weight_decay': 1e-06, 'proc.embed_min_categories': 4, 'proc.impute_strategy': 'median', 'proc.max_category_levels': 100, 'proc.skew_threshold': 0.99, 'use_ngram_features': False, 'num_layers': 4, 'hidden_size': 128, 'max_batch_size': 512, 'use_batchnorm': False, 'loss_function': 'auto'}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              {'batch_size': 256, 'num_epochs': 19}
# child_ag_args_fit                                                                                                                                                {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': ['text_ngram', 'text_as_category'], 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                             [LightGBM_BAG_L1, NeuralNetFastAI_BAG_L1, KNeighborsUnif_BAG_L1, ExtraTreesMSE_BAG_L1, RandomForestMSE_BAG_L1, XGBoost_BAG_L1, NeuralNetTorch_BAG_L1, LightGBMXT_BAG_L1, LightGBMLarge_BAG_L1, KNeighborsDist_BAG_L1, CatBoost_BAG_L1]
# descendants                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [WeightedEnsemble_L3]
#
#                                                                                                                                                                                                                                                                                                                                                                                                               1   \
# model                                                                                                                                                                                                                                                                                                                                                                                        WeightedEnsemble_L3
# score_val                                                                                                                                                                                                                                                                                                                                                                                              -0.038583
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                          64.387338
# fit_time                                                                                                                                                                                                                                                                                                                                                                                              2437.69545
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                  0.006908
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                       5.463078
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                    3
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                   True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                     22
# num_features                                                                                                                                                                                                                                                                                                                                                                                                   1
# num_models                                                                                                                                                                                                                                                                                                                                                                                                     1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                        45
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                 4198
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                               1298347064
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                             4198
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                            576066291
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                 12
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                0
# model_type                                                                                                                                                                                                                                                                                                                                                                                 WeightedEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                     GreedyWeightedEnsembleModel
# hyperparameters                                                                                                                                                                                                                                                                                       {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                           {}
# ag_args_fit                  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                                                                                 [NeuralNetTorch_BAG_L2]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                     {'ensemble_size': 100}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                   {'ensemble_size': 1}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# ancestors                                                                                                                                          [NeuralNetTorch_BAG_L2, LightGBM_BAG_L1, NeuralNetFastAI_BAG_L1, KNeighborsUnif_BAG_L1, ExtraTreesMSE_BAG_L1, RandomForestMSE_BAG_L1, XGBoost_BAG_L1, NeuralNetTorch_BAG_L1, LightGBMXT_BAG_L1, LightGBMLarge_BAG_L1, KNeighborsDist_BAG_L1, CatBoost_BAG_L1]
# descendants                                                                                                                                                                                                                                                                                                                                                                                                   []
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           2   \
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  NeuralNetTorch_BAG_L1
# score_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          -0.038583
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       2.040818
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          791.580384
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              2.040818
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 791.580384
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 10
# num_features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 5
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     5
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1346059
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1346059
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       271597
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           271597
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           11
# model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  TabularNeuralNetTorchModel
# hyperparameters                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {}
# ag_args_fit                                                                                                                                                                                              {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            None
# child_hyperparameters        {'num_epochs': 500, 'epochs_wo_improve': 20, 'activation': 'relu', 'embedding_size_factor': 1.0, 'embed_exponent': 0.56, 'max_embedding_dim': 100, 'y_range': None, 'y_range_extend': 0.05, 'dropout_prob': 0.1, 'optimizer': 'adam', 'learning_rate': 0.0003, 'weight_decay': 1e-06, 'proc.embed_min_categories': 4, 'proc.impute_strategy': 'median', 'proc.max_category_levels': 100, 'proc.skew_threshold': 0.99, 'use_ngram_features': False, 'num_layers': 4, 'hidden_size': 128, 'max_batch_size': 512, 'use_batchnorm': False, 'loss_function': 'auto'}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {'batch_size': 256, 'num_epochs': 8}
# child_ag_args_fit                                                                                                                                                {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': ['text_ngram', 'text_as_category'], 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 []
# ...
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                     {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error'}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                            {'n_estimators': 300}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                  [ExtraTreesMSE_BAG_L2, CatBoost_BAG_L2, XGBoost_BAG_L2, NeuralNetFastAI_BAG_L2, NeuralNetTorch_BAG_L2, RandomForestMSE_BAG_L2, LightGBMLarge_BAG_L2, LightGBM_BAG_L2, LightGBMXT_BAG_L2, WeightedEnsemble_L3]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                         21
# model                                                                                                                                                                                                                                                                                                                                                                                               RandomForestMSE_BAG_L2
# score_val                                                                                                                                                                                                                                                                                                                                                                                                        -0.079536
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                    81.295094
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                       1499.129777
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                           20.686001
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                119.77822
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              2
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                               15
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            21
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                  40
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                      576068027
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                         1872588656
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                  576068027
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                      576068027
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                           11
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          0
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                   RFModel
# hyperparameters                                                                                                                                                                                                                                                                           {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True, 'use_child_oof': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                  [VehBrand, ExtraTreesMSE_BAG_L1, RandomForestMSE_BAG_L1, Density, LightGBMXT_BAG_L1, NeuralNetFastAI_BAG_L1, XGBoost_BAG_L1, Region, LightGBMLarge_BAG_L1, CatBoost_BAG_L1, VehPower, LightGBM_BAG_L1, BonusMalus, DrivAge, VehGas, Area, Exposure, KNeighborsUnif_BAG_L1, VehAge, NeuralNetTorch_BAG_L1, KNeighborsDist_BAG_L1]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                     {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error'}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                            {'n_estimators': 300}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                           [LightGBM_BAG_L1, NeuralNetFastAI_BAG_L1, KNeighborsUnif_BAG_L1, ExtraTreesMSE_BAG_L1, RandomForestMSE_BAG_L1, XGBoost_BAG_L1, NeuralNetTorch_BAG_L1, LightGBMXT_BAG_L1, LightGBMLarge_BAG_L1, KNeighborsDist_BAG_L1, CatBoost_BAG_L1]
# descendants                                                                                                                                                                                                                                                                                                                                                                                                             []
#
# [30 rows x 22 columns]

# %%
predictor.get_model_best()
# Out:
# 'WeightedEnsemble_L3'

# %%
predictor.feature_importance(test_data)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	264.17s	= Expected runtime (52.83s per shuffle set)
# 	90.88s	= Actual runtime (Completed 5 of 5 shuffle sets)
#               importance        stddev   p_value  n      p99_high  \
# DrivAge     1.685793e-08  1.685820e-08  0.044506  5  5.156919e-08
# BonusMalus  8.284121e-09  9.446975e-09  0.060720  5  2.773557e-08
# Exposure    2.152276e-09  1.153540e-08  0.348974  5  2.590382e-08
# Area       -8.959609e-10  3.263300e-09  0.713770  5  5.823218e-09
# VehBrand   -2.128337e-09  7.043676e-09  0.731847  5  1.237469e-08
# Density    -4.062924e-09  1.070142e-08  0.778135  5  1.797145e-08
# Region     -4.877259e-09  8.754181e-09  0.859586  5  1.314772e-08
# VehGas     -8.062322e-09  8.409898e-09  0.950659  5  9.253774e-09
# VehAge     -1.146578e-08  1.860524e-08  0.879868  5  2.684266e-08
# VehPower   -1.378347e-08  7.603412e-09  0.992285  5  1.872064e-09
#
#                  p99_low
# DrivAge    -1.785333e-08
# BonusMalus -1.116733e-08
# Exposure   -2.159927e-08
# Area       -7.615140e-09
# VehBrand   -1.663136e-08
# Density    -2.609730e-08
# Region     -2.290224e-08
# VehGas     -2.537842e-08
# VehAge     -4.977422e-08
# VehPower   -2.943900e-08

# %% [markdown]
# ## Model 3

# %%
# %%time

predictor = TabularPredictor(
    label=label, 
    eval_metric=metric, 
    problem_type="regression"
).fit(
    train_data,
    time_limit=time_limit, 
    auto_stack=True,
    hyperparameters={'NN': {'num_epochs': 2}, 'GBM': {'num_boost_round': 20}} 
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230712_212027/"
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230712_212027/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    104582.98 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.4s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.49s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# 	WARNING: "NN" model has been deprecated in v0.4.0 and renamed to "NN_MXNET". Starting in v0.6.0, specifying "NN" or "NN_MXNET" will raise an exception. Consider instead specifying "NN_TORCH".
# Fitting 2 L1 models ...
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2398.41s of the 3598.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	2.75s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 2387.13s of the 3587.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetMXNet_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=20776, ip=10.164.150.180)
# ModuleNotFoundError: No module named 'mxnet'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=20776, ip=10.164.150.180)
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 374, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold,
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 703, in fit
#     out = self._fit(**kwargs)
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/models/tabular_nn/mxnet/tabular_nn_mxnet.py", line 135, in _fit
#     try_import_mxnet()
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/utils/try_import.py", line 49, in try_import_mxnet
#     raise ImportError(
# ImportError: Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2381.01s of the 3581.11s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-07-12 21:20:46,612	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:20:46,614	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:20:46,615	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:20:46,616	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:20:46,617	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:20:46,618	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:20:46,619	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	5.73s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2367.69s of the 3567.79s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	8.39s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2351.65s of the 3551.75s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	11.0s	 = Training   runtime
# 	0.96s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2341.73s of the 3541.84s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	13.85s	 = Training   runtime
# 	1.17s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2225.55s of the 3425.65s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	19.85s	 = Training   runtime
# 	1.39s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2212.26s of the 3412.37s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	22.51s	 = Training   runtime
# 	1.62s	 = Validation runtime
# Repeating k-fold bagging: 8/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2202.34s of the 3402.44s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	25.21s	 = Training   runtime
# 	1.87s	 = Validation runtime
# Repeating k-fold bagging: 9/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2189.21s of the 3389.32s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	27.83s	 = Training   runtime
# 	2.12s	 = Validation runtime
# Repeating k-fold bagging: 10/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2179.25s of the 3379.35s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	30.52s	 = Training   runtime
# 	2.33s	 = Validation runtime
# Repeating k-fold bagging: 11/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2169.75s of the 3369.85s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	39.11s	 = Training   runtime
# 	2.56s	 = Validation runtime
# Repeating k-fold bagging: 12/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2153.44s of the 3353.54s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	42.09s	 = Training   runtime
# 	2.79s	 = Validation runtime
# Repeating k-fold bagging: 13/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2141.15s of the 3341.25s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	58.16s	 = Training   runtime
# 	4.18s	 = Validation runtime
# Repeating k-fold bagging: 19/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2071.96s of the 3272.07s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	60.9s	 = Training   runtime
# 	4.4s	 = Validation runtime
# Repeating k-fold bagging: 20/20
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2062.23s of the 3262.33s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	63.45s	 = Training   runtime
# 	4.61s	 = Validation runtime
# Completed 20/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3252.49s of remaining time.
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# 	WARNING: "NN" model has been deprecated in v0.4.0 and renamed to "NN_MXNET". Starting in v0.6.0, specifying "NN" or "NN_MXNET" will raise an exception. Consider instead specifying "NN_TORCH".
# Fitting 2 L2 models ...
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3252.31s of the 3252.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	2.77s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L2 ... Training model for up to 3243.29s of the 3243.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	Warning: Exception caused NeuralNetMXNet_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=62550, ip=10.164.150.180)
# ModuleNotFoundError: No module named 'mxnet'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=62550, ip=10.164.150.180)
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 374, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold,
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py", line 703, in fit
#     out = self._fit(**kwargs)
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/models/tabular_nn/mxnet/tabular_nn_mxnet.py", line 135, in _fit
#     try_import_mxnet()
#   File "/home/stever7/.local/lib/python3.9/site-packages/autogluon/core/utils/try_import.py", line 49, in try_import_mxnet
#     raise ImportError(
# ImportError: Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3236.93s of the 3236.91s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 2023-07-12 21:26:35,798	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:26:35,799	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:26:35,800	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:26:35,801	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:26:35,801	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:26:35,802	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2023-07-12 21:26:35,803	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	9.21s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3224.13s of the 3224.11s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	15.05s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3210.0s of the 3209.98s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	21.04s	 = Training   runtime
# 	0.93s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3197.72s of the 3197.7s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	24.13s	 = Training   runtime
# 	1.17s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3186.21s of the 3186.19s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	27.23s	 = Training   runtime
# 	1.41s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3174.57s of the 3174.55s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	30.61s	 = Training   runtime
# 	1.64s	 = Validation runtime
# Repeating k-fold bagging: 8/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3162.09s of the 3162.07s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	33.26s	 = Training   runtime
# 	1.86s	 = Validation runtime
# Repeating k-fold bagging: 9/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3150.88s of the 3150.86s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	36.11s	 = Training   runtime
# 	2.24s	 = Validation runtime
# Repeating k-fold bagging: 10/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3140.0s of the 3139.98s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	38.73s	 = Training   runtime
# 	2.47s	 = Validation runtime
# Repeating k-fold bagging: 11/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3130.22s of the 3130.2s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	41.46s	 = Training   runtime
# 	2.71s	 = Validation runtime
# Repeating k-fold bagging: 12/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3120.27s of the 3120.25s of remaining time.
# 	Fitting 8 child models (S12F1 - S12F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	44.11s	 = Training   runtime
# 	2.92s	 = Validation runtime
# Repeating k-fold bagging: 13/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3110.61s of the 3110.6s of remaining time.
# 	Fitting 8 child models (S13F1 - S13F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	46.66s	 = Training   runtime
# 	3.16s	 = Validation runtime
# Repeating k-fold bagging: 14/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3100.48s of the 3100.46s of remaining time.
# 	Fitting 8 child models (S14F1 - S14F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	52.27s	 = Training   runtime
# 	3.36s	 = Validation runtime
# Repeating k-fold bagging: 15/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3087.6s of the 3087.58s of remaining time.
# 	Fitting 8 child models (S15F1 - S15F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	58.63s	 = Training   runtime
# 	3.59s	 = Validation runtime
# Repeating k-fold bagging: 16/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3074.2s of the 3074.18s of remaining time.
# 	Fitting 8 child models (S16F1 - S16F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	63.2s	 = Training   runtime
# 	3.76s	 = Validation runtime
# Repeating k-fold bagging: 17/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3060.39s of the 3060.38s of remaining time.
# 	Fitting 8 child models (S17F1 - S17F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	66.32s	 = Training   runtime
# 	3.99s	 = Validation runtime
# Repeating k-fold bagging: 18/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3047.91s of the 3047.89s of remaining time.
# 	Fitting 8 child models (S18F1 - S18F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	69.67s	 = Training   runtime
# 	4.21s	 = Validation runtime
# Repeating k-fold bagging: 19/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3034.94s of the 3034.92s of remaining time.
# 	Fitting 8 child models (S19F1 - S19F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	72.73s	 = Training   runtime
# 	4.46s	 = Validation runtime
# Repeating k-fold bagging: 20/20
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3021.94s of the 3021.92s of remaining time.
# 	Fitting 8 child models (S20F1 - S20F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	75.95s	 = Training   runtime
# 	4.73s	 = Validation runtime
# Completed 20/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 3009.25s of remaining time.
# 	-0.0727	 = Validation score   (-mean_absolute_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 591.23s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230712_212027/")
# CPU times: user 28.2 s, sys: 8.73 s, total: 36.9 s
# Wall time: 9min 51s

# %%
y_pred = predictor.predict(test_data)

# %%
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: mean_absolute_error on test data: -0.0737839220164657
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.0737839220164657,
#     "root_mean_squared_error": -0.20784771192379303,
#     "mean_squared_error": -0.04320067135195605,
#     "r2": 0.030648053314059842,
#     "pearsonr": 0.19211412966475822,
#     "median_absolute_error": -0.035157460719347
# }

# %%
# predictor.evaluate(test_data)
perf = predictor.evaluate(test_data)
# Out:
# /home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/predictor/predictor.py:1420: FutureWarning: Calling `predictor.predict_proba` when problem_type=regression will raise an AssertionError starting in AutoGluon v0.8. Please call `predictor.predict` instead.
#   warnings.warn(
# Evaluation: mean_absolute_error on test data: -0.0737839220164657
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.0737839220164657,
#     "root_mean_squared_error": -0.20784771192379303,
#     "mean_squared_error": -0.04320067135195605,
#     "r2": 0.030648053314059842,
#     "pearsonr": 0.19211412966475822,
#     "median_absolute_error": -0.035157460719347
# }

# %%
predictor.leaderboard(test_data, silent=True).T
# Out:
#                                        0                    1  \
# model                    LightGBM_BAG_L2  WeightedEnsemble_L3
# score_test                     -0.073784            -0.073784
# score_val                      -0.072698            -0.072698
# pred_time_test                  13.94349            13.950201
# pred_time_val                   9.342929             9.349226
# fit_time                      139.398051           139.408526
# pred_time_test_marginal         7.338942             0.006711
# pred_time_val_marginal          4.731892             0.006297
# fit_time_marginal              75.949871             0.010475
# stack_level                            2                    3
# can_infer                           True                 True
# fit_order                              3                    4
#
#                                        2                    3
# model                    LightGBM_BAG_L1  WeightedEnsemble_L2
# score_test                      -0.07398             -0.07398
# score_val                      -0.072858            -0.072858
# pred_time_test                  6.604547             6.613847
# pred_time_val                   4.611037             4.618846
# fit_time                       63.448179            63.461668
# pred_time_test_marginal         6.604547               0.0093
# pred_time_val_marginal          4.611037             0.007809
# fit_time_marginal              63.448179             0.013488
# stack_level                            1                    2
# can_infer                           True                 True
# fit_order                              1                    2

# %%
predictor.leaderboard(extra_info=True, silent=True).T
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                          0  \
# model                                                                                                                                                                                                                                                                                                                                                                                                      LightGBM_BAG_L2
# score_val                                                                                                                                                                                                                                                                                                                                                                                                        -0.072698
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                     9.342929
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                        139.398051
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                            4.731892
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                75.949871
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              2
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                3
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            11
# num_models                                                                                                                                                                                                                                                                                                                                                                                                             160
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                 320
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                       10285077
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                           20692766
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                      69052
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                          69416
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            1
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                  LGBModel
# hyperparameters                                                                                                                                                                                                                                                                                                  {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                       [VehPower, Exposure, VehBrand, LightGBM_BAG_L1, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                       {'learning_rate': 0.05, 'num_boost_round': 20}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                          {'num_boost_round': 20}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                [LightGBM_BAG_L1]
# descendants                                                                                                                                                                                                                                                                                                                                                                                          [WeightedEnsemble_L3]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                1  \
# model                                                                                                                                                                                                                                                                                                                                                                                        WeightedEnsemble_L3
# score_val                                                                                                                                                                                                                                                                                                                                                                                              -0.072698
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                           9.349226
# fit_time                                                                                                                                                                                                                                                                                                                                                                                              139.408526
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                  0.006297
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                       0.010475
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                    3
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                   True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                      4
# num_features                                                                                                                                                                                                                                                                                                                                                                                                   1
# num_models                                                                                                                                                                                                                                                                                                                                                                                                     1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                       321
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                 2788
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                 20695554
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                             2788
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                69416
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                  2
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                0
# model_type                                                                                                                                                                                                                                                                                                                                                                                 WeightedEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                     GreedyWeightedEnsembleModel
# hyperparameters                                                                                                                                                                                                                                                                                       {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                           {}
# ag_args_fit                  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                                                                                       [LightGBM_BAG_L2]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                     {'ensemble_size': 100}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                   {'ensemble_size': 1}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# ancestors                                                                                                                                                                                                                                                                                                                                                                     [LightGBM_BAG_L1, LightGBM_BAG_L2]
# descendants                                                                                                                                                                                                                                                                                                                                                                                                   []
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          2  \
# model                                                                                                                                                                                                                                                                                                                                                                                                      LightGBM_BAG_L1
# score_val                                                                                                                                                                                                                                                                                                                                                                                                        -0.072858
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                     4.611037
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                         63.448179
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                            4.611037
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                63.448179
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                1
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                             160
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                 160
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                       10407689
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                           10407689
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                      69416
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                          69416
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          3
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                  LGBModel
# hyperparameters                                                                                                                                                                                                                                                                                                  {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                       {'learning_rate': 0.05, 'num_boost_round': 20}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                          {'num_boost_round': 20}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                    [WeightedEnsemble_L2, LightGBM_BAG_L2, WeightedEnsemble_L3]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                3
# model                                                                                                                                                                                                                                                                                                                                                                                        WeightedEnsemble_L2
# score_val                                                                                                                                                                                                                                                                                                                                                                                              -0.072858
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                           4.618846
# fit_time                                                                                                                                                                                                                                                                                                                                                                                               63.461668
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                  0.007809
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                       0.013488
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                    2
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                   True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                      2
# num_features                                                                                                                                                                                                                                                                                                                                                                                                   1
# num_models                                                                                                                                                                                                                                                                                                                                                                                                     1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                       161
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                 2788
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                 10410477
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                             2788
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                69416
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                  1
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                0
# model_type                                                                                                                                                                                                                                                                                                                                                                                 WeightedEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                     GreedyWeightedEnsembleModel
# hyperparameters                                                                                                                                                                                                                                                                                       {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                           {}
# ag_args_fit                  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                                                                                       [LightGBM_BAG_L1]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                     {'ensemble_size': 100}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                   {'ensemble_size': 1}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                      [LightGBM_BAG_L1]
# descendants                                                                                                                                                                                                                                                                                                                                                                                                   []

# %%
predictor.get_model_best()
# Out:
# 'WeightedEnsemble_L3'

# %%
predictor.feature_importance(test_data)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	108.63s	= Expected runtime (21.73s per shuffle set)
# 	35.54s	= Actual runtime (Completed 5 of 5 shuffle sets)
#             importance    stddev   p_value  n  p99_high   p99_low
# BonusMalus    0.004757  0.000541  0.000020  5  0.005872  0.003643
# Exposure      0.002946  0.000592  0.000185  5  0.004165  0.001727
# DrivAge       0.000877  0.000091  0.000014  5  0.001064  0.000690
# VehBrand      0.000230  0.000046  0.000174  5  0.000324  0.000137
# VehAge        0.000222  0.000036  0.000077  5  0.000295  0.000148
# Region        0.000154  0.000046  0.000869  5  0.000249  0.000059
# Density       0.000134  0.000053  0.002505  5  0.000244  0.000024
# VehGas        0.000039  0.000021  0.007491  5  0.000082 -0.000005
# VehPower      0.000017  0.000010  0.009769  5  0.000037 -0.000004
# Area         -0.000003  0.000009  0.741503  5  0.000016 -0.000021

# %% [markdown]
# ## Model 4

# %%
# %%time

presets = ['good_quality_faster_inference_only_refit', 'optimize_for_deployment']

predictor = TabularPredictor(
    label=label, 
    eval_metric=metric,
    problem_type="regression"
).fit(
    train_data,
    time_limit=time_limit,
    presets=presets
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230712_213230/"
# Preset alias specified: 'good_quality_faster_inference_only_refit' maps to 'good_quality'.
# Presets specified: ['good_quality_faster_inference_only_refit', 'optimize_for_deployment']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230712_213230/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    101800.72 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.3s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.49s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 9 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2398.4s of the 3598.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.072	 = Validation score   (-mean_absolute_error)
# 	9.73s	 = Training   runtime
# 	2.13s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2379.84s of the 3579.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0715	 = Validation score   (-mean_absolute_error)
# 	9.61s	 = Training   runtime
# 	2.23s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 2363.31s of the 3563.41s of remaining time.
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	14.32s	 = Training   runtime
# 	11.38s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2336.65s of the 3536.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0715	 = Validation score   (-mean_absolute_error)
# 	155.21s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 2174.38s of the 3374.48s of remaining time.
# 	-0.0729	 = Validation score   (-mean_absolute_error)
# 	6.05s	 = Training   runtime
# 	10.91s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2156.27s of the 3356.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0645	 = Validation score   (-mean_absolute_error)
# 	438.68s	 = Training   runtime
# 	4.44s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1708.13s of the 2908.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0716	 = Validation score   (-mean_absolute_error)
# 	10.53s	 = Training   runtime
# 	2.54s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1688.55s of the 2888.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	520.24s	 = Training   runtime
# 	2.1s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1161.55s of the 2361.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0716	 = Validation score   (-mean_absolute_error)
# 	10.41s	 = Training   runtime
# 	1.83s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2342.19s of remaining time.
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	5.55s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 2336.47s of the 2336.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0714	 = Validation score   (-mean_absolute_error)
# 	19.1s	 = Training   runtime
# 	2.13s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 2309.86s of the 2309.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	10.09s	 = Training   runtime
# 	1.14s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 2293.02s of the 2292.95s of remaining time.
# 	-0.0714	 = Validation score   (-mean_absolute_error)
# 	64.3s	 = Training   runtime
# 	8.72s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 2219.24s of the 2219.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0712	 = Validation score   (-mean_absolute_error)
# 	285.34s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1926.61s of the 1926.55s of remaining time.
# 	-0.0718	 = Validation score   (-mean_absolute_error)
# 	11.78s	 = Training   runtime
# 	9.87s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1904.17s of the 1904.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0649	 = Validation score   (-mean_absolute_error)
# 	492.49s	 = Training   runtime
# 	4.33s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 1401.61s of the 1401.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0713	 = Validation score   (-mean_absolute_error)
# 	12.9s	 = Training   runtime
# 	2.96s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1377.29s of the 1377.23s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	706.47s	 = Training   runtime
# 	3.42s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 663.92s of the 663.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-0.0713	 = Validation score   (-mean_absolute_error)
# 	8.07s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 646.92s of remaining time.
# 	-0.0386	 = Validation score   (-mean_absolute_error)
# 	6.17s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 2959.74s ... Best model: "WeightedEnsemble_L3"
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	2.67s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	2.96s	 = Training   runtime
# Fitting model: RandomForestMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	14.32s	 = Training   runtime
# 	11.38s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	45.22s	 = Training   runtime
# Fitting model: ExtraTreesMSE_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	6.05s	 = Training   runtime
# 	10.91s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 9.
# 	119.9s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	3.85s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	84.72s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	4.03s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	115.21s	 = Training   runtime
# Refit complete, total runtime = 395.72s
# Deleting model LightGBMXT_BAG_L1. All files under AutogluonModels/ag-20230712_213230/models/LightGBMXT_BAG_L1/ will be removed.
# Deleting model LightGBM_BAG_L1. All files under AutogluonModels/ag-20230712_213230/models/LightGBM_BAG_L1/ will be removed.
# Deleting model RandomForestMSE_BAG_L1. All files under AutogluonModels/ag-20230712_213230/models/RandomForestMSE_BAG_L1/ will be removed.
# Deleting model CatBoost_BAG_L1. All files under AutogluonModels/ag-20230712_213230/models/CatBoost_BAG_L1/ will be removed.
# Deleting model ExtraTreesMSE_BAG_L1. All files under AutogluonModels/ag-20230712_213230/models/ExtraTreesMSE_BAG_L1/ will be removed.
# Deleting model NeuralNetFastAI_BAG_L1. All files under AutogluonModels/ag-20230712_213230/models/NeuralNetFastAI_BAG_L1/ will be removed.
# Deleting model XGBoost_BAG_L1. All files under AutogluonModels/ag-20230712_213230/models/XGBoost_BAG_L1/ will be removed.
# Deleting model NeuralNetTorch_BAG_L1. All files under AutogluonModels/ag-20230712_213230/models/NeuralNetTorch_BAG_L1/ will be removed.
# Deleting model LightGBMLarge_BAG_L1. All files under AutogluonModels/ag-20230712_213230/models/LightGBMLarge_BAG_L1/ will be removed.
# Deleting model WeightedEnsemble_L2. All files under AutogluonModels/ag-20230712_213230/models/WeightedEnsemble_L2/ will be removed.
# Deleting model LightGBMXT_BAG_L2. All files under AutogluonModels/ag-20230712_213230/models/LightGBMXT_BAG_L2/ will be removed.
# Deleting model LightGBM_BAG_L2. All files under AutogluonModels/ag-20230712_213230/models/LightGBM_BAG_L2/ will be removed.
# Deleting model RandomForestMSE_BAG_L2. All files under AutogluonModels/ag-20230712_213230/models/RandomForestMSE_BAG_L2/ will be removed.
# Deleting model CatBoost_BAG_L2. All files under AutogluonModels/ag-20230712_213230/models/CatBoost_BAG_L2/ will be removed.
# Deleting model ExtraTreesMSE_BAG_L2. All files under AutogluonModels/ag-20230712_213230/models/ExtraTreesMSE_BAG_L2/ will be removed.
# Deleting model NeuralNetFastAI_BAG_L2. All files under AutogluonModels/ag-20230712_213230/models/NeuralNetFastAI_BAG_L2/ will be removed.
# Deleting model XGBoost_BAG_L2. All files under AutogluonModels/ag-20230712_213230/models/XGBoost_BAG_L2/ will be removed.
# Deleting model NeuralNetTorch_BAG_L2. All files under AutogluonModels/ag-20230712_213230/models/NeuralNetTorch_BAG_L2/ will be removed.
# Deleting model LightGBMLarge_BAG_L2. All files under AutogluonModels/ag-20230712_213230/models/LightGBMLarge_BAG_L2/ will be removed.
# Deleting model WeightedEnsemble_L3. All files under AutogluonModels/ag-20230712_213230/models/WeightedEnsemble_L3/ will be removed.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230712_213230/")
# CPU times: user 4h 10min 18s, sys: 6min 6s, total: 4h 16min 24s
# Wall time: 55min 57s

# %%
y_pred = predictor.predict(test_data)

# %%
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: mean_absolute_error on test data: -0.039985124080001655
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.039985124080001655,
#     "root_mean_squared_error": -0.2148612248759777,
#     "mean_squared_error": -0.04616534595520546,
#     "r2": -0.035874364232121536,
#     "pearsonr": -0.0005947207224915478,
#     "median_absolute_error": -5.265974878376767e-10
# }

# %%
# predictor.evaluate(test_data)
perf = predictor.evaluate(test_data)
# Out:
# /home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/predictor/predictor.py:1420: FutureWarning: Calling `predictor.predict_proba` when problem_type=regression will raise an AssertionError starting in AutoGluon v0.8. Please call `predictor.predict` instead.
#   warnings.warn(
# Evaluation: mean_absolute_error on test data: -0.039985124080001655
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.039985124080001655,
#     "root_mean_squared_error": -0.2148612248759777,
#     "mean_squared_error": -0.04616534595520546,
#     "r2": -0.035874364232121536,
#     "pearsonr": -0.0005947207224915478,
#     "median_absolute_error": -5.265974878376767e-10
# }

# %%
predictor.leaderboard(test_data, silent=True).T
# Out:
#                                                   0  \
# model                    NeuralNetTorch_BAG_L2_FULL
# score_test                                -0.039985
# score_val                                      None
# pred_time_test                             6.736088
# pred_time_val                                   NaN
# fit_time                                 398.930475
# pred_time_test_marginal                    1.435956
# pred_time_val_marginal                          NaN
# fit_time_marginal                        115.206081
# stack_level                                       2
# can_infer                                      True
# fit_order                                        10
#
#                                                   1                     2  \
# model                    NeuralNetTorch_BAG_L1_FULL  LightGBM_BAG_L1_FULL
# score_test                                -0.039985             -0.072449
# score_val                                      None                  None
# pred_time_test                             0.813852              0.244048
# pred_time_val                                   NaN                   NaN
# fit_time                                  84.723778              2.963454
# pred_time_test_marginal                    0.813852              0.244048
# pred_time_val_marginal                          NaN                   NaN
# fit_time_marginal                         84.723778              2.963454
# stack_level                                       1                     1
# can_infer                                      True                  True
# fit_order                                         8                     2
#
#                                                  3                     4  \
# model                    LightGBMLarge_BAG_L1_FULL  CatBoost_BAG_L1_FULL
# score_test                               -0.072554             -0.072579
# score_val                                     None                  None
# pred_time_test                            0.226939              0.115118
# pred_time_val                                  NaN                   NaN
# fit_time                                  4.027113             45.219395
# pred_time_test_marginal                   0.226939              0.115118
# pred_time_val_marginal                         NaN                   NaN
# fit_time_marginal                         4.027113             45.219395
# stack_level                                      1                     1
# can_infer                                     True                  True
# fit_order                                        9                     4
#
#                                            5                       6  \
# model                    XGBoost_BAG_L1_FULL  LightGBMXT_BAG_L1_FULL
# score_test                         -0.072585               -0.072935
# score_val                               None                    None
# pred_time_test                      0.931852                0.229492
# pred_time_val                            NaN                     NaN
# fit_time                            3.849601                2.674958
# pred_time_test_marginal             0.931852                0.229492
# pred_time_val_marginal                   NaN                     NaN
# fit_time_marginal                   3.849601                2.674958
# stack_level                                1                       1
# can_infer                               True                    True
# fit_order                                  7                       1
#
#                                                    7  \
# model                    RandomForestMSE_BAG_L1_FULL
# score_test                                 -0.073796
# score_val                                       None
# pred_time_test                              0.559488
# pred_time_val                              11.376645
# fit_time                                   14.319179
# pred_time_test_marginal                     0.559488
# pred_time_val_marginal                     11.376645
# fit_time_marginal                          14.319179
# stack_level                                        1
# can_infer                                       True
# fit_order                                          3
#
#                                                  8  \
# model                    ExtraTreesMSE_BAG_L1_FULL
# score_test                               -0.073871
# score_val                                     None
# pred_time_test                            0.541274
# pred_time_val                            10.909958
# fit_time                                  6.050726
# pred_time_test_marginal                   0.541274
# pred_time_val_marginal                   10.909958
# fit_time_marginal                         6.050726
# stack_level                                      1
# can_infer                                     True
# fit_order                                        5
#
#                                                    9
# model                    NeuralNetFastAI_BAG_L1_FULL
# score_test                                 -0.075979
# score_val                                       None
# pred_time_test                               1.63807
# pred_time_val                                    NaN
# fit_time                                   119.89619
# pred_time_test_marginal                      1.63807
# pred_time_val_marginal                           NaN
# fit_time_marginal                          119.89619
# stack_level                                        1
# can_infer                                       True
# fit_order                                          6

# %%
predictor.leaderboard(extra_info=True, silent=True).T
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                          0  \
# model                                                                                                                                                                                                                                                                                                                                                                                            ExtraTreesMSE_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                    10.909958
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                          6.050726
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                           10.909958
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                 6.050726
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                5
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                      209004058
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                          209004058
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                  209004058
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                      209004058
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                   XTModel
# hyperparameters                                                                                                                                                                                                                                                                           {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True, 'use_child_oof': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                    {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 15}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                            {'n_estimators': 300}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          1  \
# model                                                                                                                                                                                                                                                                                                                                                                                          RandomForestMSE_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                    11.376645
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                         14.319179
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                           11.376645
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                14.319179
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                3
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                      182889021
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                          182889021
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                  182889021
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                      182889021
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                   RFModel
# hyperparameters                                                                                                                                                                                                                                                                           {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True, 'use_child_oof': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                    {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 15}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                            {'n_estimators': 300}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          2  \
# model                                                                                                                                                                                                                                                                                                                                                                                                  XGBoost_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                          NaN
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                          3.849601
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                 3.849601
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                7
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                         654518
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                             654518
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                     654518
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                         654518
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                              XGBoostModel
# hyperparameters                                                                                                                                                                                                                                                                                                  {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                           {'max_memory_usage_ratio': 1.15, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                     {'n_estimators': 150, 'learning_rate': 0.1, 'n_jobs': -1, 'proc.max_category_levels': 100, 'objective': 'reg:squarederror', 'booster': 'gbtree'}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                            {'n_estimators': 150}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             3  \
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NeuralNetTorch_BAG_L2_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           398.930475
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  115.206081
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 2
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  10
# num_features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               19
# num_models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     10
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            350910
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             402003476
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        350910
# ...
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                   {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 5, 'num_boost_round': 323}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                         {'num_boost_round': 323}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          9
# model                                                                                                                                                                                                                                                                                                                                                                                                 CatBoost_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                          NaN
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                         45.219395
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                45.219395
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                4
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                        1565444
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                            1565444
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                    1565444
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                        1565444
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                             CatBoostModel
# hyperparameters                                                                                                                                                                                                                                                                                                  {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                           {'max_memory_usage_ratio': 1.15, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                    {'iterations': 1049, 'learning_rate': 0.05, 'random_seed': 0, 'allow_writing_files': False, 'eval_metric': 'MAE'}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                             {'iterations': 1049}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]

# %%
predictor.get_model_best()
# Out:
# 'NeuralNetTorch_BAG_L2_FULL'

# %%
predictor.feature_importance(test_data)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	63.81s	= Expected runtime (12.76s per shuffle set)
# 	16.79s	= Actual runtime (Completed 5 of 5 shuffle sets)
#               importance        stddev   p_value  n      p99_high  \
# DrivAge     4.471766e-08  1.381623e-08  0.000967  5  7.316545e-08
# BonusMalus  1.496160e-08  8.122685e-09  0.007314  5  3.168632e-08
# VehAge      2.569706e-09  9.655921e-09  0.291911  5  2.245138e-08
# Density    -1.213854e-10  6.785952e-09  0.514994  5  1.385098e-08
# Region     -1.892288e-09  1.379936e-08  0.612788  5  2.652079e-08
# VehGas     -2.629924e-09  1.069423e-08  0.694173  5  1.938964e-08
# VehPower   -4.249046e-09  1.015251e-08  0.798832  5  1.665512e-08
# VehBrand   -4.497578e-09  8.998506e-09  0.836839  5  1.403047e-08
# Exposure   -5.499111e-09  5.949281e-09  0.946194  5  6.750541e-09
# Area       -9.375130e-09  1.660300e-08  0.862342  5  2.481069e-08
#
#                  p99_low
# DrivAge     1.626986e-08
# BonusMalus -1.763118e-09
# VehAge     -1.731197e-08
# Density    -1.409375e-08
# Region     -3.030537e-08
# VehGas     -2.464949e-08
# VehPower   -2.515321e-08
# VehBrand   -2.302563e-08
# Exposure   -1.774876e-08
# Area       -4.356095e-08

# %% [markdown]
# ## Model 5

# %%
# %%time

predictor_light = TabularPredictor(
    label=label, 
    eval_metric=metric,
    problem_type="regression"
).fit(
    train_data,
    time_limit=time_limit,
    hyperparameters='very_light', 

)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230712_222912/"
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230712_222912/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    95036.41 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.3s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.37s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.01, Train Rows: 470017, Val Rows: 4748
# Fitting 7 L1 models ...
# Fitting model: LightGBMXT ... Training model for up to 3598.63s of the 3598.63s of remaining time.
# 	-0.0752	 = Validation score   (-mean_absolute_error)
# 	4.15s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3594.32s of the 3594.32s of remaining time.
# 	-0.0745	 = Validation score   (-mean_absolute_error)
# 	2.94s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 3591.24s of the 3591.24s of remaining time.
# 	-0.0748	 = Validation score   (-mean_absolute_error)
# 	47.12s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 3543.99s of the 3543.99s of remaining time.
# No improvement since epoch 8: early stopping
# 	-0.0703	 = Validation score   (-mean_absolute_error)
# 	331.09s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 3212.49s of the 3212.48s of remaining time.
# 	-0.0747	 = Validation score   (-mean_absolute_error)
# 	4.36s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 3207.99s of the 3207.98s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	368.1s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 2839.76s of the 2839.76s of remaining time.
# 	-0.0746	 = Validation score   (-mean_absolute_error)
# 	3.54s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2836.04s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	0.29s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 764.82s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230712_222912/")
# CPU times: user 5h 42min 6s, sys: 8min 22s, total: 5h 50min 29s
# Wall time: 12min 45s

# %%
y_pred = predictor.predict(test_data)

# %%
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: mean_absolute_error on test data: -0.039985124080001655
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.039985124080001655,
#     "root_mean_squared_error": -0.2148612248759777,
#     "mean_squared_error": -0.04616534595520546,
#     "r2": -0.035874364232121536,
#     "pearsonr": -0.0005947207224915478,
#     "median_absolute_error": -5.265974878376767e-10
# }

# %%
# predictor.evaluate(test_data)
perf = predictor.evaluate(test_data)
# Out:
# /home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/predictor/predictor.py:1420: FutureWarning: Calling `predictor.predict_proba` when problem_type=regression will raise an AssertionError starting in AutoGluon v0.8. Please call `predictor.predict` instead.
#   warnings.warn(
# Evaluation: mean_absolute_error on test data: -0.039985124080001655
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.039985124080001655,
#     "root_mean_squared_error": -0.2148612248759777,
#     "mean_squared_error": -0.04616534595520546,
#     "r2": -0.035874364232121536,
#     "pearsonr": -0.0005947207224915478,
#     "median_absolute_error": -5.265974878376767e-10
# }

# %%
predictor.leaderboard(test_data, silent=True).T
# Out:
#                                                   0  \
# model                    NeuralNetTorch_BAG_L2_FULL
# score_test                                -0.039985
# score_val                                      None
# pred_time_test                            23.384678
# pred_time_val                                   NaN
# fit_time                                 398.930475
# pred_time_test_marginal                     1.35945
# pred_time_val_marginal                          NaN
# fit_time_marginal                        115.206081
# stack_level                                       2
# can_infer                                      True
# fit_order                                        10
#
#                                                   1                     2  \
# model                    NeuralNetTorch_BAG_L1_FULL  LightGBM_BAG_L1_FULL
# score_test                                -0.039985             -0.072449
# score_val                                      None                  None
# pred_time_test                             1.014436               0.64316
# pred_time_val                                   NaN                   NaN
# fit_time                                  84.723778              2.963454
# pred_time_test_marginal                    1.014436               0.64316
# pred_time_val_marginal                          NaN                   NaN
# fit_time_marginal                         84.723778              2.963454
# stack_level                                       1                     1
# can_infer                                      True                  True
# fit_order                                         8                     2
#
#                                                  3                     4  \
# model                    LightGBMLarge_BAG_L1_FULL  CatBoost_BAG_L1_FULL
# score_test                               -0.072554             -0.072579
# score_val                                     None                  None
# pred_time_test                            0.236408              0.340681
# pred_time_val                                  NaN                   NaN
# fit_time                                  4.027113             45.219395
# pred_time_test_marginal                   0.236408              0.340681
# pred_time_val_marginal                         NaN                   NaN
# fit_time_marginal                         4.027113             45.219395
# stack_level                                      1                     1
# can_infer                                     True                  True
# fit_order                                        9                     4
#
#                                            5                       6  \
# model                    XGBoost_BAG_L1_FULL  LightGBMXT_BAG_L1_FULL
# score_test                         -0.072585               -0.072935
# score_val                               None                    None
# pred_time_test                      1.052875                0.445999
# pred_time_val                            NaN                     NaN
# fit_time                            3.849601                2.674958
# pred_time_test_marginal             1.052875                0.445999
# pred_time_val_marginal                   NaN                     NaN
# fit_time_marginal                   3.849601                2.674958
# stack_level                                1                       1
# can_infer                               True                    True
# fit_order                                  7                       1
#
#                                                    7  \
# model                    RandomForestMSE_BAG_L1_FULL
# score_test                                 -0.073796
# score_val                                       None
# pred_time_test                              1.236068
# pred_time_val                              11.376645
# fit_time                                   14.319179
# pred_time_test_marginal                     1.236068
# pred_time_val_marginal                     11.376645
# fit_time_marginal                          14.319179
# stack_level                                        1
# can_infer                                       True
# fit_order                                          3
#
#                                                  8  \
# model                    ExtraTreesMSE_BAG_L1_FULL
# score_test                               -0.073871
# score_val                                     None
# pred_time_test                            1.176018
# pred_time_val                            10.909958
# fit_time                                  6.050726
# pred_time_test_marginal                   1.176018
# pred_time_val_marginal                   10.909958
# fit_time_marginal                         6.050726
# stack_level                                      1
# can_infer                                     True
# fit_order                                        5
#
#                                                    9
# model                    NeuralNetFastAI_BAG_L1_FULL
# score_test                                 -0.075979
# score_val                                       None
# pred_time_test                             15.879586
# pred_time_val                                    NaN
# fit_time                                   119.89619
# pred_time_test_marginal                    15.879586
# pred_time_val_marginal                           NaN
# fit_time_marginal                          119.89619
# stack_level                                        1
# can_infer                                       True
# fit_order                                          6

# %%
predictor.leaderboard(extra_info=True, silent=True).T
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                          0  \
# model                                                                                                                                                                                                                                                                                                                                                                                            ExtraTreesMSE_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                    10.909958
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                          6.050726
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                           10.909958
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                 6.050726
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                5
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                      209004058
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                          209004058
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                  209004058
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                      209004058
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                   XTModel
# hyperparameters                                                                                                                                                                                                                                                                           {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True, 'use_child_oof': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                    {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 15}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                            {'n_estimators': 300}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          1  \
# model                                                                                                                                                                                                                                                                                                                                                                                          RandomForestMSE_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                    11.376645
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                         14.319179
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                           11.376645
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                14.319179
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                3
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                      182889021
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                          182889021
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                  182889021
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                      182889021
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                   RFModel
# hyperparameters                                                                                                                                                                                                                                                                           {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True, 'use_child_oof': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                    {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 15}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                            {'n_estimators': 300}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          2  \
# model                                                                                                                                                                                                                                                                                                                                                                                                  XGBoost_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                          NaN
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                          3.849601
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                 3.849601
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                7
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                         654518
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                             654518
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                     654518
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                         654518
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                              XGBoostModel
# hyperparameters                                                                                                                                                                                                                                                                                                  {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                           {'max_memory_usage_ratio': 1.15, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                     {'n_estimators': 150, 'learning_rate': 0.1, 'n_jobs': -1, 'proc.max_category_levels': 100, 'objective': 'reg:squarederror', 'booster': 'gbtree'}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                            {'n_estimators': 150}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             3  \
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NeuralNetTorch_BAG_L2_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           398.930475
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  115.206081
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 2
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  10
# num_features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               19
# num_models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     10
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            350912
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             402003482
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        350912
# ...
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                   {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 5, 'num_boost_round': 323}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                         {'num_boost_round': 323}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          9
# model                                                                                                                                                                                                                                                                                                                                                                                                 CatBoost_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                          NaN
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                         45.219395
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                45.219395
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                4
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                        1565444
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                            1565444
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                    1565444
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                        1565444
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                             CatBoostModel
# hyperparameters                                                                                                                                                                                                                                                                                                  {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                           {'max_memory_usage_ratio': 1.15, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                    {'iterations': 1049, 'learning_rate': 0.05, 'random_seed': 0, 'allow_writing_files': False, 'eval_metric': 'MAE'}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                             {'iterations': 1049}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]

# %%
predictor.get_model_best()
# Out:
# 'NeuralNetTorch_BAG_L2_FULL'

# %%
predictor.feature_importance(test_data)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	433.26s	= Expected runtime (86.65s per shuffle set)
# 	53.82s	= Actual runtime (Completed 5 of 5 shuffle sets)
#               importance        stddev   p_value  n      p99_high  \
# DrivAge     4.471766e-08  1.381623e-08  0.000967  5  7.316545e-08
# BonusMalus  1.496160e-08  8.122685e-09  0.007314  5  3.168632e-08
# VehAge      2.569706e-09  9.655921e-09  0.291911  5  2.245138e-08
# Density    -1.213854e-10  6.785952e-09  0.514994  5  1.385098e-08
# Region     -1.892288e-09  1.379936e-08  0.612788  5  2.652079e-08
# VehGas     -2.629924e-09  1.069423e-08  0.694173  5  1.938964e-08
# VehPower   -4.249046e-09  1.015251e-08  0.798832  5  1.665512e-08
# VehBrand   -4.497578e-09  8.998506e-09  0.836839  5  1.403047e-08
# Exposure   -5.499111e-09  5.949281e-09  0.946194  5  6.750541e-09
# Area       -9.375130e-09  1.660300e-08  0.862342  5  2.481069e-08
#
#                  p99_low
# DrivAge     1.626986e-08
# BonusMalus -1.763118e-09
# VehAge     -1.731197e-08
# Density    -1.409375e-08
# Region     -3.030537e-08
# VehGas     -2.464949e-08
# VehPower   -2.515321e-08
# VehBrand   -2.302563e-08
# Exposure   -1.774876e-08
# Area       -4.356095e-08

# %% [markdown]
# ## Model 6

# %%
# %%time

excluded_model_types = ['KNN', 'NN', 'custom']

predictor_light = TabularPredictor(
    label=label, 
    eval_metric=metric,
    problem_type="regression"
).fit(
    train_data,
    time_limit=time_limit,
    excluded_model_types=excluded_model_types
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20230712_224335/"
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutogluonModels/ag-20230712_224335/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    474765
# Train Data Columns: 10
# Label Column: ClaimNb
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    85038.32 MB
# 	Train Data (Original)  Memory Usage: 141.07 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['Exposure']
# 		('int', [])    : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('object', []) : 4 | ['VehBrand', 'VehGas', 'Area', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 3 | ['VehBrand', 'Area', 'Region']
# 		('float', [])     : 1 | ['Exposure']
# 		('int', [])       : 5 | ['VehPower', 'VehAge', 'DrivAge', 'BonusMalus', 'Density']
# 		('int', ['bool']) : 1 | ['VehGas']
# 	1.3s = Fit runtime
# 	10 features in original data used to generate 10 features in processed data.
# 	Train Data (Processed) Memory Usage: 24.69 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 1.41s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mean_absolute_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.01, Train Rows: 470017, Val Rows: 4748
# Excluded Model Types: ['KNN', 'NN', 'custom']
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# 	Found 'KNN' model in hyperparameters, but 'KNN' is present in `excluded_model_types` and will be removed.
# Fitting 9 L1 models ...
# Fitting model: LightGBMXT ... Training model for up to 3598.59s of the 3598.58s of remaining time.
# 	-0.0752	 = Validation score   (-mean_absolute_error)
# 	37.97s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 3560.43s of the 3560.43s of remaining time.
# 	-0.0745	 = Validation score   (-mean_absolute_error)
# 	14.93s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE ... Training model for up to 3545.36s of the 3545.35s of remaining time.
# 	-0.0803	 = Validation score   (-mean_absolute_error)
# 	24.47s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 3518.59s of the 3518.59s of remaining time.
# 	-0.0748	 = Validation score   (-mean_absolute_error)
# 	56.68s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE ... Training model for up to 3461.78s of the 3461.77s of remaining time.
# 	-0.0783	 = Validation score   (-mean_absolute_error)
# 	10.38s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 3449.48s of the 3449.47s of remaining time.
# 	-0.069	 = Validation score   (-mean_absolute_error)
# 	468.55s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 2980.59s of the 2980.59s of remaining time.
# 	-0.0747	 = Validation score   (-mean_absolute_error)
# 	4.2s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch ... Training model for up to 2976.23s of the 2976.23s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	407.62s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 2568.47s of the 2568.47s of remaining time.
# 	-0.0746	 = Validation score   (-mean_absolute_error)
# 	3.68s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 2564.6s of remaining time.
# 	-0.0423	 = Validation score   (-mean_absolute_error)
# 	0.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1036.42s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20230712_224335/")
# CPU times: user 7h 11min 6s, sys: 8min 43s, total: 7h 19min 50s
# Wall time: 17min 16s

# %%
y_pred = predictor.predict(test_data)

# %%
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: mean_absolute_error on test data: -0.039985124080001655
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.039985124080001655,
#     "root_mean_squared_error": -0.2148612248759777,
#     "mean_squared_error": -0.04616534595520546,
#     "r2": -0.035874364232121536,
#     "pearsonr": -0.0005947207224915478,
#     "median_absolute_error": -5.265974878376767e-10
# }

# %%
# predictor.evaluate(test_data)
perf = predictor.evaluate(test_data)
# Out:
# /home/stever7/.local/lib/python3.9/site-packages/autogluon/tabular/predictor/predictor.py:1420: FutureWarning: Calling `predictor.predict_proba` when problem_type=regression will raise an AssertionError starting in AutoGluon v0.8. Please call `predictor.predict` instead.
#   warnings.warn(
# Evaluation: mean_absolute_error on test data: -0.039985124080001655
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "mean_absolute_error": -0.039985124080001655,
#     "root_mean_squared_error": -0.2148612248759777,
#     "mean_squared_error": -0.04616534595520546,
#     "r2": -0.035874364232121536,
#     "pearsonr": -0.0005947207224915478,
#     "median_absolute_error": -5.265974878376767e-10
# }

# %%
predictor.leaderboard(test_data, silent=True).T
# Out:
#                                                   0  \
# model                    NeuralNetTorch_BAG_L2_FULL
# score_test                                -0.039985
# score_val                                      None
# pred_time_test                             6.380435
# pred_time_val                                   NaN
# fit_time                                 398.930475
# pred_time_test_marginal                    1.343362
# pred_time_val_marginal                          NaN
# fit_time_marginal                        115.206081
# stack_level                                       2
# can_infer                                      True
# fit_order                                        10
#
#                                                   1                     2  \
# model                    NeuralNetTorch_BAG_L1_FULL  LightGBM_BAG_L1_FULL
# score_test                                -0.039985             -0.072449
# score_val                                      None                  None
# pred_time_test                             0.805619              0.240018
# pred_time_val                                   NaN                   NaN
# fit_time                                  84.723778              2.963454
# pred_time_test_marginal                    0.805619              0.240018
# pred_time_val_marginal                          NaN                   NaN
# fit_time_marginal                         84.723778              2.963454
# stack_level                                       1                     1
# can_infer                                      True                  True
# fit_order                                         8                     2
#
#                                                  3                     4  \
# model                    LightGBMLarge_BAG_L1_FULL  CatBoost_BAG_L1_FULL
# score_test                               -0.072554             -0.072579
# score_val                                     None                  None
# pred_time_test                            0.219945              0.114091
# pred_time_val                                  NaN                   NaN
# fit_time                                  4.027113             45.219395
# pred_time_test_marginal                   0.219945              0.114091
# pred_time_val_marginal                         NaN                   NaN
# fit_time_marginal                         4.027113             45.219395
# stack_level                                      1                     1
# can_infer                                     True                  True
# fit_order                                        9                     4
#
#                                            5                       6  \
# model                    XGBoost_BAG_L1_FULL  LightGBMXT_BAG_L1_FULL
# score_test                         -0.072585               -0.072935
# score_val                               None                    None
# pred_time_test                      0.676029                0.250628
# pred_time_val                            NaN                     NaN
# fit_time                            3.849601                2.674958
# pred_time_test_marginal             0.676029                0.250628
# pred_time_val_marginal                   NaN                     NaN
# fit_time_marginal                   3.849601                2.674958
# stack_level                                1                       1
# can_infer                               True                    True
# fit_order                                  7                       1
#
#                                                    7  \
# model                    RandomForestMSE_BAG_L1_FULL
# score_test                                 -0.073796
# score_val                                       None
# pred_time_test                              0.561873
# pred_time_val                              11.376645
# fit_time                                   14.319179
# pred_time_test_marginal                     0.561873
# pred_time_val_marginal                     11.376645
# fit_time_marginal                          14.319179
# stack_level                                        1
# can_infer                                       True
# fit_order                                          3
#
#                                                  8  \
# model                    ExtraTreesMSE_BAG_L1_FULL
# score_test                               -0.073871
# score_val                                     None
# pred_time_test                            0.515901
# pred_time_val                            10.909958
# fit_time                                  6.050726
# pred_time_test_marginal                   0.515901
# pred_time_val_marginal                   10.909958
# fit_time_marginal                         6.050726
# stack_level                                      1
# can_infer                                     True
# fit_order                                        5
#
#                                                    9
# model                    NeuralNetFastAI_BAG_L1_FULL
# score_test                                 -0.075979
# score_val                                       None
# pred_time_test                               1.65297
# pred_time_val                                    NaN
# fit_time                                   119.89619
# pred_time_test_marginal                      1.65297
# pred_time_val_marginal                           NaN
# fit_time_marginal                          119.89619
# stack_level                                        1
# can_infer                                       True
# fit_order                                          6

# %%
predictor.leaderboard(extra_info=True, silent=True).T
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                          0  \
# model                                                                                                                                                                                                                                                                                                                                                                                            ExtraTreesMSE_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                    10.909958
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                          6.050726
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                           10.909958
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                 6.050726
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                5
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                      209004058
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                          209004058
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                  209004058
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                      209004058
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                   XTModel
# hyperparameters                                                                                                                                                                                                                                                                           {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True, 'use_child_oof': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                    {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 15}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                            {'n_estimators': 300}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          1  \
# model                                                                                                                                                                                                                                                                                                                                                                                          RandomForestMSE_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                    11.376645
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                         14.319179
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                           11.376645
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                14.319179
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                3
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                      182889021
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                          182889021
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                  182889021
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                      182889021
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                   RFModel
# hyperparameters                                                                                                                                                                                                                                                                           {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True, 'use_child_oof': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                    {'n_estimators': 300, 'max_leaf_nodes': 15000, 'n_jobs': -1, 'random_state': 0, 'bootstrap': True, 'criterion': 'squared_error', 'max_depth': 15}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                            {'n_estimators': 300}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          2  \
# model                                                                                                                                                                                                                                                                                                                                                                                                  XGBoost_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                          NaN
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                          3.849601
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                 3.849601
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                7
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                         654518
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                             654518
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                     654518
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                         654518
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                              XGBoostModel
# hyperparameters                                                                                                                                                                                                                                                                                                  {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                           {'max_memory_usage_ratio': 1.15, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                     {'n_estimators': 150, 'learning_rate': 0.1, 'n_jobs': -1, 'proc.max_category_levels': 100, 'objective': 'reg:squarederror', 'booster': 'gbtree'}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                            {'n_estimators': 150}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             3  \
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NeuralNetTorch_BAG_L2_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           398.930475
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  115.206081
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 2
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  10
# num_features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               19
# num_models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     10
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            350910
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             402003482
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        350910
# ...
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                   {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 5, 'num_boost_round': 323}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                         {'num_boost_round': 323}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          9
# model                                                                                                                                                                                                                                                                                                                                                                                                 CatBoost_BAG_L1_FULL
# score_val                                                                                                                                                                                                                                                                                                                                                                                                             None
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                          NaN
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                         45.219395
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                45.219395
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                              1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                             True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                4
# num_features                                                                                                                                                                                                                                                                                                                                                                                                            10
# num_models                                                                                                                                                                                                                                                                                                                                                                                                               1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                   1
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                        1565444
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                            1565444
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                    1565444
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                        1565444
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                            0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                          1
# model_type                                                                                                                                                                                                                                                                                                                                                                                            StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                             CatBoostModel
# hyperparameters                                                                                                                                                                                                                                                                                                  {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                     {}
# ag_args_fit                           {'max_memory_usage_ratio': 1.15, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                                                                                        [VehPower, Exposure, VehBrand, VehAge, BonusMalus, Density, Region, DrivAge, VehGas, Area]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                          None
# child_hyperparameters                                                                                                                                                                                                                                                                                    {'iterations': 1049, 'learning_rate': 0.05, 'random_seed': 0, 'allow_writing_files': False, 'eval_metric': 'MAE'}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                             {'iterations': 1049}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                               []
# descendants                                                                                                                                                                                                                                                                                                                                                                                   [NeuralNetTorch_BAG_L2_FULL]

# %%
predictor.get_model_best()
# Out:
# 'NeuralNetTorch_BAG_L2_FULL'

# %%
predictor.feature_importance(test_data)
# Out:
# Computing feature importance via permutation shuffling for 10 features using 5000 rows with 5 shuffle sets...
# 	58.62s	= Expected runtime (11.72s per shuffle set)
# 	17.42s	= Actual runtime (Completed 5 of 5 shuffle sets)
#               importance        stddev   p_value  n      p99_high  \
# DrivAge     4.471766e-08  1.381623e-08  0.000967  5  7.316545e-08
# BonusMalus  1.496160e-08  8.122685e-09  0.007314  5  3.168632e-08
# VehAge      2.569706e-09  9.655921e-09  0.291911  5  2.245138e-08
# Density    -1.213854e-10  6.785952e-09  0.514994  5  1.385098e-08
# Region     -1.892288e-09  1.379936e-08  0.612788  5  2.652079e-08
# VehGas     -2.629924e-09  1.069423e-08  0.694173  5  1.938964e-08
# VehPower   -4.249046e-09  1.015251e-08  0.798832  5  1.665512e-08
# VehBrand   -4.497578e-09  8.998506e-09  0.836839  5  1.403047e-08
# Exposure   -5.499111e-09  5.949281e-09  0.946194  5  6.750541e-09
# Area       -9.375130e-09  1.660300e-08  0.862342  5  2.481069e-08
#
#                  p99_low
# DrivAge     1.626986e-08
# BonusMalus -1.763118e-09
# VehAge     -1.731197e-08
# Density    -1.409375e-08
# Region     -3.030537e-08
# VehGas     -2.464949e-08
# VehPower   -2.515321e-08
# VehBrand   -2.302563e-08
# Exposure   -1.774876e-08
# Area       -4.356095e-08

# %% [markdown]
# ## Communicate

# %% [markdown]
# (skipped)
