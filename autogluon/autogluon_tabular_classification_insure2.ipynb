# %% [markdown]
# # AutoML: Build Production-Ready Models Quickly!
#
# https://www.linkedin.com/learning/automl-build-production-ready-models-quickly/

# %%
import numpy as np
from autogluon.tabular import TabularDataset, TabularPredictor
from autogluon.core.metrics import make_scorer
from sklearn.model_selection import train_test_split

# %%
# train_data = TabularDataset('../01-machine-learning-recap/data/train_data.csv')
train_data = TabularDataset('train_data_insure.csv')

# %%
train_data.head()
# Out:
#   Customer Id  YearOfObservation  Insured_Period  Residential  \
# 0      H14663               2013             1.0            0
# 1       H2037               2015             1.0            0
# 2       H3802               2014             1.0            0
# 3       H3834               2013             1.0            0
# 4       H5053               2014             1.0            0
#
#   Building_Painted Building_Fenced Garden Settlement  Building Dimension  \
# 0                N               V      V          U               290.0
# 1                V               N      O          R               490.0
# 2                N               V      V          U               595.0
# 3                V               V      V          U              2840.0
# 4                V               N      O          R               680.0
#
#    Building_Type  Date_of_Occupancy NumberOfWindows Geo_Code  Claim
# 0              1             1960.0               .     1053      0
# 1              1             1850.0               4     1053      0
# 2              1             1960.0               .     1053      0
# 3              1             1960.0               .     1053      0
# 4              1             1800.0               3     1053      0

# %%
train, test = train_test_split(train_data, test_size=0.3, shuffle=True)

# %%
EVAL_METRIC = "f1"
SAVE_PATH = "AutoGluonModels_improved"   # Trained models will be saved here
LABEL = "Claim"

# %% [markdown]
# ## Improving your AutoGluon Model

# %% [markdown]
# ### 1. Via Feature Engineering

# %%
train["age_of_building"] = train["YearOfObservation"] - train["Date_of_Occupancy"]
test["age_of_building"] = test["YearOfObservation"] - test["Date_of_Occupancy"]
train["YearOfObservation"] = train["YearOfObservation"].astype("category")
test["YearOfObservation"] = test["YearOfObservation"].astype("category")

# %% [markdown]
# ### 2. Use the Right Preset & refit_full

# %%
predictor = TabularPredictor(label=LABEL, path=SAVE_PATH, eval_metric=EVAL_METRIC)
predictor = predictor.fit(train, presets=['best_quality'], time_limit=100, refit_full='best')
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 100s
# AutoGluon will save models to "AutoGluonModels_improved/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    5012
# Train Data Columns: 14
# Label Column: Claim
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    234888.75 MB
# 	Train Data (Original)  Memory Usage: 2.33 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 4 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Unused Original Features (Count: 1): ['Customer Id']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['Customer Id']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['YearOfObservation']
# 		('float', [])    : 4 | ['Insured_Period', 'Building Dimension', 'Date_of_Occupancy', 'age_of_building']
# 		('int', [])      : 2 | ['Residential', 'Building_Type']
# 		('object', [])   : 6 | ['Building_Painted', 'Building_Fenced', 'Garden', 'Settlement', 'NumberOfWindows', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 4 | ['YearOfObservation', 'Garden', 'NumberOfWindows', 'Geo_Code']
# 		('float', [])     : 4 | ['Insured_Period', 'Building Dimension', 'Date_of_Occupancy', 'age_of_building']
# 		('int', [])       : 1 | ['Building_Type']
# 		('int', ['bool']) : 4 | ['Residential', 'Building_Painted', 'Building_Fenced', 'Settlement']
# 	0.1s = Fit runtime
# 	13 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.25 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.17s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# 	To change this, specify the eval_metric parameter of Predictor()
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 99.83s of the 99.83s of remaining time.
# 	0.2715	 = Validation score   (f1)
# 	0.34s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 89.64s of the 89.64s of remaining time.
# 	0.2851	 = Validation score   (f1)
# 	0.02s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 89.44s of the 89.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.3508	 = Validation score   (f1)
# 	6.78s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 65.2s of the 65.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.3659	 = Validation score   (f1)
# 	7.58s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 50.52s of the 50.52s of remaining time.
# 	0.3146	 = Validation score   (f1)
# 	0.93s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 48.88s of the 48.88s of remaining time.
# 	0.3135	 = Validation score   (f1)
# 	0.65s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 47.48s of the 47.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.2451	 = Validation score   (f1)
# 	6.8s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 33.56s of the 33.56s of remaining time.
# 	0.293	 = Validation score   (f1)
# 	0.65s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 32.14s of the 32.14s of remaining time.
# 	0.2733	 = Validation score   (f1)
# 	0.67s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 30.71s of the 30.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.3856	 = Validation score   (f1)
# 	13.43s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 10.81s of the 10.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.346	 = Validation score   (f1)
# 	8.7s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 99.83s of the -4.53s of remaining time.
# 	0.3858	 = Validation score   (f1)
# 	4.33s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 109.12s ... Best model: "WeightedEnsemble_L2"
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	1.54s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# 	Stopping at the best epoch learned earlier - 9.
# /home/stever7/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1609: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# 	2.08s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	4.33s	 = Training   runtime
# Refit complete, total runtime = 7.29s
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutoGluonModels_improved/")

# %%
predictor.leaderboard(extra_info=True, silent=True).head()
# Out:
#                     model  score_val  pred_time_val   fit_time  \
# 0     WeightedEnsemble_L2   0.385842       0.331863  24.537182
# 1  NeuralNetFastAI_BAG_L1   0.385602       0.209237  13.434163
# 2         LightGBM_BAG_L1   0.365923       0.110091   7.580386
# 3       LightGBMXT_BAG_L1   0.350797       0.109746   6.775502
# 4          XGBoost_BAG_L1   0.345977       0.172047   8.703592
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.012880           4.327517            2       True
# 1                0.209237          13.434163            1       True
# 2                0.110091           7.580386            1       True
# 3                0.109746           6.775502            1       True
# 4                0.172047           8.703592            1       True
#
#    fit_order  num_features  ...  \
# 0         12             2  ...
# 1         10            13  ...
# 2          4            13  ...
# 3          3            13  ...
# 4         11            13  ...
#
#                                                                                               hyperparameters  \
# 0  {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# 1   {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# 2   {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# 3   {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# 4   {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
#
#    hyperparameters_fit  \
# 0                   {}
# 1                   {}
# 2                   {}
# 3                   {}
# 4                   {}
#
#                                                                                                                                                                                                                                                                                                                                                                            ag_args_fit  \
# 0  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# 1  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# 2  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# 3  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# 4  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
#
#                                                                                                                                                                                                     features  \
# 0                                                                                                                                                                [NeuralNetFastAI_BAG_L1, LightGBMXT_BAG_L1]
# 1  [Residential, Settlement, YearOfObservation, Building_Painted, Building_Type, Date_of_Occupancy, NumberOfWindows, Insured_Period, Building_Fenced, Garden, Geo_Code, Building Dimension, age_of_building]
# 2  [Residential, Settlement, YearOfObservation, Building_Painted, Building_Type, Date_of_Occupancy, NumberOfWindows, Insured_Period, Building_Fenced, Garden, Geo_Code, Building Dimension, age_of_building]
# 3  [Residential, Settlement, YearOfObservation, Building_Painted, Building_Type, Date_of_Occupancy, NumberOfWindows, Insured_Period, Building_Fenced, Garden, Geo_Code, Building Dimension, age_of_building]
# 4  [Residential, Settlement, YearOfObservation, Building_Painted, Building_Type, Date_of_Occupancy, NumberOfWindows, Insured_Period, Building_Fenced, Garden, Geo_Code, Building Dimension, age_of_building]
#
#    compile_time  \
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
#
#                                                                                                                                                            child_hyperparameters  \
# 0                                                                                                                                                         {'ensemble_size': 100}
# 1  {'layers': None, 'emb_drop': 0.1, 'ps': 0.1, 'bs': 'auto', 'lr': 0.01, 'epochs': 'auto', 'early.stopping.min_delta': 0.0001, 'early.stopping.patience': 20, 'smoothing': 0.0}
# 2                                                                                                                                                        {'learning_rate': 0.05}
# 3                                                                                                                                   {'learning_rate': 0.05, 'extra_trees': True}
# 4                              {'n_estimators': 10000, 'learning_rate': 0.1, 'n_jobs': -1, 'proc.max_category_levels': 100, 'objective': 'binary:logistic', 'booster': 'gbtree'}
#
#          child_hyperparameters_fit  \
# 0            {'ensemble_size': 17}
# 1  {'epochs': 30, 'best_epoch': 9}
# 2         {'num_boost_round': 446}
# 3         {'num_boost_round': 524}
# 4            {'n_estimators': 433}
#
#                                                                                                                                                                                                                                                                                                                                                                                                              child_ag_args_fit  \
# 0                                          {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# 1  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': ['text_ngram', 'text_as_category'], 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# 2                                {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# 3                                {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# 4                                {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
#
#                                      ancestors            descendants
# 0  [NeuralNetFastAI_BAG_L1, LightGBMXT_BAG_L1]                     []
# 1                                           []  [WeightedEnsemble_L2]
# 2                                           []                     []
# 3                                           []  [WeightedEnsemble_L2]
# 4                                           []                     []
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 3. Via CustomMetrics

# %%
fp_cost = 1000  # Admin fees spent to investigate potential insurance claim
fn_cost = 10000 # Average insurance claim made
tp_cost = 1000 # Admin fees spent to investigate potential insurance claim
tn_cost = 0

# %%
def cost_fn(y_true, y_prob):
    tp = np.where((y_prob >= 0.7) & (y_true==1), tp_cost, 0)
    fp = np.where((y_prob >= 0.7) & (y_true==0), fp_cost, 0)
    tn = np.where((y_prob < 0.7) & (y_true==0), tn_cost, 0)
    fn = np.where((y_prob < 0.7) & (y_true==1), fn_cost, 0)
    return np.sum([tp,fp,tn,fn])

# %%
my_scorer = make_scorer(
    name="operating_cost",
    score_func=cost_fn,
    greater_is_better=False,
    needs_proba=True
)

# %%
predictor.leaderboard(test, extra_metrics=[my_scorer], silent=True).head()
# Out:
#                     model  score_test  operating_cost  score_val  \
# 0         LightGBM_BAG_L1    0.376694        -4308000   0.365923
# 1          XGBoost_BAG_L1    0.363636        -4385000   0.345977
# 2       LightGBMXT_BAG_L1    0.362869        -4374000   0.350797
# 3     WeightedEnsemble_L2    0.362468        -4244000   0.385842
# 4  NeuralNetFastAI_BAG_L1    0.360153        -4214000   0.385602
#
#    pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0        0.143363       0.110091   7.580386                 0.143363
# 1        0.310239       0.172047   8.703592                 0.310239
# 2        0.161988       0.109746   6.775502                 0.161988
# 3        0.574867       0.331863  24.537182                 0.004168
# 4        0.408712       0.209237  13.434163                 0.408712
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.110091           7.580386            1       True
# 1                0.172047           8.703592            1       True
# 2                0.109746           6.775502            1       True
# 3                0.012880           4.327517            2       True
# 4                0.209237          13.434163            1       True
#
#    fit_order
# 0          4
# 1         11
# 2          3
# 3         12
# 4         10
