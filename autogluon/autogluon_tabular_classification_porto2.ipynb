# %% [markdown]
# # AutoML: Build Production-Ready Models Quickly!
#
# ## Classification with Porto Seguro - Part 2
#
# https://www.linkedin.com/learning/automl-build-production-ready-models-quickly/

# %%
import numpy as np
from autogluon.tabular import TabularDataset, TabularPredictor
from autogluon.core.metrics import make_scorer
# from sklearn.model_selection import train_test_split

# %%
# train_data = TabularDataset('../01-machine-learning-recap/data/train_data.csv')
# train_data = TabularDataset('train_data_insure.csv')
train_data = TabularDataset("porto_train.csv")
test_data = TabularDataset("porto_test.csv")

# %%
train_data.head().T
# Out:
#                         0          1           2          3          4
# id               9.000000  13.000000   16.000000  17.000000  20.000000
# target           0.000000   0.000000    0.000000   0.000000   0.000000
# ps_ind_01        1.000000   5.000000    0.000000   0.000000   2.000000
# ps_ind_02_cat    1.000000   4.000000    1.000000   2.000000   1.000000
# ps_ind_03        7.000000   9.000000    2.000000   0.000000   3.000000
# ps_ind_04_cat    0.000000   1.000000    0.000000   1.000000   1.000000
# ps_ind_05_cat    0.000000   0.000000    0.000000   0.000000   0.000000
# ps_ind_06_bin    0.000000   0.000000    1.000000   1.000000   0.000000
# ps_ind_07_bin    0.000000   0.000000    0.000000   0.000000   1.000000
# ps_ind_08_bin    1.000000   1.000000    0.000000   0.000000   0.000000
# ps_ind_09_bin    0.000000   0.000000    0.000000   0.000000   0.000000
# ps_ind_10_bin    0.000000   0.000000    0.000000   0.000000   0.000000
# ps_ind_11_bin    0.000000   0.000000    0.000000   0.000000   0.000000
# ps_ind_12_bin    0.000000   0.000000    0.000000   0.000000   0.000000
# ps_ind_13_bin    0.000000   0.000000    0.000000   0.000000   0.000000
# ps_ind_14        0.000000   0.000000    0.000000   0.000000   0.000000
# ps_ind_15        3.000000  12.000000    8.000000   9.000000   8.000000
# ps_ind_16_bin    0.000000   1.000000    1.000000   1.000000   1.000000
# ps_ind_17_bin    0.000000   0.000000    0.000000   0.000000   0.000000
# ps_ind_18_bin    1.000000   0.000000    0.000000   0.000000   0.000000
# ps_reg_01        0.800000   0.000000    0.900000   0.700000   0.600000
# ps_reg_02        0.400000   0.000000    0.200000   0.600000   0.100000
# ps_reg_03        0.766078  -1.000000    0.580948   0.840759   0.617454
# ps_car_01_cat   11.000000   7.000000    7.000000  11.000000   6.000000
# ps_car_02_cat    1.000000   1.000000    1.000000   1.000000   1.000000
# ps_car_03_cat   -1.000000  -1.000000    0.000000  -1.000000  -1.000000
# ps_car_04_cat    0.000000   0.000000    0.000000   0.000000   0.000000
# ps_car_05_cat   -1.000000  -1.000000    1.000000  -1.000000   1.000000
# ps_car_06_cat   11.000000  14.000000   11.000000  14.000000  11.000000
# ps_car_07_cat    1.000000   1.000000    1.000000   1.000000   1.000000
# ps_car_08_cat    1.000000   1.000000    1.000000   1.000000   1.000000
# ps_car_09_cat    2.000000   2.000000    3.000000   2.000000   0.000000
# ps_car_10_cat    1.000000   1.000000    1.000000   1.000000   1.000000
# ps_car_11_cat   19.000000  60.000000  104.000000  82.000000  99.000000
# ps_car_11        3.000000   1.000000    1.000000   3.000000   2.000000
# ps_car_12        0.316228   0.316228    0.374166   0.316070   0.316228
# ps_car_13        0.618817   0.641586    0.542949   0.565832   0.639683
# ps_car_14        0.388716   0.347275    0.294958   0.365103   0.368782
# ps_car_15        2.449490   3.316625    2.000000   2.000000   3.162278
# ps_calc_01       0.300000   0.500000    0.600000   0.400000   0.200000
# ps_calc_02       0.100000   0.700000    0.900000   0.600000   0.600000
# ps_calc_03       0.300000   0.100000    0.100000   0.000000   0.500000
# ps_calc_04       2.000000   2.000000    2.000000   2.000000   2.000000
# ps_calc_05       1.000000   2.000000    4.000000   2.000000   2.000000
# ps_calc_06       9.000000   9.000000    7.000000   6.000000   8.000000
# ps_calc_07       5.000000   1.000000    1.000000   3.000000   1.000000
# ps_calc_08       8.000000   8.000000    8.000000  10.000000   8.000000
# ps_calc_09       1.000000   2.000000    4.000000   2.000000   3.000000
# ps_calc_10       7.000000   7.000000    2.000000  12.000000  10.000000
# ps_calc_11       3.000000   4.000000    2.000000   3.000000   3.000000
# ps_calc_12       1.000000   2.000000    2.000000   1.000000   0.000000
# ps_calc_13       1.000000   7.000000    4.000000   1.000000   0.000000
# ps_calc_14       9.000000   7.000000    9.000000   3.000000  10.000000
# ps_calc_15_bin   0.000000   0.000000    0.000000   0.000000   0.000000
# ps_calc_16_bin   1.000000   1.000000    0.000000   0.000000   1.000000
# ps_calc_17_bin   1.000000   1.000000    0.000000   0.000000   0.000000
# ps_calc_18_bin   0.000000   0.000000    0.000000   1.000000   0.000000
# ps_calc_19_bin   1.000000   1.000000    0.000000   1.000000   1.000000
# ps_calc_20_bin   0.000000   0.000000    0.000000   0.000000   0.000000
# fold             5.000000   1.000000    3.000000   2.000000   1.000000

# %%
# train, test = train_test_split(train_data, test_size=0.3, shuffle=True)

# %%
train_data = train_data.replace(-1, np.nan)
test_data = test_data.replace(-1, np.nan)

# %%
train_data = train_data.drop(["id", "fold"], axis=1)
test_data = test_data.drop(["id"], axis=1)

# %%
cat_vars = [col for col in train_data.columns if 'cat' in col]
cat_vars
# Out:
# ['ps_ind_02_cat',
#  'ps_ind_04_cat',
#  'ps_ind_05_cat',
#  'ps_car_01_cat',
#  'ps_car_02_cat',
#  'ps_car_03_cat',
#  'ps_car_04_cat',
#  'ps_car_05_cat',
#  'ps_car_06_cat',
#  'ps_car_07_cat',
#  'ps_car_08_cat',
#  'ps_car_09_cat',
#  'ps_car_10_cat',
#  'ps_car_11_cat']

# %%
for col in cat_vars:
    test_data[col] = test_data[col].astype('category')
    
cat_vars = cat_vars + ["target"]

for col in cat_vars:
    train_data[col] = train_data[col].astype('category')

# %%
# EVAL_METRIC = "f1"
EVAL_METRIC = "roc_auc"
# SAVE_PATH = "AutoGluonModels_improved"   # Trained models will be saved here
SAVE_PATH = "AutoGluonModels_porto2"   # Trained models will be saved here
# LABEL = "Claim"
LABEL = "target"

# %% [markdown]
# ## Improving your AutoGluon Model

# %% [markdown]
# ### 1. Via Feature Engineering

# %%
# train["age_of_building"] = train["YearOfObservation"] - train["Date_of_Occupancy"]
# test["age_of_building"] = test["YearOfObservation"] - test["Date_of_Occupancy"]
# train["YearOfObservation"] = train["YearOfObservation"].astype("category")
# test["YearOfObservation"] = test["YearOfObservation"].astype("category")

# %% [markdown]
# ### 2. Use the Right Preset & refit_full

# %%
predictor = TabularPredictor(label=LABEL, path=SAVE_PATH, eval_metric=EVAL_METRIC)
# predictor = predictor.fit(train, presets=['best_quality'], time_limit=100, refit_full='best')
# increase time_limit=100 to 3600
predictor = predictor.fit(train_data, presets=['best_quality'], time_limit=3600, refit_full='best')
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=0, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 3600s
# AutoGluon will save models to "AutoGluonModels_porto2/"
# AutoGluon Version:  0.7.0
# Python Version:     3.9.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu May 4 15:21:22 UTC 2023
# Train Data Rows:    476170
# Train Data Columns: 57
# Label Column: target
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    261086.19 MB
# 	Train Data (Original)  Memory Usage: 170.47 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 18 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 14 | ['ps_ind_02_cat', 'ps_ind_04_cat', 'ps_ind_05_cat', 'ps_car_01_cat', 'ps_car_02_cat', ...]
# 		('float', [])    : 11 | ['ps_reg_01', 'ps_reg_02', 'ps_reg_03', 'ps_car_11', 'ps_car_12', ...]
# 		('int', [])      : 32 | ['ps_ind_01', 'ps_ind_03', 'ps_ind_06_bin', 'ps_ind_07_bin', 'ps_ind_08_bin', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 13 | ['ps_ind_02_cat', 'ps_ind_04_cat', 'ps_ind_05_cat', 'ps_car_01_cat', 'ps_car_02_cat', ...]
# 		('float', [])     : 11 | ['ps_reg_01', 'ps_reg_02', 'ps_reg_03', 'ps_car_11', 'ps_car_12', ...]
# 		('int', [])       : 15 | ['ps_ind_01', 'ps_ind_03', 'ps_ind_14', 'ps_ind_15', 'ps_calc_04', ...]
# 		('int', ['bool']) : 18 | ['ps_ind_06_bin', 'ps_ind_07_bin', 'ps_ind_08_bin', 'ps_ind_09_bin', 'ps_ind_10_bin', ...]
# 	2.4s = Fit runtime
# 	57 features in original data used to generate 57 features in processed data.
# 	Train Data (Processed) Memory Usage: 113.81 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 2.94s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric parameter of Predictor()
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 3597.06s of the 3597.06s of remaining time.
# 	0.5077	 = Validation score   (roc_auc)
# 	0.87s	 = Training   runtime
# 	30.1s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 3556.25s of the 3556.25s of remaining time.
# 	0.5076	 = Validation score   (roc_auc)
# 	0.54s	 = Training   runtime
# 	30.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3524.96s of the 3524.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6327	 = Validation score   (roc_auc)
# 	9.31s	 = Training   runtime
# 	1.47s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 3498.67s of the 3498.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6313	 = Validation score   (roc_auc)
# 	7.18s	 = Training   runtime
# 	1.34s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 3484.91s of the 3484.9s of remaining time.
# 	0.5995	 = Validation score   (roc_auc)
# 	15.64s	 = Training   runtime
# 	31.47s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 3435.16s of the 3435.16s of remaining time.
# 	0.6033	 = Validation score   (roc_auc)
# 	15.52s	 = Training   runtime
# 	29.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 3387.9s of the 3387.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6412	 = Validation score   (roc_auc)
# 	354.84s	 = Training   runtime
# 	1.2s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 3026.34s of the 3026.34s of remaining time.
# 	0.6019	 = Validation score   (roc_auc)
# 	9.78s	 = Training   runtime
# 	27.9s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2986.04s of the 2986.04s of remaining time.
# 	0.6028	 = Validation score   (roc_auc)
# 	9.96s	 = Training   runtime
# 	27.8s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2945.54s of the 2945.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6337	 = Validation score   (roc_auc)
# 	397.26s	 = Training   runtime
# 	5.04s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2540.86s of the 2540.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6384	 = Validation score   (roc_auc)
# 	11.99s	 = Training   runtime
# 	3.79s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2521.74s of the 2521.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6248	 = Validation score   (roc_auc)
# 	317.05s	 = Training   runtime
# 	4.25s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2198.28s of the 2198.27s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6311	 = Validation score   (roc_auc)
# 	13.35s	 = Training   runtime
# 	1.63s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2178.01s of the 2178.0s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6347	 = Validation score   (roc_auc)
# 	18.64s	 = Training   runtime
# 	2.95s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2162.11s of the 2162.11s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.633	 = Validation score   (roc_auc)
# 	14.43s	 = Training   runtime
# 	2.67s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2148.71s of the 2148.71s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6414	 = Validation score   (roc_auc)
# 	614.04s	 = Training   runtime
# 	2.34s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1883.42s of the 1883.42s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6385	 = Validation score   (roc_auc)
# 	810.44s	 = Training   runtime
# 	10.11s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1462.03s of the 1462.03s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6407	 = Validation score   (roc_auc)
# 	24.02s	 = Training   runtime
# 	7.82s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1442.96s of the 1442.96s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.6303	 = Validation score   (roc_auc)
# 	647.08s	 = Training   runtime
# 	8.55s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1106.6s of the 1106.59s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	0.633	 = Validation score   (roc_auc)
# 	24.51s	 = Training   runtime
# 	3.1s	 = Validation runtime
# Completed 2/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 1086.94s of remaining time.
# 	0.6444	 = Validation score   (roc_auc)
# 	107.38s	 = Training   runtime
# 	0.09s	 = Validation runtime
# AutoGluon training complete, total runtime = 2621.23s ... Best model: "WeightedEnsemble_L2"
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	2.4s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	15.64s	 = Training   runtime
# 	31.47s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	15.52s	 = Training   runtime
# 	29.1s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	59.3s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# 	Stopping at the best epoch learned earlier - 5.
# 	72.05s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	6.85s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	42.7s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	107.38s	 = Training   runtime
# Refit complete, total runtime = 210.71s
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutoGluonModels_porto2/")

# %%
predictor.leaderboard(extra_info=True, silent=True).head().T
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                0  \
# model                                                                                                                                                                                                                                                                                                                                                                                        WeightedEnsemble_L2
# score_val                                                                                                                                                                                                                                                                                                                                                                                                0.64438
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                          92.404387
# fit_time                                                                                                                                                                                                                                                                                                                                                                                             2252.750872
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                  0.087173
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                     107.377994
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                    2
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                   True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                     14
# num_features                                                                                                                                                                                                                                                                                                                                                                                                   7
# num_models                                                                                                                                                                                                                                                                                                                                                                                                     1
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                        83
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                 4797
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                               1361864684
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                             4797
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                            648087212
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                  7
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                0
# model_type                                                                                                                                                                                                                                                                                                                                                                                 WeightedEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                     GreedyWeightedEnsembleModel
# hyperparameters                                                                                                                                                                                                                                                                                       {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                           {}
# ag_args_fit                  {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                                                                                                                                                                                                                                                   [NeuralNetFastAI_BAG_L1, NeuralNetTorch_BAG_L1, XGBoost_BAG_L1, LightGBMXT_BAG_L1, RandomForestEntr_BAG_L1, CatBoost_BAG_L1, RandomForestGini_BAG_L1]
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                     {'ensemble_size': 100}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                  {'ensemble_size': 65}
# child_ag_args_fit            {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# ancestors                                                                                                                                                                                                                                                  [NeuralNetFastAI_BAG_L1, NeuralNetTorch_BAG_L1, XGBoost_BAG_L1, LightGBMXT_BAG_L1, RandomForestEntr_BAG_L1, CatBoost_BAG_L1, RandomForestGini_BAG_L1]
# descendants                                                                                                                                                                                                                                                                                                                                                                                                   []
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1  \
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                CatBoost_BAG_L1
# score_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.641441
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               2.336168
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  614.037724
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      2.336168
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         614.037724
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          7
# num_features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      57
# num_models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        16
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            16
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 28645568
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     28645568
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              3052282
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  3052282
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       CatBoostModel
# hyperparameters                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {}
# ag_args_fit                                                                                                                                                                                                                                                      {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                     [ps_calc_14, ps_car_07_cat, ps_ind_06_bin, ps_ind_17_bin, ps_car_14, ps_calc_06, ps_car_05_cat, ps_ind_12_bin, ps_ind_15, ps_car_01_cat, ps_ind_10_bin, ps_car_11, ps_calc_07, ps_calc_13, ps_car_10_cat, ps_ind_03, ps_reg_02, ps_ind_14, ps_ind_01, ps_ind_16_bin, ps_ind_08_bin, ps_ind_11_bin, ps_reg_03, ps_calc_15_bin, ps_ind_05_cat, ps_car_02_cat, ps_car_04_cat, ps_calc_16_bin, ps_car_13, ps_calc_01, ps_calc_05, ps_calc_18_bin, ps_car_06_cat, ps_ind_04_cat, ps_calc_03, ps_car_12, ps_ind_09_bin, ps_car_03_cat, ps_ind_07_bin, ps_calc_08, ps_ind_02_cat, ps_ind_18_bin, ps_car_15, ps_calc_10, ps_...
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         {'iterations': 10000, 'learning_rate': 0.05, 'random_seed': 0, 'allow_writing_files': False, 'eval_metric': 'Logloss'}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        {'iterations': 646}
# child_ag_args_fit                                                                                                                                                                                                                                      {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         []
# descendants                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [WeightedEnsemble_L2]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2  \
# model                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 XGBoost_BAG_L1
# score_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.640715
# pred_time_val                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               7.818072
# fit_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   24.023688
# pred_time_val_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      7.818072
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          24.023688
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         11
# num_features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      57
# num_models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        16
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            16
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  9088198
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      9088198
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               680433
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   680433
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        XGBoostModel
# hyperparameters                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {}
# ag_args_fit                                                                                                                                                                                                                                                      {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                     [ps_calc_14, ps_car_07_cat, ps_ind_06_bin, ps_ind_17_bin, ps_car_14, ps_calc_06, ps_car_05_cat, ps_ind_12_bin, ps_ind_15, ps_car_01_cat, ps_ind_10_bin, ps_car_11, ps_calc_07, ps_calc_13, ps_car_10_cat, ps_ind_03, ps_reg_02, ps_ind_14, ps_ind_01, ps_ind_16_bin, ps_ind_08_bin, ps_ind_11_bin, ps_reg_03, ps_calc_15_bin, ps_ind_05_cat, ps_car_02_cat, ps_car_04_cat, ps_calc_16_bin, ps_car_13, ps_calc_01, ps_calc_05, ps_calc_18_bin, ps_car_06_cat, ps_ind_04_cat, ps_calc_03, ps_car_12, ps_ind_09_bin, ps_car_03_cat, ps_ind_07_bin, ps_calc_08, ps_ind_02_cat, ps_ind_18_bin, ps_car_15, ps_calc_10, ps_...
# ...
# fit_time_marginal                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          18.635457
# stack_level                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# can_infer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       True
# fit_order                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          3
# num_features                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      57
# num_models                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        16
# num_models_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            16
# memory_size                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  6739071
# memory_size_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      6739071
# memory_size_min                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               996843
# memory_size_min_w_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   996843
# num_ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      0
# num_descendants                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      StackerEnsembleModel
# child_model_type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            LGBModel
# hyperparameters                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               {}
# ag_args_fit                                                                                                                                                                                                                                                      {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}
# features                     [ps_calc_14, ps_car_07_cat, ps_ind_06_bin, ps_ind_17_bin, ps_car_14, ps_calc_06, ps_car_05_cat, ps_ind_12_bin, ps_ind_15, ps_car_01_cat, ps_ind_10_bin, ps_car_11, ps_calc_07, ps_calc_13, ps_car_10_cat, ps_ind_03, ps_reg_02, ps_ind_14, ps_ind_01, ps_ind_16_bin, ps_ind_08_bin, ps_ind_11_bin, ps_reg_03, ps_calc_15_bin, ps_ind_05_cat, ps_car_02_cat, ps_car_04_cat, ps_calc_16_bin, ps_car_13, ps_calc_01, ps_calc_05, ps_calc_18_bin, ps_car_06_cat, ps_ind_04_cat, ps_calc_03, ps_car_12, ps_ind_09_bin, ps_car_03_cat, ps_ind_07_bin, ps_calc_08, ps_ind_02_cat, ps_ind_18_bin, ps_car_15, ps_calc_10, ps_...
# compile_time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    None
# child_hyperparameters                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {'learning_rate': 0.05, 'extra_trees': True}
# child_hyperparameters_fit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   {'num_boost_round': 112}
# child_ag_args_fit                                                                                                                                                                                                                                      {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': ['bool', 'int', 'float', 'category'], 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None}
# ancestors                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         []
# descendants                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [WeightedEnsemble_L2]

# %% [markdown]
# ### 3. Via CustomMetrics

# %%
fp_cost = 1000  # Admin fees spent to investigate potential insurance claim
fn_cost = 10000 # Average insurance claim made
tp_cost = 1000 # Admin fees spent to investigate potential insurance claim
tn_cost = 0

# %%
def cost_fn(y_true, y_prob):
    tp = np.where((y_prob >= 0.7) & (y_true==1), tp_cost, 0)
    fp = np.where((y_prob >= 0.7) & (y_true==0), fp_cost, 0)
    tn = np.where((y_prob < 0.7) & (y_true==0), tn_cost, 0)
    fn = np.where((y_prob < 0.7) & (y_true==1), fn_cost, 0)
    return np.sum([tp,fp,tn,fn])

# %%
my_scorer = make_scorer(
    name="operating_cost",
    score_func=cost_fn,
    greater_is_better=False,
    needs_proba=True
)

# %%
predictor.leaderboard(test_data, extra_metrics=[my_scorer], silent=True).head().T
# Out:
#                                            0                1  \
# model                    WeightedEnsemble_L2  CatBoost_BAG_L1
# score_test                           0.63742          0.63694
# operating_cost                     -43350000        -43350000
# score_val                            0.64438         0.641441
# pred_time_test                     60.105205         2.578153
# pred_time_val                      92.404387         2.336168
# fit_time                         2252.750872       614.037724
# pred_time_test_marginal             0.012863         2.578153
# pred_time_val_marginal              0.087173         2.336168
# fit_time_marginal                 107.377994       614.037724
# stack_level                                2                1
# can_infer                               True             True
# fit_order                                 14                7
#
#                                                 2               3  \
# model                    WeightedEnsemble_L2_FULL  XGBoost_BAG_L1
# score_test                               0.636556        0.636139
# operating_cost                          -43350000       -43350000
# score_val                                     NaN        0.640715
# pred_time_test                           6.399577       14.968619
# pred_time_val                                 NaN        7.818072
# fit_time                               321.823792       24.023688
# pred_time_test_marginal                  0.014527       14.968619
# pred_time_val_marginal                        NaN        7.818072
# fit_time_marginal                      107.377994       24.023688
# stack_level                                     2               1
# can_infer                                    True            True
# fit_order                                      22              11
#
#                                             4
# model                    CatBoost_BAG_L1_FULL
# score_test                           0.636111
# operating_cost                      -43350000
# score_val                                 NaN
# pred_time_test                       0.176755
# pred_time_val                             NaN
# fit_time                            59.295773
# pred_time_test_marginal              0.176755
# pred_time_val_marginal                    NaN
# fit_time_marginal                   59.295773
# stack_level                                 1
# can_infer                                True
# fit_order                                  18
